# %%
import pandas as pd
import networkx as nx
import regex as re

# %%
df = pd.read_pickle("US_Accidents_Processed_df.pkl")

# %%
# All of the different findings to split into network diagrams
findings_ls = list(set(df['finding_description']))
findings_ls
# Out:
# ['Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-Pilot of other aircraft - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Sign/marker-Effect on equipment',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general)-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Not attained/maintained - F',
#  'Personnel issues-Experience/knowledge-Training-Initial instruct/training-Pilot - C',
#  'Environmental issues-Physical environment-Terrain-Rough terrain-Effect on operation - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Not serviced/maintained',
#  'Personnel issues-Experience/knowledge-Training-(general)-Pilot of other aircraft - F',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Incorrect service/maintenance - F',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven terrain-Decision related to condition - F',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general)-Inadequate inspection - F',
#  'Organizational issues-Management-Culture-Safety-Other government',
#  'Aircraft-Fluids/misc hardware-Fluids-Grease-Fluid condition - C',
#  'Personnel issues-Task performance-(general)-(general)-Other/unknown - F',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-ATC personnel - F',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Spatial disorientation-Pilot - C',
#  'Personnel issues-Action/decision-Action-Incomplete action-ATC personnel',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to structural icing-Effect on personnel - C',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Incorrect use/operation - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Not specified - F',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Not serviced/maintained',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Unintentional use/operation - F',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-ATC personnel - F',
#  'Aircraft-Aircraft systems-Navigation system-Attitude & direction-Malfunction - C',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Capability exceeded - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Not serviced/maintained - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Attain/maintain not possible - F',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Not installed/available - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Effect on operation',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-(general)-Damaged/degraded - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Inoperative',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Configuration-Not specified',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Damaged/degraded',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Not specified - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Related operating info - C',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general)-Effect on equipment - C',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general)-Incorrect use/operation - F',
#  'Aircraft-Aircraft systems-Flight control system-(general)-Incorrect use/operation',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Low visibility-Decision related to condition',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Failure - C',
#  'Personnel issues-Task performance-Inspection-(general)-Pilot - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Malfunction - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Airport structure-Contributed to outcome - C',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general)-Related records - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller feather/reversing-Not specified',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Incorrect use/operation - C',
#  'Aircraft-Aircraft systems-(general)-(general)-Capability exceeded - F',
#  'Personnel issues-Action/decision-Action-Incomplete action-Pilot',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Design - F',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy-Decision related to condition',
#  'Environmental issues-Task environment-Pressures/demands-Time/schedule pressure-Effect on personnel - F',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Air inlet section (core eng)-Inadequate inspection - C',
#  'Aircraft-Aircraft systems-Navigation system-Global positioning sys (GPS)-Incorrect use/operation - F',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general)-Not specified - C',
#  'Aircraft-Aircraft systems-Hydraulic power system-(general)-Design',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Related operating info - F',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Copilot',
#  'Aircraft-Aircraft systems-(general)-(general)-Not specified - F',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Perception-Pilot of other aircraft - C',
#  'Aircraft-Aircraft power plant-Turbocharging (recip only)-Turbocharger-Damaged/degraded - C',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-Eng oil dist (airframe furn)-Inadequate inspection - C',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general)-Not installed/available - F',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of geographic area-Pilot - F',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Damaged/degraded - F',
#  'Environmental issues-Physical environment-Terrain-Wet/muddy-Effect on equipment - C',
#  'Aircraft-Aircraft power plant-Power plant-(general)-Related maintenance info',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other aircraft-Not specified - C',
#  'Environmental issues-Physical environment-Terrain-Wet/muddy-Not specified',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Not used/operated - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Not used/operated - F',
#  'Organizational issues-Management-(general)-(general)-Operator',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Ability to respond/compensate - F',
#  'Personnel issues-Experience/knowledge-Training-Recurrent instruct/training-Student/instructed pilot',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Awareness of condition - F',
#  'Aircraft-Aircraft handling/service-Placards and markings-(general)-Not installed/available - F',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Decision related to condition - F',
#  'Aircraft-Aircraft systems-Flight control system-Gust lock or damper-Inadequate inspection - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Effect on operation',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Ground crew - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Prop/rotor parameters-Related operating info',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Parachute-Design - C',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Design',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Compliance w/ procedure - F',
#  'Personnel issues-Action/decision-Action-Forgotten action/omission-Pilot of other aircraft - F',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Owner/builder - C',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Cabin crew - C',
#  'Aircraft-Aircraft handling/service-Loading-(general)-Incorrect use/operation - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Wet-Not specified',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Visual illusion/disorientation-Pilot',
#  'Environmental issues-Operating environment-Airport facilities/design-Fuel service/equipment-Effect on operation',
#  'Personnel issues-Experience/knowledge-Training-Training with equipment-Student/instructed pilot - C',
#  'Aircraft-Aircraft structures-(general)-(general)-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general)-Related maintenance info',
#  'Personnel issues-Action/decision-Action-Lack of action-Student/instructed pilot - C',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Combustion section-Not serviced/maintained',
#  'Environmental issues-Physical environment-Terrain-Mountainous/hilly terrain-Contributed to outcome',
#  'Aircraft-Aircraft structures-Empennage structure-Horizontal stabilizer-Design - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of available resources-Pilot - F',
#  'Aircraft-Aircraft systems-Fuel system-(general)-Not inspected - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Capability exceeded',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent/approach/glide path-Capability exceeded - F',
#  'Environmental issues-Operating environment-Air traffic/operating proc-(general)-Effect on operation - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Availability of related info - C',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Instructor/check pilot - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Takeoff distance-Related operating info',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Design - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-Main rotor blade system-Related maintenance info - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Not serviced/maintained - F',
#  'Personnel issues-Experience/knowledge-Training-Total instruct/training recvd-Pilot - F',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-(general)-Failure - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Awareness of condition',
#  'Aircraft-Aircraft power plant-Power plant-Mounts-Capability exceeded - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Design - F',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Unintentional use/operation - F',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Owner/builder - F',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Design',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Braking capability-Capability exceeded - C',
#  'Personnel issues-Task performance-Record-keeping-Aircraft/maintenance logs-Pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng liquid cooling-Malfunction',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Reduction gear and shaft-Design',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general)-Effect on operation - C',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Contributed to outcome - C',
#  'Aircraft-Aircraft systems-Electrical power system-Electrical pwr sys wiring-Design - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Configuration-Incorrect use/operation',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Incorrect service/maintenance - F',
#  'Environmental issues-Operating environment-Air traffic/operating proc-ATC clearance procedure-Compliance w/ procedure - F',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy-Effect on equipment',
#  'Aircraft-Aircraft structures-Wing structure-Main frame (on wing)-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Unintentional use/operation - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Contributed to outcome - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general)-Not attained/maintained - C',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Copilot - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Effect on operation - F',
#  'Organizational issues-Management-Policy/procedure-Availability of policy/proc-Equipment supplier - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Failure - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Not attained/maintained - C',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Other government - F',
#  'Personnel issues-Task performance-Use of equip/info-Aircraft control-Pilot of other aircraft - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Effect on equipment - C',
#  'Personnel issues-Task performance-Maintenance-Unauthorized maint/repair-Not specified - F',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Incorrect service/maintenance',
#  'Aircraft-Aircraft structures-Empennage structure-Elevators-Capability exceeded - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng supercharger-Capability exceeded - C',
#  'Organizational issues-Management-Culture-Pressures/demands-Operator',
#  'Organizational issues-Management-Communication (organizational)-Between groups/organizations-Manufacturer',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Glassy-Not specified - F',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Obscuration-Awareness of condition',
#  'Aircraft-Aircraft structures-Nacelles/pylons structure-Attach fittings (nac/pylon)-Design - C',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience w/ equipment-Maintenance personnel',
#  'Personnel issues-Task performance-Communication (personnel)-(general)-Instructor/check pilot - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Soft-Not specified',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Instrument panel-Not installed/available',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general)-Malfunction - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Windshear-Ability to respond/compensate - C',
#  'Aircraft-Aircraft structures-Doors-Cargo/baggage doors-Failure - C',
#  'Environmental issues-Operating environment-Airport facilities/design-(general)-Availability of related info',
#  'Personnel issues-Task performance-Maintenance-Repair-Owner/builder - C',
#  'Aircraft-Aircraft systems-Hydraulic power system-Pressure relief, main-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Lightning-Effect on personnel',
#  'Personnel issues-Task performance-Use of equip/info-(general)-Pilot - F',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Perception-Flight crew - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Prop/rotor parameters-Incorrect use/operation - C',
#  'Environmental issues-Physical environment-Object/animal/substance-(general)-Response/compensation - C',
#  'Aircraft-Aircraft power plant-Accessory gear-boxes-(general)-Failure',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway/landing area condition-Availability of related info - F',
#  'Personnel issues-Experience/knowledge-Training-Total instruct/training recvd-Student pilot',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience w/ equipment-Copilot',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Visual illusion/disorientation-Student/instructed pilot',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience w/ equipment-Copilot - F',
#  'Environmental issues-Operating environment-Air traffic/operating proc-(general)-Effect on operation - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Related maintenance info - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Heading/course-Not attained/maintained',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Combustion section-Fatigue/wear/corrosion',
#  'Personnel issues-Action/decision-Action-Lack of action-Airport personnel',
#  'Personnel issues-Task performance-Communication (personnel)-(general)-ATC personnel',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general)-Related records',
#  'Aircraft-Aircraft systems-(general)-(general)-Malfunction - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Life jacket-Not specified',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Not specified - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Incorrect service/maintenance - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft-Effect on equipment',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Not inspected - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Dynamic load-Capability exceeded',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Contributed to outcome - F',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Unintentional use/operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Failure - F',
#  'Organizational issues-Management-Communication (organizational)-Within group(s)/organization-Maintenance provider - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Capability exceeded',
#  'Aircraft-Fluids/misc hardware-Fluids-(general)-Fluid type - C',
#  'Personnel issues-Psychological-Personality/attitude-Complacency-Pilot - F',
#  'Personnel issues-Psychological-Attention/monitoring-Attention-Flight crew - C',
#  'Organizational issues-Management-Policy/procedure-(general)-Not specified',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Unknown/Not determined',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience in position-Student pilot',
#  'Personnel issues-Task performance-Use of equip/info-(general)-Cabin crew - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Failure - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Awareness of condition - C',
#  'Personnel issues-Task performance-Maintenance-(general)-Owner/builder - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Maximum crosswind component-Capability exceeded - C',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Design',
#  'Organizational issues-Development-Design-Policy/procedure development-Operator - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Design - C',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Flight crew - F',
#  'Aircraft-Fluids/misc hardware-Fluids-Water-Inadequate inspection',
#  'Personnel issues-Action/decision-Action-Forgotten action/omission-Flight service personnel - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Tower/antenna (incl guy wires)-Decision related to condition',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor-(general)-Incorrect service/maintenance',
#  'Personnel issues-Physical-Physical characteristic-Physical limitation-Pilot',
#  'Personnel issues-Action/decision-Action-Incomplete action-Ground crew - C',
#  'Personnel issues-Task performance-Communication (personnel)-(general)-Ground crew - F',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general)-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft power plant-Ignition system-Dist (ignition harness)-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Landing gear system-Steering unit-Malfunction - C',
#  'Aircraft-Aircraft structures-Empennage structure-(general)-Failure - C',
#  'Aircraft-Aircraft structures-Empennage structure-Vertical stabilizer-Incorrect service/maintenance - C',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Maintenance personnel - C',
#  'Aircraft-Aircraft structures-Doors-(general)-Incorrect use/operation - F',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Flight crew',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Malfunction - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Awareness of condition - F',
#  'Aircraft-Aircraft systems-Auto flight system-Autopilot system-Unintentional use/operation - C',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic congestion-Contributed to outcome - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Related operating info - C',
#  'Personnel issues-Task performance-Planning/preparation-Fuel planning-Student pilot - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Response/compensation',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Unneccessary use/operation - C',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-(general)-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-(general)-Not specified - F',
#  'Environmental issues-Task environment-Physical workspace-Visibility-Awareness of condition - F',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Pilot of other aircraft - C',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Reduction gear and shaft-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft systems-Flight control system-TE flap control system-Malfunction - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent/approach/glide path-Not specified - C',
#  'Aircraft-Aircraft structures-Empennage structure-Attach fittings (flt controls)-Failure - C',
#  'Aircraft-Aircraft structures-Wing structure-Landing gear (fitting on wing)-Failure',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Not used/operated - C',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-(general)-Other/unknown - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Design - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Malfunction',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Malfunction',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Related maintenance info - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-(general)-Not specified - C',
#  'Personnel issues-Task performance-Use of equip/info-(general)-Ground crew - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Thermal lifting-Not specified',
#  'Aircraft-Aircraft structures-Empennage structure-Vertical stab attach fitting-Failure - C',
#  'Aircraft-Aircraft power plant-Engine controls-Eng cntl sys wiring-Fatigue/wear/corrosion - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of charts-Ground crew - F',
#  'Personnel issues-Task performance-Maintenance-Installation-Maintenance personnel - F',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, main system-Failure',
#  'Aircraft-Aircraft structures-(general)-(general)-Fatigue/wear/corrosion - F',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Turbine section-Design',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Incorrect use/operation - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Ability to respond/compensate',
#  'Personnel issues-Psychological-Attention/monitoring-Attention-Pilot of other aircraft - C',
#  'Aircraft-Aircraft structures-Wing structure-Spoilers-Not used/operated - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Ability to respond/compensate',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Central warning-Not used/operated - F',
#  'Personnel issues-Action/decision-Action-Lack of action-Emergency services personnel',
#  'Aircraft-Aircraft systems-Flight control system-TE flap control system-Incorrect use/operation',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Compressor bleed control-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Not specified - C',
#  'Environmental issues-Physical environment-Terrain-(general)-Not specified',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Inoperative - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Sudden wind shift-Ability to respond/compensate - F',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Agricultural/external load sys-Unknown/Not determined',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Rain-Effect on equipment',
#  'Personnel issues-Action/decision-Action-Lack of action-Other',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Airport personnel - F',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Incorrect service/maintenance - C',
#  'Organizational issues-Management-Culture-(general)-Operator',
#  'Personnel issues-Miscellaneous-(general)-(general)-Instructor/check pilot - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general)-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Communications system-Interphone-Capability exceeded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Low ceiling-Contributed to outcome - F',
#  'Personnel issues-Action/decision-Action-Lack of action-Owner/builder - C',
#  'Aircraft-Aircraft systems-Vacuum system-Vacuum distribution system-Failure - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Passenger - C',
#  'Aircraft-Aircraft power plant-(general)-(general)-Malfunction',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Owner/builder - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-Main rotor blade system-Damaged/degraded',
#  'Environmental issues-Physical environment-Object/animal/substance-Debris/dirt/foreign object-Effect on equipment - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Incorrect use/operation',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Fatigue/wear/corrosion - C',
#  'Personnel issues-Physical-Sensory ability/limitation-Visual function-Pilot - F',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Incorrect service/maintenance - C',
#  'Personnel issues-Physical-Health/Fitness-Use of alcohol-Pilot',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity indicator-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Accessory drives-Design - F',
#  'Personnel issues-Task performance-Use of equip/info-Aircraft control-Student pilot - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general)-Effect on equipment',
#  'Environmental issues-Operating environment-Airport facilities/design-Security-Contributed to outcome - C',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Inadequate inspection - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Powerplant parameters-Not attained/maintained',
#  'Personnel issues-Physical-Impairment/incapacitation-Illness/injury-Pilot - F',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Student pilot',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Effect on equipment',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Incorrect service/maintenance',
#  'Environmental issues-Operating environment-Meteorological services-Automated weather-Accuracy of related info - F',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Incorrect use/operation - C',
#  'Aircraft-Aircraft structures-Wing structure-Spar (on wing)-Damaged/degraded',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Attain/maintain not possible',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Soft-Response/compensation - C',
#  'Environmental issues-Task environment-Physical workspace-Air quality/dust/smoke-Effect on personnel - C',
#  'Environmental issues-Physical environment-Terrain-Mountainous/hilly terrain-Ability to respond/compensate - C',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Pilot',
#  'Aircraft-Aircraft handling/service-Loading-(general)-Incorrect use/operation - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Malfunction - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Configuration-Capability exceeded - C',
#  'Personnel issues-Action/decision-Action-Lack of action-Designated examiner - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Water/moisture-Effect on operation',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general)-Decision related to condition',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Instrument panel-Inoperative - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Awareness of condition',
#  'Aircraft-Aircraft systems-Air conditioning system-Air distribution system-Failure - C',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Qualification/certification-Pilot - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Downdraft-Effect on operation',
#  'Aircraft-Aircraft systems-Flight control system-(general)-Design',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller hub section-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Hydraulic power system-Pump, main-Fatigue/wear/corrosion - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Fluid type - F',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Incorrect service/maintenance',
#  'Personnel issues-Psychological-Mental/emotional state-(general)-Pilot - F',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring environment-Pilot',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-(general)-Not serviced/maintained',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Sudden wind shift-Response/compensation - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway lighting-Effect on operation - F',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic congestion-Effect on operation',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Terrain induced turbulence-Ability to respond/compensate',
#  'Aircraft-Aircraft systems-Electrical power system-Electrical pwr sys wiring-Inoperative',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Effect on personnel - C',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Incorrect service/maintenance',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Drizzle/mist-Contributed to outcome - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High temperature-Effect on equipment - F',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High temperature-Effect on personnel - F',
#  'Aircraft-Aircraft systems-Flight control system-Stabilizer control system-Failure - C',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Copilot - C',
#  'Aircraft-Aircraft handling/service-Parking/securing-Parking/storage-Incorrect use/operation - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel oil cooler-Capability exceeded - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Haze/smoke-Contributed to outcome - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Not serviced/maintained',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Awareness of condition - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Climb rate-Capability exceeded - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Failure',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-ATC personnel - F',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Ground crew - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Related operating info',
#  'Personnel issues-Task performance-Maintenance-Installation-Maintenance personnel - C',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general)-Not serviced/maintained',
#  'Aircraft-Aircraft systems-Communications system-VHF communication system-Incorrect use/operation - C',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Maintenance personnel',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Not serviced/maintained - C',
#  'Personnel issues-Physical-Impairment/incapacitation-Alcohol-Pilot - F',
#  'Environmental issues-Physical environment-Terrain-Rough terrain-Not specified',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Ground crew',
#  'Personnel issues-Action/decision-Action-Forgotten action/omission-ATC personnel',
#  'Environmental issues-Task environment-Physical workspace-Access to equipment/controls-Ability to respond/compensate - F',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-Maintenance records-Operator - F',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven terrain-Effect on personnel',
#  'Personnel issues-Psychological-Perception/orientation/illusion-(general)-Copilot',
#  'Personnel issues-Task performance-Communication (personnel)-Issuing instructions-Pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Emergency floatation section-Design',
#  'Personnel issues-Action/decision-Action-Incomplete action-Other/unknown - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring environment-Airport personnel - C',
#  'Environmental issues-Physical environment-(general)-(general)-Effect on equipment',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Configuration-Attain/maintain not possible - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent rate-Not attained/maintained - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Not inspected - C',
#  'Environmental issues-Operating environment-Air traffic/operating proc-(general)-Not specified',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Not attained/maintained - C',
#  'Organizational issues-Management-Policy/procedure-Availability of policy/proc-Manufacturer - F',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Incorrect use/operation - F',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Not inspected - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Ground support/equipment-Not specified',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Instructor/check pilot - F',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-Temperature-Not specified',
#  'Aircraft-Aircraft power plant-Power plant-Engine cowling system-Failure',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Failure - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Cabin crew',
#  'Aircraft-Aircraft power plant-Water injection-(general)-Not used/operated',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Perception-Instructor/check pilot - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Incorrect service/maintenance - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Updraft-Response/compensation',
#  'Aircraft-Aircraft systems-Vacuum system-(general)-Failure - F',
#  'Personnel issues-Psychological-Attention/monitoring-(general)-Pilot - F',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Situational awareness-Pilot',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Response/compensation',
#  'Aircraft-Aircraft systems-Equipment/furnishings-(general)-Not specified - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Effect on operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Malfunction - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other aircraft-Pilot of other aircraft - F',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, main system-Failure - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Instructor/check pilot - C',
#  'Personnel issues-Action/decision-Action-Unneccessary action-Pilot of other aircraft - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Copilot',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Not attained/maintained - F',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Capability exceeded',
#  'Aircraft-Aircraft power plant-Ignition system-(general)-Failure - C',
#  'Organizational issues-Support/oversight/monitoring-Oversight-(general)-FAA/Regulator - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Malfunction - C',
#  'Aircraft-Aircraft systems-Hydraulic power system-(general)-Simulated malf/failure',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Not specified',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Incorrect use/operation - C',
#  'Aircraft-Aircraft power plant-Power plant-(general)-Not specified - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general)-Attain/maintain not possible',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller governor-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Hydraulic power system-(general)-Failure - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Awareness of condition',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Not specified',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-(general)-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Escape slide-Failure - C',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Damaged/degraded - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Hidden/submerged object-Effect on equipment - C',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-(general)-Failure',
#  'Aircraft-Aircraft structures-Wing structure-Plates/skins (on wing)-Incorrect service/maintenance',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-ATC personnel - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Response/compensation - C',
#  'Personnel issues-Experience/knowledge-Training-Recurrent instruct/training-Pilot - F',
#  'Personnel issues-Action/decision-Action-Delayed action-Student/instructed pilot - F',
#  'Personnel issues-Action/decision-Action-Lack of action-Designated examiner - C',
#  'Aircraft-Aircraft systems-Landing gear system-Master cylinder/brake valve-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Inadequate inspection - C',
#  'Personnel issues-Psychological-Cognitive limitation-Cognitive overload-Pilot - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Not specified - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Not attained/maintained',
#  'Organizational issues-Management-Policy/procedure-(general)-FAA/Regulator',
#  'Aircraft-Aircraft systems-Electrical power system-Electrical pwr sys wiring-Damaged/degraded',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Effect on operation - C',
#  'Personnel issues-Task performance-Maintenance-Modification/alteration-Maintenance personnel - C',
#  'Aircraft-Aircraft power plant-Turbocharging (recip only)-Turbocharger-Incorrect service/maintenance',
#  'Aircraft-Aircraft power plant-Engine exhaust-Noise suppressor-Inadequate inspection - C',
#  'Aircraft-Aircraft systems-Vacuum system-(general)-Damaged/degraded - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Malfunction',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Availability of safety program-Operator',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy terrain-Effect on operation',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-CG/weight distribution-Incorrect use/operation',
#  'Aircraft-Aircraft systems-(general)-(general)-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Capability exceeded',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Ability to respond/compensate - C',
#  'Aircraft-Aircraft systems-Flight control system-Elevator tab control system-Malfunction - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Copilot - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Effect on equipment',
#  'Personnel issues-Task performance-Maintenance-Installation-Not specified - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Contributed to outcome - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel sys wiring-Failure - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Related operating info - F',
#  'Personnel issues-Task performance-Maintenance-Installation-Other/unknown',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Effect on personnel - C',
#  'Aircraft-Aircraft systems-Electrical power system-DC power distribution system-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-Main rotor blade system-Not specified',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-ATC personnel - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-(general)-Effect on operation - C',
#  'Personnel issues-Miscellaneous-(general)-(general)-Not specified - C',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Ground crew - C',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Damaged/degraded',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Dark-Effect on personnel - F',
#  'Aircraft-Aircraft systems-Hydraulic power system-(general)-Inoperative - F',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Hail-Effect on operation',
#  'Aircraft-Aircraft systems-Fuel system-(general)-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Capability exceeded - C',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Student/instructed pilot - C',
#  'Environmental issues-Physical environment-Terrain-Rough terrain-Effect on equipment - F',
#  'Environmental issues-Task environment-Physical workspace-Positioning/available space-Contributed to outcome',
#  'Aircraft-Aircraft systems-Flight control system-TE flap control system-Not used/operated - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Tower/antenna (incl guy wires)-Effect on operation - F',
#  'Environmental issues-Physical environment-Terrain-(general)-Effect on operation - F',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-ATC personnel',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Not specified',
#  'Aircraft-Aircraft structures-Nacelles/pylons structure-Nacelle/pylon misc structure-Failure - C',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Malfunction - C',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Main rotor control-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Engine exhaust-(general)-Malfunction - C',
#  'Aircraft-Aircraft systems-Lighting system-Exterior lighting-Not installed/available - F',
#  'Aircraft-Aircraft structures-Wing structure-Flight surfaces (wing)-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Capability exceeded - F',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven-Decision related to condition - C',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Pilot - F',
#  'Personnel issues-Physical-Impairment/incapacitation-Other loss of consciousness-Pilot - C',
#  'Personnel issues-Physical-Alertness/Fatigue-Lack of sleep-Pilot - F',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven-Effect on operation - F',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy-Awareness of condition',
#  'Aircraft-Aircraft structures-Wing structure-(general)-Not specified - C',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of equipment-Pilot - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent rate-Incorrect use/operation - C',
#  'Personnel issues-Psychological-Personality/attitude-Complacency-Pilot',
#  'Aircraft-Aircraft power plant-Ignition system-Spark plugs/igniters-Fatigue/wear/corrosion - F',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent experience w/ equipment-Pilot - C',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Instrument panel-Failure',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Not specified',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Convective turbulence-Contributed to outcome',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general)-Not serviced/maintained - F',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Snow-Contributed to outcome - F',
#  'Personnel issues-Action/decision-Action-(general)-Cabin crew - C',
#  'Aircraft-Aircraft handling/service-Parking/securing-Tie-down/mooring-Incorrect use/operation',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Damaged/degraded',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Failure',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Inoperative - C',
# ...
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control electronic-Incorrect service/maintenance - C',
#  'Organizational issues-Support/oversight/monitoring-Training-Initial training-Equipment supplier',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Ground crew',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Qualification/certification-Passenger - C',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor-Tail rotor blade-Not specified',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Attain/maintain not possible - F',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Intake anti-ice, deice-Incorrect use/operation - C',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Maintenance personnel - C',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Failure - C',
#  'Environmental issues-Operating environment-Airport facilities/design-(general)-Not specified - F',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Incorrect use/operation - C',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Student/instructed pilot',
#  'Environmental issues-Operating environment-Air traffic/operating proc-(general)-Availability of related info - C',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Inoperative',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Design - F',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Damaged/degraded - C',
#  'Personnel issues-Task performance-Communication (personnel)-Issuing instructions-ATC personnel',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Incorrect use/operation - F',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Unscheduled maint checks-Not inspected - C',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general)-Not installed/available',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Choppy-Effect on equipment',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Malfunction - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Residence/building-Effect on operation - C',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Inadequate inspection - C',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Ground crew - F',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Ground crew - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Response/compensation',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Not specified',
#  'Personnel issues-Miscellaneous-Intentional act-Criminal/illegal act-Pilot',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Failure - C',
#  'Aircraft-Aircraft systems-Auto flight system-Autopilot system-Malfunction',
#  'Aircraft-Fluids/misc hardware-Fluids-Oil-Fluid condition - F',
#  'Aircraft-Aircraft systems-Flight control system-(general)-Incorrect use/operation - C',
#  'Personnel issues-Task performance-Maintenance-Unauthorized maint/repair-Pilot - C',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general)-Ability to respond/compensate - C',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Failure - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Decision related to condition',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Flight crew',
#  'Personnel issues-Task performance-Communication (personnel)-Readback-Maintenance personnel - F',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Not specified - C',
#  'Aircraft-Aircraft structures-Wing structure-Trailing edge flaps-Not specified',
#  'Aircraft-Aircraft power plant-Ignition system-Spark plugs/igniters-Damaged/degraded - C',
#  'Personnel issues-Action/decision-Action-Unnecessary action-Ground crew - F',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear steering system-Damaged/degraded - F',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Perception-Pilot of other aircraft - C',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Damaged/degraded',
#  'Aircraft-Aircraft systems-Auto flight system-Autopilot computer-Capability exceeded - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Student/instructed pilot',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Rotorcraft servo system-Incorrect service/maintenance',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Not specified - F',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Spatial disorientation-Student/instructed pilot - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Taxiway markings/signage-Awareness of condition - C',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Related maintenance info - C',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Capability exceeded - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Inadequate inspection - C',
#  'Aircraft-Aircraft systems-Vacuum system-Vacuum distribution system-Incorrect service/maintenance - F',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Low light-Contributed to outcome',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Not inspected',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Other',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Incorrect use/operation - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Response/compensation - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-CG/weight distribution-Incorrect use/operation - C',
#  'Aircraft-Aircraft power plant-Ignition system-Ignition power supply-Failure - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Engine out control-Not attained/maintained',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Choppy surface-Decision related to condition - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Decision related to condition - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Effect on operation - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Decision related to condition',
#  'Personnel issues-Task performance-Communication (personnel)-(general)-Pilot - F',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Malfunction - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Effect on operation',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Obscuration-Response/compensation - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Related operating info - F',
#  'Environmental issues-Task environment-(general)-(general)-Effect on operation - C',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Pilot - C',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-Tail rotor drive shaft-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Design - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general)-Decision related to condition',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Unknown/Not determined',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other aircraft-Student pilot - F',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Parachute-Malfunction - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Response/compensation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear attach section-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Incorrect use/operation',
#  'Personnel issues-Task performance-(general)-(general)-Flight crew',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general)-Incorrect service/maintenance',
#  'Aircraft-Aircraft structures-Wing structure-Spoilers-Unintentional use/operation - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Not specified',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Central computers (e.g. EICAS)-Incorrect use/operation',
#  'Organizational issues-Development-Design-Design of document/info-Operator - C',
#  'Organizational issues-Support/oversight/monitoring-Training-Upgrade training-FAA/Regulator - F',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Geographic disorient (lost)-Pilot - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Damaged/degraded - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-(general)-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Electrical power system-(general)-Inoperative - F',
#  'Personnel issues-Physical-Alertness/Fatigue-Lack of sleep-Flight crew - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Climb capability-Attain/maintain not possible',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Drizzle/mist-Decision related to condition - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Landing distance-Not attained/maintained',
#  'main system-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Electrical power system-DC regulator-Failure',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Pilot - F',
#  'Aircraft-Aircraft power plant-Ignition system-(general)-Not specified - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng liquid cooling-Malfunction - C',
#  'Aircraft-Aircraft propeller/rotor-(general)-(general)-Capability exceeded',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Incorrect use/operation',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Wake turbulence-Ability to respond/compensate - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Contributed to outcome',
#  'Aircraft-Aircraft systems-Auto flight system-Auto throttle system-Related operating info',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Thermal lifting-Contributed to outcome - F',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Cabin crew - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-(general)-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, indicating system-Design',
#  'Aircraft-Aircraft systems-Navigation system-Pitot/static system-Damaged/degraded',
#  'Personnel issues-Task performance-Maintenance-Repair-Owner/builder',
#  'Organizational issues-Development-Manufacture/production-Document/info production-Manufacturer - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng liquid cooling-Fatigue/wear/corrosion - C',
#  'Organizational issues-Management-Policy/procedure-(general)-Manufacturer',
#  'Personnel issues-Task performance-(general)-(general)-Passenger - C',
#  'Aircraft-Aircraft structures-Doors-Landing gear doors-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Not specified - C',
#  'Aircraft-Aircraft handling/service-Loading-(general)-Not serviced/maintained - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Downdraft-Awareness of condition',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Copilot - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Parachute-Not used/operated - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general)-Attain/maintain not possible - C',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-(general)-Operator',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Decision related to condition - C',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Instructor/check pilot - C',
#  'Aircraft-Aircraft systems-Navigation system-Ground proximity system-Not used/operated',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Terrain induced turbulence-Effect on personnel',
#  'Environmental issues-Physical environment-Object/animal/substance-Debris/dirt/foreign object-Effect on equipment - F',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Tail rotor control system-Unintentional use/operation - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Taxiway lighting-Effect on operation',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Effect on operation - F',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Central display-Malfunction',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience-Student pilot - F',
#  'Personnel issues-Experience/knowledge-(general)-(general)-Pilot - C',
#  'Environmental issues-Task environment-Physical workspace-Visibility-Effect on personnel',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Hail-Effect on equipment',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general)-Effect on equipment',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-Pilot - C',
#  'Aircraft-Aircraft structures-Wing structure-Spar (on wing)-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Incorrect service/maintenance - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Contributed to outcome - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Damaged/degraded',
#  'Environmental issues-Task environment-Pressures/demands-Personal pressure-Effect on operation - F',
#  'Personnel issues-Physical-Impairment/incapacitation-Hypoxia/anoxia-Pilot',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller hub section-Fatigue/wear/corrosion',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Pilot - F',
#  'Personnel issues-Action/decision-Action-Delayed action-Flight crew',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-Main rotor head system-Failure - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-(general)-Availability of related info - F',
#  'Aircraft-Aircraft systems-Ice/rain protection system-(general)-Not used/operated - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Water-Related operating info',
#  'Aircraft-Aircraft structures-Empennage structure-Rudder-Incorrect service/maintenance - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Effect on equipment',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven-Not specified - F',
#  'Personnel issues-Psychological-Perception/orientation/illusion-(general)-Pilot - C',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Oversight of operation-Training organization - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Failure',
#  'Aircraft-Aircraft systems-Flight control system-Elevator tab control system-Unintentional use/operation - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Not specified',
#  'Environmental issues-Operating environment-Airport facilities/design-Airport lighting-Not specified',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Failure - C',
#  ...]

# %%
# Count the number of layers that will be needed in the network diagram
word_no = len(re.split('-', findings_ls[0]))
print(word_no)
# Out:
# 6

# %%
# identify the unique words for each layer
type_ls = []
sys_ls = []
subsys_ls = []
details_ls = []
moredet_ls = []
ix = 0
for finding in findings_ls:
    # for each finding I want to append each word to a separate list
    # but I also want the connections
    ix += 1
    word_ls = re.split('-', finding)
    if len(word_ls) >= 5:
        type_ls.append(word_ls[0])
        sys_ls.append(word_ls[1])
        subsys_ls.append(word_ls[2])
        details_ls.append(word_ls[3])
        moredet_ls.append(word_ls[4])
    else:
        type_ls.append(word_ls[0])
        sys_ls.append(word_ls[1])
        subsys_ls.append(word_ls[2])

# %%
type_ls = set(type_ls)
sys_ls = set(sys_ls)
subsys_ls = set(subsys_ls)
details_ls = set(details_ls)
moredet_ls = set(moredet_ls)

# %% [markdown]
# ## Create the network diagram of the connections

# %%
# create a dictionary where the types are the main keys and the values are in a list which correspond to the ones that are linked to each other
ls = []
for type_name in type_ls:
    for finding in findings_ls:
        if # type is before the second word then add as an option
        type_dict[type_name] = ls.append(
# Out:
#   Cell In[7], line 5
#     if # type is before the second word then add as an option
#        ^
# SyntaxError: invalid syntax

# %%
G = nx.Graph()

# %%
sys_dict
