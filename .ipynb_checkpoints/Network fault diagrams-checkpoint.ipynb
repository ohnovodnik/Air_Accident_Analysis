# %%
import pandas as pd
import networkx as nx
import regex as re
import matplotlib.pyplot as plt
import matplotlib as mat

# %%
df = pd.read_pickle("US_Accidents_Processed_df.pkl")

# %%
# All of the different findings to split into network diagrams
findings_ls = list(set(df['finding_description']))
findings_ls
# Out:
# ['Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Attain/maintain not possible - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Awareness of condition - F',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Combustion section-Not serviced/maintained',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Failure - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Capability exceeded',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Damaged/degraded - C',
#  'Aircraft-Aircraft power plant-Ignition system-Switching-Unintentional use/operation - F',
#  'Personnel issues-Task performance-Maintenance-(general)-Maintenance personnel - F',
#  'Aircraft-Aircraft systems-Fuel system-(general)-Incorrect use/operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Effect on equipment - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Inadequate inspection - C',
#  'Aircraft-Aircraft power plant-Engine indicating system-Power indicating system-Failure - C',
#  'Aircraft-Aircraft power plant-Power plant-Engine cowling system-Capability exceeded',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity sensor-Malfunction - F',
#  'Aircraft-Aircraft systems-Flight control system-Rudder actuator-Failure',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller hub section-Incorrect service/maintenance - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Not specified',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Not serviced/maintained',
#  'Aircraft-Aircraft structures-Empennage structure-(general)-Failure',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Ground crew - C',
#  'Personnel issues-Action/decision-Action-Lack of action-Maintenance personnel - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general)-Capability exceeded',
#  'Aircraft-Aircraft systems-Oxygen system-(general)-Inadequate inspection - C',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general)-Failure',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Flight crew',
#  'Aircraft-Aircraft systems-Navigation system-Ground proximity system-Capability exceeded',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity indicator-Failure - F',
#  'Aircraft-Aircraft power plant-Accessory gear-boxes-(general)-Not serviced/maintained - C',
#  'Aircraft-Aircraft systems-Navigation system-Flight environment data-Not serviced/maintained - F',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Not installed/available - F',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Flt operations/dispatcher - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Awareness of condition - C',
#  'Personnel issues-Task performance-(general)-(general)-ATC personnel - C',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Capability exceeded',
#  'Organizational issues-Management-Resources-(general)-Manufacturer',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Other/unknown - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Powerplant parameters-Incorrect use/operation',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Pilot',
#  'Personnel issues-Physical-Sensory ability/limitation-Visual function-Ground crew - C',
#  'Environmental issues-Task environment-Pressures/demands-Other pressure/demand-Decision related to condition',
#  'Personnel issues-Psychological-Personality/attitude-Self confidence-Pilot - F',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring equip/instruments-Flight crew - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Incorrect use/operation',
#  'Aircraft-Aircraft structures-Wing structure-Spar (on wing)-Failure - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Instructor/check pilot',
#  'Aircraft-Aircraft structures-(general)-(general)-Not used/operated - F',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Agricultural/external load sys-Unintentional use/operation - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Glassy-Effect on operation - F',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-Maintenance records-Operator - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Not specified - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Failure',
#  'Environmental issues-Task environment-Physical workspace-Visibility-Contributed to outcome',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Not specified - F',
#  'Environmental issues-Operating environment-Approach aid coverage/avail-Approach lighting-Not specified',
#  'Aircraft-Aircraft power plant-(general)-(general)-Not specified - F',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Pilot of other aircraft - C',
#  'Personnel issues-Action/decision-Action-Delayed action-Instructor/check pilot - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Not specified - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Engine out capability-Not attained/maintained - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Drizzle/mist-Effect on operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Runway/taxi/approach light-Contributed to outcome - F',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Oil system-Inoperative',
#  'Personnel issues-Task performance-Planning/preparation-Weight/balance calculations-Pilot',
#  'Personnel issues-Task performance-Communication (personnel)-Issuing instructions-ATC personnel - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Not serviced/maintained - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Attain/maintain not possible',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Not inspected - C',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Incorrect service/maintenance',
#  'Personnel issues-Psychological-Attention/monitoring-Attention-Student pilot - F',
#  'Aircraft-Aircraft power plant-Engine indicating system-Engine indication sys wiring-Damaged/degraded',
#  'Not determined-Not determined-(general)-(general)-Unknown/Not determined',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Design',
#  'Aircraft-Aircraft structures-Empennage structure-Horizontal stabilizer-Incorrect service/maintenance - C',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Not specified',
#  'Aircraft-Aircraft structures-Wing structure-Fus (attach fitting on wing)-Inadequate inspection',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Incorrect service/maintenance - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High density altitude-Response/compensation - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Ability to respond/compensate',
#  'Personnel issues-Task performance-Planning/preparation-Fuel planning-Flight crew - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered-Awareness of condition - C',
#  'Aircraft-Aircraft systems-Electrical power system-(general)-Not specified',
#  'Environmental issues-Task environment-Physical workspace-Vibration-Effect on operation',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Contributed to outcome - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Malfunction',
#  'Aircraft-Aircraft power plant-Power plant-Engine cowling system-Failure',
#  'Personnel issues-Action/decision-Action-Lack of action-Flight crew - C',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Adequacy of safety program-Emergency services',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Adequacy of safety program-Other government',
#  'Aircraft-Aircraft structures-Empennage structure-Elevator/tab attach fitting-Incorrect service/maintenance - C',
#  'Personnel issues-Task performance-Maintenance-Modification/alteration-Student/instructed pilot',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Malfunction - C',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Malfunction - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Rotor/drive indicating system-Unknown/Not determined',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Fatigue/wear/corrosion - F',
#  'Environmental issues-Physical environment-Terrain-Mountainous/hilly terrain-Awareness of condition',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Inadequate inspection - F',
#  'Personnel issues-Action/decision-Action-(general)-Student pilot - C',
#  'Aircraft-Aircraft structures-Wing structure-Main frame (on wing)-Failure',
#  'Aircraft-Aircraft structures-Fuselage-Frames (main fuselage)-Inadequate inspection - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Sign/marker-Not specified',
#  'Aircraft-Aircraft structures-Fuselage-Gear attach fittings (on fus)-Inadequate inspection - C',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-(general)-Not specified - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng liquid cooling-Malfunction - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Incorrect use/operation - F',
#  'Environmental issues-Task environment-Pressures/demands-Equipment/operational-Effect on personnel - F',
#  'Aircraft-Aircraft power plant-Power plant-Eng air baffle sec (recip.)-Incorrect service/maintenance - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Response/compensation - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway markings/signage-Decision related to condition - F',
#  'Aircraft-Aircraft power plant-Power plant-Engine cowling system-Incorrect use/operation',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Capability exceeded - C',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general)-Design',
#  'Aircraft-Aircraft structures-Wing structure-Flight surfaces (wing)-Incorrect service/maintenance - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on equipment - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Other/unknown',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Student pilot - C',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Owner/builder - C',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general)-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft systems-Electrical power system-DC regulator-Failure - C',
#  'Aircraft-Aircraft power plant-Power plant-(general)-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft handling/service-Towing and taxiing-Taxiing-Incorrect use/operation - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Not serviced/maintained',
#  'Personnel issues-Task performance-Communication (personnel)-(general)-Pilot of other aircraft',
#  'Personnel issues-Psychological-Personality/attitude-Complacency-Student/instructed pilot',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Dark-Ability to respond/compensate - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Ground crew - C',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven-Effect on equipment - F',
#  'Personnel issues-Psychological-Personality/attitude-Motivation/respond to pressure-Pilot',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-Eng oil dist (airframe furn)-Inadequate inspection',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-(general)-Decision related to condition - C',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Damaged/degraded - F',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy terrain-Effect on equipment',
#  'Personnel issues-Psychological-Mental/emotional state-Stress-Pilot - C',
#  'Personnel issues-Action/decision-Action-Forgotten action/omission-Flight crew - C',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Terrain induced turbulence-Effect on operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Effect on operation - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Tower/antenna (incl guy wires)-Contributed to outcome - F',
#  'Aircraft-Aircraft systems-(general)-(general)-Malfunction - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Incorrect use/operation - C',
#  'Environmental issues-Operating environment-(general)-(general)-Contributed to outcome - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Not serviced/maintained',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Effect on equipment',
#  'Personnel issues-Action/decision-Action-(general)-Flight crew - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Awareness of condition - C',
#  'Aircraft-Aircraft structures-Doors-Landing gear doors-Related maintenance info - C',
#  'Aircraft-Aircraft structures-Wing structure-Trailing edge flaps-Not used/operated - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller feather/reversing-Not specified - F',
#  'Personnel issues-Task performance-Communication (personnel)-Interpretation/understanding-Student/instructed pilot - C',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-(general)-Pilot - F',
#  'Aircraft-Aircraft power plant-Ignition system-Ignition power supply-Malfunction - C',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Bright light-Effect on personnel',
#  'Aircraft-Aircraft power plant-Turbocharging (recip only)-(general)-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Fatigue/wear/corrosion - C',
#  'Environmental issues-Operating environment-Airport facilities/design-(general)-Awareness of condition - C',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Incorrect use/operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Not specified',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Emergency locator beacon-Not specified',
#  'Aircraft-Aircraft structures-Doors-Emergency exit-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Inadequate inspection - C',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Failure',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Unintentional use/operation - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general)-Contributed to outcome - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general)-Not attained/maintained - C',
#  'Aircraft-Aircraft systems-Electrical power system-DC generator-alternator-Failure',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Failure - C',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Student pilot - C',
#  'Personnel issues-Task performance-(general)-(general)-Pilot - F',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Oil system-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Oil system-Damaged/degraded - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general)-Response/compensation - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Flight crew',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Not specified - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general)-Effect on personnel',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Related operating info - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Damaged/degraded',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Fasteners-Not serviced/maintained - C',
#  'Personnel issues-Task performance-Maintenance-Modification/alteration-Maintenance personnel - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Inoperative',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Effect on equipment',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear attach section-Capability exceeded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Clouds-Not specified',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Adequacy of safety program-Other institution/organization - F',
#  'Personnel issues-Physical-Alertness/Fatigue-Lack of sleep-Flight crew - F',
#  'Environmental issues-Task environment-(general)-(general)-Effect on equipment - C',
#  'Environmental issues-Physical environment-Terrain-Rough terrain-Contributed to outcome - F',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Flight compartment equipment-Not installed/available - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Malfunction - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Incorrect service/maintenance',
#  'Aircraft-Fluids/misc hardware-Fluids-Oil-Not serviced/maintained - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below approach minima-Decision related to condition - F',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Effect on personnel - F',
#  'Aircraft-Aircraft systems-Landing gear system-Wheel/ski/float-Capability exceeded - C',
#  'Environmental issues-Physical environment-Terrain-Rough terrain-Awareness of condition - C',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Flat light-Effect on operation - C',
#  'Personnel issues-Psychological-Attention/monitoring-(general)-Pilot - C',
#  'Aircraft-Aircraft systems-Electrical power system-AC power distribution system-Malfunction - C',
#  'Aircraft-Aircraft power plant-(general)-(general)-Malfunction',
#  'Environmental issues-Operating environment-Communication system-(general)-Contributed to outcome - F',
#  'Personnel issues-Action/decision-Action-Lack of action-Designated examiner - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Failure',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Student/instructed pilot',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Incorrect use/operation - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Not specified - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Not specified - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general)-Effect on operation - F',
#  'Personnel issues-Physical-Health/Fitness-Predisposing condition-Pilot',
#  'Personnel issues-Task performance-Maintenance-Installation-Other/unknown',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Effect on operation - C',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Not serviced/maintained - C',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Fasteners-Not specified - C',
#  'Aircraft-Aircraft power plant-(general)-(general)-Damaged/degraded',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Not specified',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Not specified',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Oil system-Not specified',
#  'Aircraft-Aircraft structures-Wing structure-Ailerons-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Hydraulic power system-(general)-Malfunction - C',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Not specified - C',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Unintentional use/operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Incorrect use/operation - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Related operating info - F',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of meteorologic cond-Pilot',
#  'Personnel issues-Action/decision-Action-Delayed action-Instructor/check pilot - C',
#  'Aircraft-Aircraft systems-Fuel system-(general)-Inadequate inspection - C',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-(general)-Damaged/degraded - F',
#  'Personnel issues-Task performance-Communication (personnel)-Accuracy of communication-Other/unknown - F',
#  'Personnel issues-Physical-Alertness/Fatigue-(general)-Pilot',
#  'Aircraft-Aircraft systems-Oxygen system-Crew oxygen system-Not used/operated - C',
#  'Aircraft-Aircraft systems-Flight control system-Rudder tab control system-Unintentional use/operation - C',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Engine anti-icing system-Malfunction - C',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Fasteners-Incorrect service/maintenance',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-Maintenance records-Manufacturer',
#  'Personnel issues-Task performance-Planning/preparation-Performance calculations-Pilot - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Passenger - F',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic pattern procedure-Contributed to outcome - F',
#  'Aircraft-Aircraft structures-Empennage structure-Horizontal stabilizer-Damaged/degraded',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Incorrect service/maintenance - F',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Pilot - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Wet surface-Effect on operation - F',
#  'Aircraft-Aircraft systems-Electrical power system-DC power distribution system-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft power plant-Power plant-(general)-Damaged/degraded - F',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear selector-Inoperative',
#  'Personnel issues-Action/decision-Action-Lack of action-Maintenance personnel',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Spatial disorientation-Pilot - F',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Incorrect service/maintenance',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Incorrect use/operation - C',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Adequacy of safety program-FAA/Regulator - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Inadequate inspection',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-ATC personnel - C',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Hoses and tubes-Incorrect service/maintenance - C',
#  'Personnel issues-Task performance-Communication (personnel)-Accuracy of communication-Pilot - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Ability to respond/compensate - F',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Incorrect use/operation',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Climb capability-Not specified - C',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Passenger - F',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Flight crew',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Geographic disorient (lost)-Pilot - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring equip/instruments-Instructor/check pilot - C',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Incorrect service/maintenance - F',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Flight crew - F',
#  'Aircraft-Aircraft propeller/rotor-(general)-(general)-Damaged/degraded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Obscuration-Effect on operation - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Effect on equipment',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-ATC personnel',
#  'Aircraft-Aircraft power plant-Engine starting-(general)-Unintentional use/operation',
#  'Environmental issues-Physical environment-Object/animal/substance-(general)-Effect on operation',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Maintenance personnel - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Effect on equipment - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel oil cooler-Incorrect service/maintenance',
#  'Environmental issues-Operating environment-Airport facilities/design-Taxiway markings/signage-Availability of related info - C',
#  'Aircraft-Aircraft structures-(general)-(general)-Fatigue/wear/corrosion',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general)-Not specified - C',
#  'Aircraft-Aircraft systems-Navigation system-Pitot/static system-Inadequate inspection',
#  'Organizational issues-Development-Design-Policy/procedure development-Airport - C',
#  'Personnel issues-Task performance-Workload management-Task allocation-Pilot - F',
#  'Personnel issues-Physical-Alertness/Fatigue-Fatigue due to work schedule-Instructor/check pilot',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent rate-Capability exceeded - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Related maintenance info - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Debris/dirt/foreign object-Decision related to condition',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Malfunction - F',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general)-Incorrect use/operation - F',
#  'Aircraft-Aircraft systems-Hydraulic power system-Pump, main-Incorrect service/maintenance',
#  'Aircraft-Fluids/misc hardware-Fluids-Oil-Unknown/Not determined',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general)-Decision related to condition - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Contributed to outcome - C',
#  'Personnel issues-Action/decision-Action-Incomplete action-Pilot - F',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-(general)-Failure - C',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Contributed to outcome - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Malfunction - C',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Failure - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of manual-Instructor/check pilot - C',
#  'Personnel issues-Physical-Impairment/incapacitation-Cardiovascular-Pilot',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Student/instructed pilot',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Pilot - F',
#  'Environmental issues-Operating environment-Air traffic/operating proc-ATC clearance procedure-Effect on operation - F',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor-(general)-Damaged/degraded',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Inoperative - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered-Effect on equipment - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Damaged/degraded - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Failure - F',
#  'Personnel issues-Miscellaneous-Intentional act-(general)-Not specified - F',
#  'Personnel issues-Task performance-(general)-(general)-Maintenance personnel - C',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Capability exceeded',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Contributed to outcome',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Flight crew - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Not serviced/maintained - C',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Student pilot - C',
#  'Personnel issues-Psychological-Personality/attitude-(general)-Pilot',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel controlling system-Malfunction',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Inadequate inspection',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High temperature-Effect on operation',
#  'Aircraft-Aircraft structures-Wing structure-Spar (on wing)-Fatigue/wear/corrosion - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Runway/taxi/approach light-Decision related to condition',
#  'Organizational issues-Support/oversight/monitoring-Training-Initial training-ATC - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Unnecessary use/operation - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Windshear-Effect on operation - F',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Obscuration-Effect on operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Malfunction - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Ability to respond/compensate - F',
#  'Aircraft-Aircraft systems-Landing gear system-Steering unit-Not specified',
#  'Aircraft-Aircraft systems-Equipment/furnishings-(general)-Not specified',
#  'Personnel issues-Task performance-Planning/preparation-(general)-Flight crew - F',
#  'Aircraft-Aircraft power plant-Ignition system-Switching-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Inadequate inspection',
#  'Environmental issues-Operating environment-(general)-(general)-Effect on personnel',
#  'Environmental issues-Physical environment-Object/animal/substance-Snow/ice-Contributed to outcome - C',
#  'Personnel issues-Task performance-Maintenance-Repair-Pilot - F',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Whiteout-Effect on personnel - C',
#  'Environmental issues-Task environment-Pressures/demands-Time/schedule pressure-Decision related to condition - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Response/compensation',
#  'Environmental issues-Task environment-Physical workspace-Air quality/dust/smoke-Decision related to condition - F',
#  'Personnel issues-Action/decision-Action-(general)-Ground crew - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng supercharger-Capability exceeded - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Yaw control-Not attained/maintained - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Malfunction - C',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Pilot - F',
#  'Aircraft-Aircraft oper/perf/capability-(general)-(general)-Attain/maintain not possible - C',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Malfunction - C',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Inoperative - C',
#  'Aircraft-Aircraft structures-Empennage structure-Vertical stab attach fitting-Failure - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Incorrect use/operation - C',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Not specified - F',
#  'Aircraft-Aircraft power plant-Ignition system-(general)-Incorrect use/operation - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Design - F',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general)-Damaged/degraded - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Soft-Decision related to condition - F',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Not specified - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-CG/weight distribution-Not attained/maintained',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Capability exceeded - C',
#  'Personnel issues-Action/decision-Action-Unneccessary action-Passenger - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Climb rate-Capability exceeded',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general)-Not specified - F',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general)-Not specified - F',
#  'Personnel issues-Task performance-Maintenance-Installation-Maintenance personnel - C',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Passenger - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Not attained/maintained - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Not specified - F',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Tail rotor control system-Not specified - C',
#  'Aircraft-Aircraft systems-Navigation system-Directional gyro & indication-Failure - F',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Airport personnel - F',
#  'Personnel issues-Physical-Impairment/incapacitation-Prescription medication-Pilot of other aircraft - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Snow removal service/equipment-Contributed to outcome',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on operation',
#  'Environmental issues-Operating environment-Airport facilities/design-(general)-Effect on operation',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience w/ equipment-Copilot - F',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Malfunction',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Owner/builder - F',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general)-Effect on operation - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Ground support/equipment-Not specified',
#  'Aircraft-Aircraft handling/service-Parking/securing-Tie-down/mooring-Not specified - F',
#  'Aircraft-Aircraft systems-(general)-(general)-Malfunction',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Not specified',
#  'Personnel issues-Task performance-Communication (personnel)-Interpretation/understanding-Pilot - F',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Malfunction - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Engine out control-Not attained/maintained - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Incorrect service/maintenance - C',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Terrain induced turbulence-Ability to respond/compensate',
#  'Personnel issues-Task performance-Maintenance-Scheduled/routine maintenance-Owner/builder - C',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Not used/operated - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel divider-Incorrect service/maintenance - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Ability to respond/compensate',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Student/instructed pilot',
#  'Environmental issues-Physical environment-Object/animal/substance-Debris/dirt/foreign object-Ability to respond/compensate',
#  'Aircraft-Aircraft power plant-(general)-(general)-Incorrect service/maintenance - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Contributed to outcome',
#  'Personnel issues-Physical-Impairment/incapacitation-Prescription medication-Student pilot - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Wet surface-Effect on operation',
#  'Personnel issues-Task performance-Maintenance-(general)-Other/unknown - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Prop/spinner section-Unknown/Not determined',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Takeoff distance-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine controls-Eng cntl sys wiring-Fatigue/wear/corrosion - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Flight crew - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity indicator-Related operating info - F',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-(general)-FAA/Regulator',
#  'Personnel issues-Psychological-Personality/attitude-Motivation/respond to pressure-Pilot - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Decision related to condition - C',
#  'Organizational issues-Support/oversight/monitoring-Training-Emergency proc training-FAA/Regulator',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent/approach/glide path-Related operating info - C',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Failure - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Failure - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Incorrect use/operation',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-Main rotor blade system-Not serviced/maintained - C',
#  'Environmental issues-Task environment-Pressures/demands-Time/schedule pressure-Decision related to condition',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Data recorders (flight/maint)-Capability exceeded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Effect on operation - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Contributed to outcome - F',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Unintentional use/operation - C',
#  'Aircraft-Aircraft structures-Windows-windshield system-(general)-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Engine fuel and control-(general)-Incorrect use/operation - C',
#  'Aircraft-Aircraft handling/service-Placards and markings-(general)-Not installed/available - F',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-(general)-Pilot',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity sensor-Failure - C',
#  'Organizational issues-Development-Selection/certification/testing-Document/info verification-FAA/Regulator - C',
#  'Organizational issues-Support/oversight/monitoring-Training-(general)-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-(general)-Effect on equipment',
#  'Aircraft-Aircraft power plant-Turbocharging (recip only)-(general)-Incorrect service/maintenance - C',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of geographic area-Pilot - C',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Ground crew',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-FAA or designated personnel - F',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Not inspected - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Not specified',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Incorrect use/operation',
#  'Aircraft-Aircraft structures-(general)-(general)-Capability exceeded',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway lighting-Effect on operation - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Capability exceeded',
#  'Aircraft-Aircraft handling/service-Loading-(general)-Incorrect use/operation',
#  'Environmental issues-Operating environment-Airport facilities/design-Security-Contributed to outcome - C',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Not installed/available',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Incorrect use/operation - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Not specified - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Incorrect service/maintenance',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Not inspected - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Effect on operation',
#  'Aircraft-Aircraft structures-Empennage structure-Horizontal stabilizer-Incorrect service/maintenance - F',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Ground crew - F',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Braking capability-Malfunction',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Related operating info - F',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-Ground crew - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general)-Contributed to outcome - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Related operating info - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-(general)-Attain/maintain not possible',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Pilot of other aircraft - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Malfunction - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Pilot of other aircraft - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Not specified',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Qualification/certification-Student pilot',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-Personnel records-Not specified',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Instrument panel-Malfunction - C',
#  'Aircraft-Aircraft systems-Electrical power system-External power system-Incorrect use/operation - C',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general)-Not specified',
#  'Personnel issues-Physical-Alertness/Fatigue-Fatigue due to work schedule-Flight crew - F',
#  'Environmental issues-Operating environment-Approach aid coverage/avail-(general)-Use of related info - F',
#  'Aircraft-Aircraft systems-Electrical power system-DC generation system-Malfunction',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Other/unknown - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-(general)-Incorrect use/operation',
#  'Aircraft-Aircraft systems-Air conditioning system-Pressurization control system-Not used/operated - C',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Cabin crew - F',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Ground crew',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Angle of attack-Related operating info',
#  'Aircraft-Aircraft structures-Windows-windshield system-Flight compartment windows-Incorrect service/maintenance',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Effect on operation - F',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent experience-Student pilot',
#  'Aircraft-Aircraft structures-Windows-windshield system-Flight compartment windows-Unintentional use/operation - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel flow sensor-Incorrect use/operation - F',
#  'Personnel issues-Task performance-Inspection-Scheduled/routine inspection-Owner/builder - C',
#  'Personnel issues-Physical-Health/Fitness-(general)-Pilot - F',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Equipment monitoring-Manufacturer',
#  'Aircraft-Aircraft structures-Empennage structure-Ventral struc (on vert stab)-Not specified',
#  'Personnel issues-Experience/knowledge-Training-(general)-Pilot - F',
#  'Environmental issues-Operating environment-Communication system-VHF/HF radio-Compliance w/ procedure - C',
#  'Environmental issues-Physical environment-Terrain-Water-Awareness of condition',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Compressor section-Failure',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-(general)-Availability of related info',
#  'Environmental issues-Operating environment-Airport facilities/design-Ramp facilities-Effect on operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Snow/ice-Ability to respond/compensate - C',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Not specified - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Damaged/degraded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Decision related to condition - C',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-Tail rotor drive shaft-Failure - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Prop/rotor parameters-Incorrect use/operation - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Copilot - C',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Design',
#  'Environmental issues-Physical environment-Object/animal/substance-Person-Effect on operation - C',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Pilot of other aircraft - C',
#  'Organizational issues-Management-Policy/procedure-(general)-Operator',
#  'Aircraft-Aircraft power plant-Turbocharging (recip only)-Turbocharger-Incorrect service/maintenance - C',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Flight crew - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Airport structure-Ability to respond/compensate',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Inadequate inspection - C',
# ...
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on personnel',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pressure-Damaged/degraded - C',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Pilot',
#  'Aircraft-Aircraft structures-Wing structure-Ribs/bulkheads (on wing)-Damaged/degraded',
#  'Organizational issues-Development-Design-Design of document/info-Operator - F',
#  'Personnel issues-Physical-Health/Fitness-Physical fitness-Pilot - C',
#  'Aircraft-Aircraft power plant-Power plant-(general)-Unintentional use/operation',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of equipment-Student pilot - F',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy-Awareness of condition',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Incorrect use/operation - C',
#  'Personnel issues-Action/decision-Action-Forgotten action/omission-Maintenance personnel - F',
#  'Organizational issues-Development-Selection/certification/testing-Equip certification/testing-Manufacturer',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Capability exceeded - F',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Fluid condition - F',
#  'Personnel issues-Physical-Impairment/incapacitation-(general)-Pilot',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-Eng oil dist (airframe furn)-Damaged/degraded - C',
#  'Personnel issues-Psychological-Mental/emotional state-Confusion-Pilot',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Student/instructed pilot - C',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Wake turbulence-Contributed to outcome - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Incorrect use/operation - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Glassy surface-Effect on personnel - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Takeoff distance-Related operating info',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Response/compensation - C',
#  'Environmental issues-Physical environment-Terrain-High elevation-Contributed to outcome',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Prop/rotor parameters-Attain/maintain not possible - F',
#  'Personnel issues-Action/decision-Action-Incomplete action-Other/unknown - C',
#  'Environmental issues-Physical environment-Terrain-(general)-Effect on operation - C',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of geographic area-Pilot',
#  'Aircraft-Aircraft systems-Air conditioning system-Cooling sys (air/vapor cycle)-Failure - F',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-(general)-Not specified - F',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Related operating info - C',
#  'Personnel issues-Miscellaneous-(general)-(general)-ATC personnel',
#  'Aircraft-Aircraft power plant-Engine exhaust-Thrust reverser-Design',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Capability exceeded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Low ceiling-Not specified - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Not specified - F',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Incorrect service/maintenance - F',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Visual illusion/disorientation-Pilot - F',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Inadequate inspection - F',
#  'Personnel issues-Physical-Health/Fitness-Use of medication/drugs-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-(general)-Effect on personnel - F',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Incorrect use/operation - C',
#  'Personnel issues-Task performance-Planning/preparation-Flight planning/navigation-Pilot - F',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Incorrect use/operation - F',
#  'Aircraft-Aircraft systems-Landing gear system-Master cylinder/brake valve-Malfunction - F',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Incorrect service/maintenance',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Design - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Malfunction',
#  'Personnel issues-Psychological-Attention/monitoring-(general)-Other/unknown - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Unknown/Not determined',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-(general)-Incorrect service/maintenance',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway markings/signage-Contributed to outcome',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Powerplant parameters-Not attained/maintained',
#  'Environmental issues-Physical environment-Terrain-Mountainous/hilly terrain-Ability to respond/compensate - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Low visibility-Accuracy of related info',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Failure',
#  'Environmental issues-Physical environment-Terrain-Water-Effect on equipment - C',
#  'Environmental issues-Physical environment-Object/animal/substance-(general)-Effect on operation - C',
#  'Personnel issues-Task performance-Maintenance-(general)-Owner/builder - C',
#  'Organizational issues-Support/oversight/monitoring-Training-Recurrent training-FAA/Regulator - F',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring environment-Pilot - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Pilot of other aircraft - C',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Inoperative - C',
#  'Environmental issues-Physical environment-Terrain-Water-Not specified',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Configuration-Incorrect use/operation - C',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Passenger - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of charts-Pilot - F',
#  'Personnel issues-Task performance-Planning/preparation-Flight planning/navigation-Not specified - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Awareness of condition - C',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Intake anti-ice, deice-Not used/operated - C',
#  'Aircraft-Aircraft structures-Nacelles/pylons structure-Main frame (on nacelles/pylon)-Fatigue/wear/corrosion - C',
#  'Personnel issues-Action/decision-Action-Unnecessary action-Pilot',
#  'Personnel issues-Task performance-Record-keeping-Aircraft/maintenance logs-Pilot - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Failure - C',
#  'Aircraft-Aircraft systems-Flight control system-Elevator tab control system-Incorrect use/operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear steering system-Inoperative - C',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Student pilot - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Capability exceeded - C',
#  'Aircraft-Aircraft structures-Nacelles/pylons structure-(general)-Not specified - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general)-Not serviced/maintained - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Contributed to outcome - F',
#  'Personnel issues-Action/decision-Action-Incomplete action-Student/instructed pilot - C',
#  'Personnel issues-Task performance-Maintenance-(general)-Not specified - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear/wheel fairing-Not serviced/maintained',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Compressor bleed control-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Failure - C',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Other/unknown',
#  'Aircraft-Aircraft power plant-Engine starting-Cranking-Incorrect use/operation - C',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Accuracy of related info - F',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Flight crew - C',
#  'Organizational issues-Management-Resources-Adequacy of equipment-Operator',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Effect on operation - F',
#  'Personnel issues-Task performance-Planning/preparation-Performance calculations-Pilot',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-FAA or designated personnel',
#  'Environmental issues-Task environment-Physical workspace-Air quality/dust/smoke-Effect on operation - C',
#  'Aircraft-Aircraft structures-Wing structure-Trailing edge flaps-Incorrect use/operation',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation - F',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Dark-Contributed to outcome',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Climb rate-Not attained/maintained',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Damaged/degraded - C',
#  'Aircraft-Aircraft structures-(general)-(general)-Inadequate inspection - C',
#  'Personnel issues-Task performance-Planning/preparation-(general)-Pilot',
#  'Aircraft-Aircraft systems-Flight control system-Gust lock or damper-Unintentional use/operation - C',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Maintenance personnel - F',
#  'Personnel issues-Physical-Sensory ability/limitation-Visual function-Pilot',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Instrument panel   -Not specified - C',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Flight crew - C',
#  'Environmental issues-Task environment-Physical workspace-Vibration-Ability to respond/compensate',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control electronic-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pressure-Failure - C',
#  'Aircraft-Aircraft structures-(general)-(general)-Inadequate inspection',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Wake turbulence-Effect on equipment - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Design - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Not inspected',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Incorrect use/operation - F',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Unintentional use/operation - C',
#  'Personnel issues-Physical-Impairment/incapacitation-Prescription medication-Student/instructed pilot - C',
#  'Personnel issues-Action/decision-Info processing/decision-(general)-Student pilot - C',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-Tail rotor drive shaft-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Damaged/degraded',
#  'Personnel issues-Task performance-(general)-(general)-Owner/builder - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-(general)-Incorrect service/maintenance - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Pilot - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Wet-Effect on operation - C',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Incorrect service/maintenance - F',
#  'Personnel issues-Task performance-Record-keeping-Aircraft/maintenance logs-Maintenance personnel',
#  'Aircraft-Aircraft systems-Navigation system-Pitot/static system-Inoperative',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Use of related info',
#  'Aircraft-Aircraft structures-Fuselage-Gear attach fittings (on fus)-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Parachute-Failure - C',
#  'Environmental issues-Conditions/weather/phenomena-(general)-(general)-Decision related to condition - F',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Flight control system-Gust lock or damper-Not inspected - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity sensor-Fatigue/wear/corrosion - F',
#  'Aircraft-Aircraft power plant-Engine exhaust-(general)-Not specified',
#  'Personnel issues-Physical-Sensory ability/limitation-Hearing-Pilot - F',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Capability exceeded - C',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Effect on personnel - C',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-Tail rotor gearbox-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Climb rate-Incorrect use/operation - C',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Flight service personnel - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Turbine governor-Damaged/degraded - C',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Owner/builder - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Decision related to condition - C',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Hoses and tubes-Incorrect service/maintenance',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Fatigue/wear/corrosion - C',
#  'Personnel issues-Action/decision-Info processing/decision-(general)-Flight crew',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Malfunction',
#  'Aircraft-Aircraft structures-Windows-windshield system-(general)-Damaged/degraded - F',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Not specified - C',
#  'Personnel issues-Physical-Impairment/incapacitation-OTC medication-Student/instructed pilot - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng liquid cooling-Malfunction',
#  'Aircraft-Aircraft power plant-Power plant-Powerplant wiring-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Haze/smoke-Effect on personnel',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Not inspected - C',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Flight control system-Elevator tab control system-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Failure',
#  'Aircraft-Aircraft systems-Fuel system-Fuel transfer valve-Incorrect use/operation - C',
#  'Organizational issues-Management-Resources-Availability of personnel-Operator',
#  ...]

# %%
findings_ls[0].replace('- C', '')
# Out:
# 'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Attain/maintain not possible '

# %%
len(findings_ls)
# Out:
# 6163

# %%
findings_ls_ver1 = []
for finding in findings_ls:
    if re.split('-', finding)[-1] == ' C':
        finding = finding.replace('- C', '')
    if re.split('-', finding)[-1] == ' F':
        finding = finding.replace('- F', '')
    findings_ls_ver1.append(finding)

# %%
len(findings_ls_ver1)
# Out:
# 6163

# %%
finding = findings_ls_ver1[9]
finding = finding.replace('-(general)', '', 1)
ix = finding.find('(general)')
ls = re.split('-', finding[ix:])
# finding[0:ix] + ls[0] + ' ' + ls[1]
# what if there's more than one word after the (general) word?
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 5
#       3 ix = finding.find('(general)')
#       4 ls = re.split('-', finding[ix:])
# ----> 5 finding[0:ix] + ls[0] + ' ' + ls[1]
#       6 # what if there's more than one word after the (general) word?
#
# IndexError: list index out of range

# %%
# Locate all of the (general) options and instead combine it with the next part
findings_ls_ver2 = []
for finding in findings_ls_ver1:
    if '(general)' in finding:
        if finding.count('(general)') == 1:
            # know which specific index the 'general' is in and recreate the previous format
            ix = finding.find('(general)')
            ls = re.split('-', finding[ix:])
            if len(ls) == 2:
                finding = finding[0:ix] + ls[0] + ' ' + ls[1] # finding = before (general) + (general) + rest of the finding
            else:
                print(finding, '- Recheck')
        else:
            # what if (general) occurs more than once? Remove one of the instances and repeat the same process as above
            finding = finding.replace('-(general)', '', 1)
            ix = finding.find('(general)')
            ls = re.split('-', finding[ix:])
            if len(ls) == 2:
                finding = finding[0:ix] + ls[0] + ' ' + ls[1] # finding = before (general) + (general) + rest of the finding
            else:
                print(finding, '- Recheck')
    findings_ls_ver2.append(finding)

# %%
findings_ls_ver2
# Out:
# ['Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Attain/maintain not possible ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Awareness of condition ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Combustion section-Not serviced/maintained',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Failure ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Capability exceeded',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Damaged/degraded ',
#  'Aircraft-Aircraft power plant-Ignition system-Switching-Unintentional use/operation ',
#  'Personnel issues-Task performance-Maintenance-(general) Maintenance personnel ',
#  'Aircraft-Aircraft systems-Fuel system-(general) Incorrect use/operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Effect on equipment ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Inadequate inspection ',
#  'Aircraft-Aircraft power plant-Engine indicating system-Power indicating system-Failure ',
#  'Aircraft-Aircraft power plant-Power plant-Engine cowling system-Capability exceeded',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity sensor-Malfunction ',
#  'Aircraft-Aircraft systems-Flight control system-Rudder actuator-Failure',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller hub section-Incorrect service/maintenance ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Not specified',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Not serviced/maintained',
#  'Aircraft-Aircraft structures-Empennage structure-(general) Failure',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Ground crew ',
#  'Personnel issues-Action/decision-Action-Lack of action-Maintenance personnel ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general) Capability exceeded',
#  'Aircraft-Aircraft systems-Oxygen system-(general) Inadequate inspection ',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general) Failure',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Flight crew',
#  'Aircraft-Aircraft systems-Navigation system-Ground proximity system-Capability exceeded',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity indicator-Failure ',
#  'Aircraft-Aircraft power plant-Accessory gear-boxes-(general) Not serviced/maintained ',
#  'Aircraft-Aircraft systems-Navigation system-Flight environment data-Not serviced/maintained ',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Not installed/available ',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Flt operations/dispatcher ',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Awareness of condition ',
#  'Personnel issues-Task performance-(general) ATC personnel ',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Capability exceeded',
#  'Organizational issues-Management-Resources-(general) Manufacturer',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Other/unknown ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Powerplant parameters-Incorrect use/operation',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Pilot',
#  'Personnel issues-Physical-Sensory ability/limitation-Visual function-Ground crew ',
#  'Environmental issues-Task environment-Pressures/demands-Other pressure/demand-Decision related to condition',
#  'Personnel issues-Psychological-Personality/attitude-Self confidence-Pilot ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring equip/instruments-Flight crew ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Incorrect use/operation',
#  'Aircraft-Aircraft structures-Wing structure-Spar (on wing)-Failure ',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Instructor/check pilot',
#  'Aircraft-Aircraft structures-(general) Not used/operated ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Agricultural/external load sys-Unintentional use/operation ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Glassy-Effect on operation ',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-Maintenance records-Operator ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Not specified ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Failure',
#  'Environmental issues-Task environment-Physical workspace-Visibility-Contributed to outcome',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Not specified ',
#  'Environmental issues-Operating environment-Approach aid coverage/avail-Approach lighting-Not specified',
#  'Aircraft-Aircraft power plant-(general) Not specified ',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Pilot of other aircraft ',
#  'Personnel issues-Action/decision-Action-Delayed action-Instructor/check pilot ',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Not specified ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Engine out capability-Not attained/maintained ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Drizzle/mist-Effect on operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Runway/taxi/approach light-Contributed to outcome ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Oil system-Inoperative',
#  'Personnel issues-Task performance-Planning/preparation-Weight/balance calculations-Pilot',
#  'Personnel issues-Task performance-Communication (personnel)-Issuing instructions-ATC personnel ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Not serviced/maintained ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Attain/maintain not possible',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Not inspected ',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Incorrect service/maintenance',
#  'Personnel issues-Psychological-Attention/monitoring-Attention-Student pilot ',
#  'Aircraft-Aircraft power plant-Engine indicating system-Engine indication sys wiring-Damaged/degraded',
#  'Not determined-Not determined-(general) Unknown/Not determined',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Design',
#  'Aircraft-Aircraft structures-Empennage structure-Horizontal stabilizer-Incorrect service/maintenance ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Not specified',
#  'Aircraft-Aircraft structures-Wing structure-Fus (attach fitting on wing)-Inadequate inspection',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Incorrect service/maintenance ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High density altitude-Response/compensation ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Ability to respond/compensate',
#  'Personnel issues-Task performance-Planning/preparation-Fuel planning-Flight crew ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered-Awareness of condition ',
#  'Aircraft-Aircraft systems-Electrical power system-(general) Not specified',
#  'Environmental issues-Task environment-Physical workspace-Vibration-Effect on operation',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Contributed to outcome ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Malfunction',
#  'Aircraft-Aircraft power plant-Power plant-Engine cowling system-Failure',
#  'Personnel issues-Action/decision-Action-Lack of action-Flight crew ',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Adequacy of safety program-Emergency services',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Adequacy of safety program-Other government',
#  'Aircraft-Aircraft structures-Empennage structure-Elevator/tab attach fitting-Incorrect service/maintenance ',
#  'Personnel issues-Task performance-Maintenance-Modification/alteration-Student/instructed pilot',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Malfunction ',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Malfunction ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Rotor/drive indicating system-Unknown/Not determined',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Fatigue/wear/corrosion ',
#  'Environmental issues-Physical environment-Terrain-Mountainous/hilly terrain-Awareness of condition',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Inadequate inspection ',
#  'Personnel issues-Action/decision-Action-(general) Student pilot ',
#  'Aircraft-Aircraft structures-Wing structure-Main frame (on wing)-Failure',
#  'Aircraft-Aircraft structures-Fuselage-Frames (main fuselage)-Inadequate inspection ',
#  'Environmental issues-Physical environment-Object/animal/substance-Sign/marker-Not specified',
#  'Aircraft-Aircraft structures-Fuselage-Gear attach fittings (on fus)-Inadequate inspection ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-(general) Not specified ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng liquid cooling-Malfunction ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Incorrect use/operation ',
#  'Environmental issues-Task environment-Pressures/demands-Equipment/operational-Effect on personnel ',
#  'Aircraft-Aircraft power plant-Power plant-Eng air baffle sec (recip.)-Incorrect service/maintenance ',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Response/compensation ',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway markings/signage-Decision related to condition ',
#  'Aircraft-Aircraft power plant-Power plant-Engine cowling system-Incorrect use/operation',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Capability exceeded ',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general) Design',
#  'Aircraft-Aircraft structures-Wing structure-Flight surfaces (wing)-Incorrect service/maintenance ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on equipment ',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Other/unknown',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Student pilot ',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Owner/builder ',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general) Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Electrical power system-DC regulator-Failure ',
#  'Aircraft-Aircraft power plant-Power plant-(general) Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft handling/service-Towing and taxiing-Taxiing-Incorrect use/operation ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Not serviced/maintained',
#  'Personnel issues-Task performance-Communication (personnel)-(general) Pilot of other aircraft',
#  'Personnel issues-Psychological-Personality/attitude-Complacency-Student/instructed pilot',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Dark-Ability to respond/compensate ',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Ground crew ',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven-Effect on equipment ',
#  'Personnel issues-Psychological-Personality/attitude-Motivation/respond to pressure-Pilot',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-Eng oil dist (airframe furn)-Inadequate inspection',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-(general) Decision related to condition ',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Damaged/degraded ',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy terrain-Effect on equipment',
#  'Personnel issues-Psychological-Mental/emotional state-Stress-Pilot ',
#  'Personnel issues-Action/decision-Action-Forgotten action/omission-Flight crew ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Terrain induced turbulence-Effect on operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Effect on operation ',
#  'Environmental issues-Physical environment-Object/animal/substance-Tower/antenna (incl guy wires)-Contributed to outcome ',
#  'Aircraft-Aircraft systems-(general) Malfunction ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Incorrect use/operation ',
#  'Environmental issues-Operating environment-(general) Contributed to outcome ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Not serviced/maintained',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Effect on equipment',
#  'Personnel issues-Action/decision-Action-(general) Flight crew ',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Awareness of condition ',
#  'Aircraft-Aircraft structures-Doors-Landing gear doors-Related maintenance info ',
#  'Aircraft-Aircraft structures-Wing structure-Trailing edge flaps-Not used/operated ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller feather/reversing-Not specified ',
#  'Personnel issues-Task performance-Communication (personnel)-Interpretation/understanding-Student/instructed pilot ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-(general) Pilot ',
#  'Aircraft-Aircraft power plant-Ignition system-Ignition power supply-Malfunction ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Bright light-Effect on personnel',
#  'Aircraft-Aircraft power plant-Turbocharging (recip only)-(general) Fatigue/wear/corrosion',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Fatigue/wear/corrosion ',
#  'Environmental issues-Operating environment-Airport facilities/design-(general) Awareness of condition ',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Damaged/degraded ',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Not specified',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Emergency locator beacon-Not specified',
#  'Aircraft-Aircraft structures-Doors-Emergency exit-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Inadequate inspection ',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Failure',
#  'Aircraft-Aircraft systems-Landing gear system-(general) Unintentional use/operation ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general) Contributed to outcome ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general) Not attained/maintained ',
#  'Aircraft-Aircraft systems-Electrical power system-DC generator-alternator-Failure',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Failure ',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Student pilot ',
#  'Personnel issues-Task performance-(general) Pilot ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Oil system-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Oil system-Damaged/degraded ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general) Response/compensation ',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Flight crew',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Not specified ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general) Effect on personnel',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Related operating info ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Damaged/degraded',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Fasteners-Not serviced/maintained ',
#  'Personnel issues-Task performance-Maintenance-Modification/alteration-Maintenance personnel ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Inoperative',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Effect on equipment',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear attach section-Capability exceeded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Clouds-Not specified',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Adequacy of safety program-Other institution/organization ',
#  'Personnel issues-Physical-Alertness/Fatigue-Lack of sleep-Flight crew ',
#  'Environmental issues-Task environment-(general) Effect on equipment ',
#  'Environmental issues-Physical environment-Terrain-Rough terrain-Contributed to outcome ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Flight compartment equipment-Not installed/available ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Malfunction ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Incorrect service/maintenance',
#  'Aircraft-Fluids/misc hardware-Fluids-Oil-Not serviced/maintained ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below approach minima-Decision related to condition ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Effect on personnel ',
#  'Aircraft-Aircraft systems-Landing gear system-Wheel/ski/float-Capability exceeded ',
#  'Environmental issues-Physical environment-Terrain-Rough terrain-Awareness of condition ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Flat light-Effect on operation ',
#  'Personnel issues-Psychological-Attention/monitoring-(general) Pilot ',
#  'Aircraft-Aircraft systems-Electrical power system-AC power distribution system-Malfunction ',
#  'Aircraft-Aircraft power plant-(general) Malfunction',
#  'Environmental issues-Operating environment-Communication system-(general) Contributed to outcome ',
#  'Personnel issues-Action/decision-Action-Lack of action-Designated examiner ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Failure',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Student/instructed pilot',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Incorrect use/operation ',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Not specified ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Not specified ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general) Effect on operation ',
#  'Personnel issues-Physical-Health/Fitness-Predisposing condition-Pilot',
#  'Personnel issues-Task performance-Maintenance-Installation-Other/unknown',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Effect on operation ',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Not serviced/maintained ',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Fasteners-Not specified ',
#  'Aircraft-Aircraft power plant-(general) Damaged/degraded',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Not specified',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Not specified',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Oil system-Not specified',
#  'Aircraft-Aircraft structures-Wing structure-Ailerons-Damaged/degraded ',
#  'Aircraft-Aircraft systems-Hydraulic power system-(general) Malfunction ',
#  'Aircraft-Aircraft systems-Landing gear system-(general) Not specified ',
#  'Aircraft-Aircraft systems-Landing gear system-(general) Unintentional use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Related operating info ',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of meteorologic cond-Pilot',
#  'Personnel issues-Action/decision-Action-Delayed action-Instructor/check pilot ',
#  'Aircraft-Aircraft systems-Fuel system-(general) Inadequate inspection ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-(general) Damaged/degraded ',
#  'Personnel issues-Task performance-Communication (personnel)-Accuracy of communication-Other/unknown ',
#  'Personnel issues-Physical-Alertness/Fatigue-(general) Pilot',
#  'Aircraft-Aircraft systems-Oxygen system-Crew oxygen system-Not used/operated ',
#  'Aircraft-Aircraft systems-Flight control system-Rudder tab control system-Unintentional use/operation ',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Engine anti-icing system-Malfunction ',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Fasteners-Incorrect service/maintenance',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-Maintenance records-Manufacturer',
#  'Personnel issues-Task performance-Planning/preparation-Performance calculations-Pilot ',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Passenger ',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic pattern procedure-Contributed to outcome ',
#  'Aircraft-Aircraft structures-Empennage structure-Horizontal stabilizer-Damaged/degraded',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Incorrect service/maintenance ',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Pilot ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Wet surface-Effect on operation ',
#  'Aircraft-Aircraft systems-Electrical power system-DC power distribution system-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft power plant-Power plant-(general) Damaged/degraded ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear selector-Inoperative',
#  'Personnel issues-Action/decision-Action-Lack of action-Maintenance personnel',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Spatial disorientation-Pilot ',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Incorrect service/maintenance',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Incorrect use/operation ',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Adequacy of safety program-FAA/Regulator ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Inadequate inspection',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-ATC personnel ',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Hoses and tubes-Incorrect service/maintenance ',
#  'Personnel issues-Task performance-Communication (personnel)-Accuracy of communication-Pilot ',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Ability to respond/compensate ',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Incorrect use/operation',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Climb capability-Not specified ',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Passenger ',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Flight crew',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Geographic disorient (lost)-Pilot ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring equip/instruments-Instructor/check pilot ',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Incorrect service/maintenance ',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Flight crew ',
#  'Aircraft-Aircraft propeller/rotor-(general) Damaged/degraded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Obscuration-Effect on operation ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Effect on equipment',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-ATC personnel',
#  'Aircraft-Aircraft power plant-Engine starting-(general) Unintentional use/operation',
#  'Environmental issues-Physical environment-Object/animal/substance-(general) Effect on operation',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Maintenance personnel ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Effect on equipment ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel oil cooler-Incorrect service/maintenance',
#  'Environmental issues-Operating environment-Airport facilities/design-Taxiway markings/signage-Availability of related info ',
#  'Aircraft-Aircraft structures-(general) Fatigue/wear/corrosion',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general) Not specified ',
#  'Aircraft-Aircraft systems-Navigation system-Pitot/static system-Inadequate inspection',
#  'Organizational issues-Development-Design-Policy/procedure development-Airport ',
#  'Personnel issues-Task performance-Workload management-Task allocation-Pilot ',
#  'Personnel issues-Physical-Alertness/Fatigue-Fatigue due to work schedule-Instructor/check pilot',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent rate-Capability exceeded ',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Related maintenance info ',
#  'Environmental issues-Physical environment-Object/animal/substance-Debris/dirt/foreign object-Decision related to condition',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Malfunction ',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general) Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Hydraulic power system-Pump, main-Incorrect service/maintenance',
#  'Aircraft-Fluids/misc hardware-Fluids-Oil-Unknown/Not determined',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general) Decision related to condition ',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Contributed to outcome ',
#  'Personnel issues-Action/decision-Action-Incomplete action-Pilot ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-(general) Failure ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Contributed to outcome ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Malfunction ',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Failure ',
#  'Personnel issues-Task performance-Use of equip/info-Use of manual-Instructor/check pilot ',
#  'Personnel issues-Physical-Impairment/incapacitation-Cardiovascular-Pilot',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Student/instructed pilot',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Pilot ',
#  'Environmental issues-Operating environment-Air traffic/operating proc-ATC clearance procedure-Effect on operation ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor-(general) Damaged/degraded',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Inoperative ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered-Effect on equipment ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Damaged/degraded ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Failure ',
#  'Personnel issues-Miscellaneous-Intentional act-(general) Not specified ',
#  'Personnel issues-Task performance-(general) Maintenance personnel ',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Capability exceeded',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Contributed to outcome',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Flight crew ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Not serviced/maintained ',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Student pilot ',
#  'Personnel issues-Psychological-Personality/attitude-(general) Pilot',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel controlling system-Malfunction',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Inadequate inspection',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High temperature-Effect on operation',
#  'Aircraft-Aircraft structures-Wing structure-Spar (on wing)-Fatigue/wear/corrosion ',
#  'Environmental issues-Physical environment-Object/animal/substance-Runway/taxi/approach light-Decision related to condition',
#  'Organizational issues-Support/oversight/monitoring-Training-Initial training-ATC ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Unnecessary use/operation ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Windshear-Effect on operation ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Obscuration-Effect on operation ',
#  'Aircraft-Aircraft systems-Landing gear system-(general) Malfunction ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Ability to respond/compensate ',
#  'Aircraft-Aircraft systems-Landing gear system-Steering unit-Not specified',
#  'Aircraft-Aircraft systems-Equipment/furnishings-(general) Not specified',
#  'Personnel issues-Task performance-Planning/preparation-(general) Flight crew ',
#  'Aircraft-Aircraft power plant-Ignition system-Switching-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Inadequate inspection',
#  'Environmental issues-Operating environment-(general) Effect on personnel',
#  'Environmental issues-Physical environment-Object/animal/substance-Snow/ice-Contributed to outcome ',
#  'Personnel issues-Task performance-Maintenance-Repair-Pilot ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Whiteout-Effect on personnel ',
#  'Environmental issues-Task environment-Pressures/demands-Time/schedule pressure-Decision related to condition ',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Response/compensation',
#  'Environmental issues-Task environment-Physical workspace-Air quality/dust/smoke-Decision related to condition ',
#  'Personnel issues-Action/decision-Action-(general) Ground crew ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng supercharger-Capability exceeded ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Yaw control-Not attained/maintained ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Malfunction ',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Pilot ',
#  'Aircraft-Aircraft oper/perf/capability-(general) Attain/maintain not possible ',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Malfunction ',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Inoperative ',
#  'Aircraft-Aircraft structures-Empennage structure-Vertical stab attach fitting-Failure ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Incorrect use/operation ',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Not specified ',
#  'Aircraft-Aircraft power plant-Ignition system-(general) Incorrect use/operation ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Design ',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general) Damaged/degraded ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Soft-Decision related to condition ',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Not specified ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-CG/weight distribution-Not attained/maintained',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Capability exceeded ',
#  'Personnel issues-Action/decision-Action-Unneccessary action-Passenger ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Climb rate-Capability exceeded',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general) Not specified ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general) Not specified ',
#  'Personnel issues-Task performance-Maintenance-Installation-Maintenance personnel ',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Passenger ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Not attained/maintained ',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Not specified ',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Tail rotor control system-Not specified ',
#  'Aircraft-Aircraft systems-Navigation system-Directional gyro & indication-Failure ',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Airport personnel ',
#  'Personnel issues-Physical-Impairment/incapacitation-Prescription medication-Pilot of other aircraft ',
#  'Environmental issues-Operating environment-Airport facilities/design-Snow removal service/equipment-Contributed to outcome',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on operation',
#  'Environmental issues-Operating environment-Airport facilities/design-(general) Effect on operation',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience w/ equipment-Copilot ',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Malfunction',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Owner/builder ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general) Effect on operation ',
#  'Environmental issues-Operating environment-Airport facilities/design-Ground support/equipment-Not specified',
#  'Aircraft-Aircraft handling/service-Parking/securing-Tie-down/mooring-Not specified ',
#  'Aircraft-Aircraft systems-(general) Malfunction',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Not specified',
#  'Personnel issues-Task performance-Communication (personnel)-Interpretation/understanding-Pilot ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Malfunction ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Engine out control-Not attained/maintained ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Incorrect service/maintenance ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Terrain induced turbulence-Ability to respond/compensate',
#  'Personnel issues-Task performance-Maintenance-Scheduled/routine maintenance-Owner/builder ',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Not used/operated ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel divider-Incorrect service/maintenance ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Ability to respond/compensate',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Student/instructed pilot',
#  'Environmental issues-Physical environment-Object/animal/substance-Debris/dirt/foreign object-Ability to respond/compensate',
#  'Aircraft-Aircraft power plant-(general) Incorrect service/maintenance ',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Contributed to outcome',
#  'Personnel issues-Physical-Impairment/incapacitation-Prescription medication-Student pilot ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Wet surface-Effect on operation',
#  'Personnel issues-Task performance-Maintenance-(general) Other/unknown ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Prop/spinner section-Unknown/Not determined',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Takeoff distance-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine controls-Eng cntl sys wiring-Fatigue/wear/corrosion ',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Flight crew ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity indicator-Related operating info ',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-(general) FAA/Regulator',
#  'Personnel issues-Psychological-Personality/attitude-Motivation/respond to pressure-Pilot ',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Decision related to condition ',
#  'Organizational issues-Support/oversight/monitoring-Training-Emergency proc training-FAA/Regulator',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent/approach/glide path-Related operating info ',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Failure ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Failure ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Incorrect use/operation',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Incorrect service/maintenance ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-Main rotor blade system-Not serviced/maintained ',
#  'Environmental issues-Task environment-Pressures/demands-Time/schedule pressure-Decision related to condition',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Data recorders (flight/maint)-Capability exceeded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Effect on operation ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Contributed to outcome ',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Unintentional use/operation ',
#  'Aircraft-Aircraft structures-Windows-windshield system-(general) Damaged/degraded',
#  'Aircraft-Aircraft power plant-Engine fuel and control-(general) Incorrect use/operation ',
#  'Aircraft-Aircraft handling/service-Placards and markings-(general) Not installed/available ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-(general) Pilot',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity sensor-Failure ',
#  'Organizational issues-Development-Selection/certification/testing-Document/info verification-FAA/Regulator ',
#  'Organizational issues-Support/oversight/monitoring-Training-(general) Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-(general) Effect on equipment',
#  'Aircraft-Aircraft power plant-Turbocharging (recip only)-(general) Incorrect service/maintenance ',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of geographic area-Pilot ',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Ground crew',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-FAA or designated personnel ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Not inspected ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Not specified',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Incorrect use/operation',
#  'Aircraft-Aircraft structures-(general) Capability exceeded',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway lighting-Effect on operation ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Capability exceeded',
#  'Aircraft-Aircraft handling/service-Loading-(general) Incorrect use/operation',
#  'Environmental issues-Operating environment-Airport facilities/design-Security-Contributed to outcome ',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Not installed/available',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Incorrect use/operation ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Not specified ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Incorrect service/maintenance',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Not inspected ',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Effect on operation',
#  'Aircraft-Aircraft structures-Empennage structure-Horizontal stabilizer-Incorrect service/maintenance ',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Ground crew ',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Incorrect service/maintenance ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Braking capability-Malfunction',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Related operating info ',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-Ground crew ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general) Contributed to outcome ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Related operating info ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-(general) Attain/maintain not possible',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Pilot of other aircraft ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Malfunction ',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Pilot of other aircraft ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Not specified',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Qualification/certification-Student pilot',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-Personnel records-Not specified',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Instrument panel-Malfunction ',
#  'Aircraft-Aircraft systems-Electrical power system-External power system-Incorrect use/operation ',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general) Not specified',
#  'Personnel issues-Physical-Alertness/Fatigue-Fatigue due to work schedule-Flight crew ',
#  'Environmental issues-Operating environment-Approach aid coverage/avail-(general) Use of related info ',
#  'Aircraft-Aircraft systems-Electrical power system-DC generation system-Malfunction',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Other/unknown ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-(general) Incorrect use/operation',
#  'Aircraft-Aircraft systems-Air conditioning system-Pressurization control system-Not used/operated ',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Cabin crew ',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Ground crew',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Angle of attack-Related operating info',
#  'Aircraft-Aircraft structures-Windows-windshield system-Flight compartment windows-Incorrect service/maintenance',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Effect on operation ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent experience-Student pilot',
#  'Aircraft-Aircraft structures-Windows-windshield system-Flight compartment windows-Unintentional use/operation ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel flow sensor-Incorrect use/operation ',
#  'Personnel issues-Task performance-Inspection-Scheduled/routine inspection-Owner/builder ',
#  'Personnel issues-Physical-Health/Fitness-(general) Pilot ',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Equipment monitoring-Manufacturer',
#  'Aircraft-Aircraft structures-Empennage structure-Ventral struc (on vert stab)-Not specified',
#  'Personnel issues-Experience/knowledge-Training-(general) Pilot ',
#  'Environmental issues-Operating environment-Communication system-VHF/HF radio-Compliance w/ procedure ',
#  'Environmental issues-Physical environment-Terrain-Water-Awareness of condition',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Compressor section-Failure',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-(general) Availability of related info',
#  'Environmental issues-Operating environment-Airport facilities/design-Ramp facilities-Effect on operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Snow/ice-Ability to respond/compensate ',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Not specified ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Damaged/degraded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Decision related to condition ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-Tail rotor drive shaft-Failure ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Prop/rotor parameters-Incorrect use/operation ',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Copilot ',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Design',
#  'Environmental issues-Physical environment-Object/animal/substance-Person-Effect on operation ',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Pilot of other aircraft ',
#  'Organizational issues-Management-Policy/procedure-(general) Operator',
#  'Aircraft-Aircraft power plant-Turbocharging (recip only)-Turbocharger-Incorrect service/maintenance ',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Flight crew ',
#  'Environmental issues-Physical environment-Object/animal/substance-Airport structure-Ability to respond/compensate',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Inadequate inspection ',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Spatial disorientation-Student/instructed pilot',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general) Incorrect service/maintenance',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway/landing area length-Awareness of condition ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Response/compensation',
#  'Organizational issues-Management-Culture-Pressures/demands-Other institution/organization ',
#  'Personnel issues-Task performance-(general) Other/unknown ',
#  'Aircraft-Aircraft handling/service-Loading-(general) Not serviced/maintained ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller hub section-Capability exceeded',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Inoperative',
#  'Aircraft-Aircraft systems-Flight control system-(general) Not specified',
#  'Environmental issues-Physical environment-Object/animal/substance-(general) Contributed to outcome ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-(general) Effect on operation ',
# ...
#  'Personnel issues-Task performance-Communication (personnel)-(general) Instructor/check pilot',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Unknown/Not determined',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Contributed to outcome ',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general) Not installed/available ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on personnel',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pressure-Damaged/degraded ',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Pilot',
#  'Aircraft-Aircraft structures-Wing structure-Ribs/bulkheads (on wing)-Damaged/degraded',
#  'Organizational issues-Development-Design-Design of document/info-Operator ',
#  'Personnel issues-Physical-Health/Fitness-Physical fitness-Pilot ',
#  'Aircraft-Aircraft power plant-Power plant-(general) Unintentional use/operation',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of equipment-Student pilot ',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy-Awareness of condition',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Incorrect use/operation ',
#  'Personnel issues-Action/decision-Action-Forgotten action/omission-Maintenance personnel ',
#  'Organizational issues-Development-Selection/certification/testing-Equip certification/testing-Manufacturer',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Capability exceeded ',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Fluid condition ',
#  'Personnel issues-Physical-Impairment/incapacitation-(general) Pilot',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-Eng oil dist (airframe furn)-Damaged/degraded ',
#  'Personnel issues-Psychological-Mental/emotional state-Confusion-Pilot',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Student/instructed pilot ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Wake turbulence-Contributed to outcome ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Incorrect use/operation ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Glassy surface-Effect on personnel ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Takeoff distance-Related operating info',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Response/compensation ',
#  'Environmental issues-Physical environment-Terrain-High elevation-Contributed to outcome',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Prop/rotor parameters-Attain/maintain not possible ',
#  'Personnel issues-Action/decision-Action-Incomplete action-Other/unknown ',
#  'Environmental issues-Physical environment-Terrain-(general) Effect on operation ',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of geographic area-Pilot',
#  'Aircraft-Aircraft systems-Air conditioning system-Cooling sys (air/vapor cycle)-Failure ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-(general) Not specified ',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Related operating info ',
#  'Personnel issues-Miscellaneous-(general) ATC personnel',
#  'Aircraft-Aircraft power plant-Engine exhaust-Thrust reverser-Design',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Capability exceeded',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Low ceiling-Not specified ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Not specified ',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Incorrect service/maintenance ',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Visual illusion/disorientation-Pilot ',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Inadequate inspection ',
#  'Personnel issues-Physical-Health/Fitness-Use of medication/drugs-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-(general) Effect on personnel ',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Incorrect use/operation ',
#  'Personnel issues-Task performance-Planning/preparation-Flight planning/navigation-Pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Master cylinder/brake valve-Malfunction ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Damaged/degraded ',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Incorrect service/maintenance',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Design ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Malfunction',
#  'Personnel issues-Psychological-Attention/monitoring-(general) Other/unknown ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Unknown/Not determined',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-(general) Incorrect service/maintenance',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway markings/signage-Contributed to outcome',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Incorrect service/maintenance ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Powerplant parameters-Not attained/maintained',
#  'Environmental issues-Physical environment-Terrain-Mountainous/hilly terrain-Ability to respond/compensate ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Low visibility-Accuracy of related info',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Failure',
#  'Environmental issues-Physical environment-Terrain-Water-Effect on equipment ',
#  'Environmental issues-Physical environment-Object/animal/substance-(general) Effect on operation ',
#  'Personnel issues-Task performance-Maintenance-(general) Owner/builder ',
#  'Organizational issues-Support/oversight/monitoring-Training-Recurrent training-FAA/Regulator ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring environment-Pilot ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Pilot of other aircraft ',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Inoperative ',
#  'Environmental issues-Physical environment-Terrain-Water-Not specified',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Configuration-Incorrect use/operation ',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Passenger ',
#  'Personnel issues-Task performance-Use of equip/info-Use of charts-Pilot ',
#  'Personnel issues-Task performance-Planning/preparation-Flight planning/navigation-Not specified ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Awareness of condition ',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Intake anti-ice, deice-Not used/operated ',
#  'Aircraft-Aircraft structures-Nacelles/pylons structure-Main frame (on nacelles/pylon)-Fatigue/wear/corrosion ',
#  'Personnel issues-Action/decision-Action-Unnecessary action-Pilot',
#  'Personnel issues-Task performance-Record-keeping-Aircraft/maintenance logs-Pilot ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Failure ',
#  'Aircraft-Aircraft systems-Flight control system-Elevator tab control system-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear steering system-Inoperative ',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Student pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Capability exceeded ',
#  'Aircraft-Aircraft structures-Nacelles/pylons structure-(general) Not specified ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general) Not serviced/maintained ',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Contributed to outcome ',
#  'Personnel issues-Action/decision-Action-Incomplete action-Student/instructed pilot ',
#  'Personnel issues-Task performance-Maintenance-(general) Not specified ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear/wheel fairing-Not serviced/maintained',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Fatigue/wear/corrosion',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Compressor bleed control-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Failure ',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Other/unknown',
#  'Aircraft-Aircraft power plant-Engine starting-Cranking-Incorrect use/operation ',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Accuracy of related info ',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Flight crew ',
#  'Organizational issues-Management-Resources-Adequacy of equipment-Operator',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Effect on operation ',
#  'Personnel issues-Task performance-Planning/preparation-Performance calculations-Pilot',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-FAA or designated personnel',
#  'Environmental issues-Task environment-Physical workspace-Air quality/dust/smoke-Effect on operation ',
#  'Aircraft-Aircraft structures-Wing structure-Trailing edge flaps-Incorrect use/operation',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Dark-Contributed to outcome',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Climb rate-Not attained/maintained',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Damaged/degraded ',
#  'Aircraft-Aircraft structures-(general) Inadequate inspection ',
#  'Personnel issues-Task performance-Planning/preparation-(general) Pilot',
#  'Aircraft-Aircraft systems-Flight control system-Gust lock or damper-Unintentional use/operation ',
#  'Personnel issues-Experience/knowledge-Knowledge-Knowledge of procedures-Maintenance personnel ',
#  'Personnel issues-Physical-Sensory ability/limitation-Visual function-Pilot',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Instrument panel   -Not specified ',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Flight crew ',
#  'Environmental issues-Task environment-Physical workspace-Vibration-Ability to respond/compensate',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control electronic-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pressure-Failure ',
#  'Aircraft-Aircraft structures-(general) Inadequate inspection',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Wake turbulence-Effect on equipment ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Design ',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Not inspected',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Unintentional use/operation ',
#  'Personnel issues-Physical-Impairment/incapacitation-Prescription medication-Student/instructed pilot ',
#  'Personnel issues-Action/decision-Info processing/decision-(general) Student pilot ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-Tail rotor drive shaft-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Damaged/degraded',
#  'Personnel issues-Task performance-(general) Owner/builder ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-(general) Incorrect service/maintenance ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Pilot ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Wet-Effect on operation ',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Incorrect service/maintenance ',
#  'Personnel issues-Task performance-Record-keeping-Aircraft/maintenance logs-Maintenance personnel',
#  'Aircraft-Aircraft systems-Navigation system-Pitot/static system-Inoperative',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Use of related info',
#  'Aircraft-Aircraft structures-Fuselage-Gear attach fittings (on fus)-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Parachute-Failure ',
#  'Environmental issues-Conditions/weather/phenomena-(general) Decision related to condition ',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Flight control system-Gust lock or damper-Not inspected ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity sensor-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft power plant-Engine exhaust-(general) Not specified',
#  'Personnel issues-Physical-Sensory ability/limitation-Hearing-Pilot ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Capability exceeded ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Effect on personnel ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-Tail rotor gearbox-Incorrect service/maintenance ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Climb rate-Incorrect use/operation ',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Flight service personnel ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Turbine governor-Damaged/degraded ',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Owner/builder ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Decision related to condition ',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Hoses and tubes-Incorrect service/maintenance',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Fatigue/wear/corrosion ',
#  'Personnel issues-Action/decision-Info processing/decision-(general) Flight crew',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Malfunction',
#  'Aircraft-Aircraft structures-Windows-windshield system-(general) Damaged/degraded ',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Not specified ',
#  'Personnel issues-Physical-Impairment/incapacitation-OTC medication-Student/instructed pilot ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng liquid cooling-Malfunction',
#  'Aircraft-Aircraft power plant-Power plant-Powerplant wiring-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Haze/smoke-Effect on personnel',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Not inspected ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Flight control system-Elevator tab control system-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Failure',
#  'Aircraft-Aircraft systems-Fuel system-Fuel transfer valve-Incorrect use/operation ',
#  'Organizational issues-Management-Resources-Availability of personnel-Operator',
#  ...]

# %%
# double check and remove all empty space after all findings and then use list(set())
findings_ls_ver3 = list(set([finding.rstrip() for finding in findings_ls_ver2]))
print(str(len(findings_ls_ver2)) + 'vs ' + str(len(findings_ls_ver3)))
# Out:
# 6163vs 3793

# %%
findings_ls = findings_ls_ver3

# %%
# Count the number of layers that will be needed in the network diagram - max and min
word_no_ls = []
for finding in findings_ls:
    word_no = len(re.split('-', finding))
    word_no_ls.append(word_no)
max_word_no = max(word_no_ls)
min_word_no = min(word_no_ls)
print('Min connections are: ', min_word_no)
print('Max connections are: ', max_word_no)
# Out:
# Min connections are:  2
# Max connections are:  6

# %%
# identify the unique words for each layer
type_ls = []
sys_ls = []
subsys_ls = []
details_ls = []
moredet_ls = []
evenmore_ls = []
ix = 0
for finding in findings_ls:
    # for each finding I want to append each word to a separate list
    # but I also want the connection
    # remove trailing characters to enable the only values to be found and shown using .rstrip()
    ix += 1
    word_ls = re.split('-', finding)
    if len(word_ls) == 2:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
    elif len(word_ls) == 3:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
        subsys_ls.append(word_ls[2].rstrip())
    elif len(word_ls) == 4:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
        subsys_ls.append(word_ls[2].rstrip())
        details_ls.append(word_ls[3].rstrip())
    elif len(word_ls) == 5:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
        subsys_ls.append(word_ls[2].rstrip())
        details_ls.append(word_ls[3].rstrip())
        moredet_ls.append(word_ls[4].rstrip())
    else:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
        subsys_ls.append(word_ls[2].rstrip())
        details_ls.append(word_ls[3].rstrip())
        moredet_ls.append(word_ls[4].rstrip())
        evenmore_ls.append(word_ls[5].rstrip())

# %%
type_ls = set(type_ls)
sys_ls = set(sys_ls)
subsys_ls = set(subsys_ls)
details_ls = set(details_ls)
moredet_ls = set(moredet_ls)
evenmore_ls = set(evenmore_ls)

# %%
# Does it make sense to rework the data as a dictionary of dictionaries for creating network diagrams?

# %% [markdown]
# ## Create the network diagram of the connections

# %%
def NetworkLinks(type_ls, findings_ls, ix1, ix2):
    LinkDict = {}
    for type_name in type_ls:
        ls = []
        for finding in findings_ls:
            type_names_found = re.split('-', finding)
            if len(type_names_found) < 2:
                continue
            else:
                type_name_found = type_names_found[ix1]
                system = re.split('-', finding)[ix2]
                if type_name == type_name_found:
                    ls.append(system)
                else:
                    continue
        ls = list(set(ls))
        LinkDict[type_name] = ls 
    return LinkDict

# %%
def NetworkLinks_ver2(subsys_ls, findings_ls, ix1, ix2): # only for subsystem to more details
    LinkDict = {}
    for type_name in subsys_ls:
        ls = []
        for finding in findings_ls:
            type_names_found = re.split('-', finding)
            if len(type_names_found) <= 3: # condition for the 
                continue
            else:
                type_name_found = type_names_found[ix1]
                system = type_names_found[ix2]
                if type_name == type_name_found:
                    ls.append(system)
                else:
                    continue
        ls = list(set(ls))
        LinkDict[type_name] = ls
    return LinkDict

# %%
type_to_sys = NetworkLinks(type_ls, findings_ls, 0, 1)
sys_to_sub = NetworkLinks_ver2(sys_ls, findings_ls, 1, 2)
sub_to_det = NetworkLinks_ver2(subsys_ls, findings_ls, 2, 3) # need to add an extra condition for sets of strings that don't have any more words
#det_to_more = NetworkLinks_ver2(details_ls, findings_ls, 3, 4)

# %%
list(sys_to_sub.values())[0]
# Out:
# []

# %%
key_ls = list(type_to_sys.keys())
value_ls = list(type_to_sys.values())

# %% [markdown]
# ## Choose a specific type no. for visualisation

# %%
type_no = 0
for key in key_ls:
    print(key, ' correspond to Type No. ', type_no)
    type_no += 1
# Out:
# Environmental issues  correspond to Type No.  0
# Aircraft  correspond to Type No.  1
# Not determined  correspond to Type No.  2
# Personnel issues  correspond to Type No.  3
# Organizational issues  correspond to Type No.  4
# main system  correspond to Type No.  5

# %%
type_no = 0
plt.figure(3,figsize=(15, 15)) 
G = nx.Graph()
for value in value_ls[type_no]:
    G.add_edge(key_ls[type_no], value)
nx.draw(G, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=18)
plt.show()

# %%
# How to build on top of the graph already made?
sys_to_sub_ls = list(sys_to_sub.keys())
value_test_ls = []
plt.figure(3,figsize=(20, 20)) 
# pos = nx.bfs_layout(G, key_ls[type_no]) # recreation of the layout I've been using for my spider diagrams
pos = nx.kamada_kawai_layout(G, scale = 10) # recommended layout type for clearest visualisation BUT overlapping labels
for value in value_ls[type_no]:
    for system in sys_to_sub_ls:
        if value == system:
            for subsys in sys_to_sub[system]:
                value_test_ls.append(subsys)
                G.add_edge(system, subsys)
nx.draw(G, pos=pos, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=10)
plt.show()

# %%
# do it part by part
# only select 5 conditions to develop
#value_test_ls = value_test_ls[0:5]

# %% [markdown]
# ## Choose a specific system/subsystem to visualise

# %%
key_ls = list(sub_to_det.keys())
value_ls = list(sub_to_det.values())

# %%
subsys_no = 0
for key in key_ls:
    print(key, ' = Subsys No. ', type_no)
    type_no += 1
# Out:
# Airport facilities/design  = Subsys No.  0
# Object/animal/substance  = Subsys No.  1
# Auto flight system  = Subsys No.  2
# Main rotor drive  = Subsys No.  3
# Inspection  = Subsys No.  4
# (general) Student pilot  = Subsys No.  5
# Placards and markings  = Subsys No.  6
# (general) Simulated malf/failure  = Subsys No.  7
# Culture  = Subsys No.  8
# Turbulence  = Subsys No.  9
# Safety programs  = Subsys No.  10
# Workload management  = Subsys No.  11
# Fluids  = Subsys No.  12
# (general) Inoperative  = Subsys No.  13
# (general) Flight crew  = Subsys No.  14
# Alertness/Fatigue  = Subsys No.  15
# Tail rotor  = Subsys No.  16
# Eng oil sys (airframe furnish)  = Subsys No.  17
# Ice/rain protection system  = Subsys No.  18
# (general) Airport personnel  = Subsys No.  19
# Selection/certification/testing  = Subsys No.  20
# (general) Manufacturer  = Subsys No.  21
# Engine (reciprocating)  = Subsys No.  22
# Tail rotor drive system  = Subsys No.  23
# Accessory gear  = Subsys No.  24
# Design  = Subsys No.  25
# Performance/control parameters  = Subsys No.  26
# Engine exhaust  = Subsys No.  27
# (general) Airport  = Subsys No.  28
# Perception/orientation/illusio  = Subsys No.  29
# Policy/procedure  = Subsys No.  30
# Airborne APU system  = Subsys No.  31
# Record  = Subsys No.  32
# Balloon/dirigible structures  = Subsys No.  33
# (general) Attain/maintain not possible  = Subsys No.  34
# Engine starting  = Subsys No.  35
# Personality/attitude  = Subsys No.  36
# Oversight  = Subsys No.  37
# Electrical power system  = Subsys No.  38
# Selection/certification/testin  = Subsys No.  39
# Water and waste system  = Subsys No.  40
# Experience/qualifications  = Subsys No.  41
# (general) Not used/operated  = Subsys No.  42
# Parking/securing  = Subsys No.  43
# Ceiling/visibility/precip  = Subsys No.  44
# Intentional act  = Subsys No.  45
# (general) Not serviced/maintained  = Subsys No.  46
# (general) Maintenance personnel  = Subsys No.  47
# (general) Decision related to condition  = Subsys No.  48
# (general) Passenger  = Subsys No.  49
# Pressures/demands  = Subsys No.  50
# Documentation/record keeping  = Subsys No.  51
# Water injection  = Subsys No.  52
# Fire protection system  = Subsys No.  53
# Navigation system  = Subsys No.  54
# (general) Unintentional use/operation  = Subsys No.  55
# Light condition  = Subsys No.  56
# Aircraft capability  = Subsys No.  57
# Windows  = Subsys No.  58
# (general) Student/instructed pilot  = Subsys No.  59
# Nacelles/pylons structure  = Subsys No.  60
# (general) Incorrect use/operation  = Subsys No.  61
# Health/Fitness  = Subsys No.  62
# (general) ATC personnel  = Subsys No.  63
# (general) Not specified  = Subsys No.  64
# (general) Fatigue/wear/corrosion  = Subsys No.  65
# Sensory ability/limitation  = Subsys No.  66
# (general) Unknown/Not determined  = Subsys No.  67
# Enforcement  = Subsys No.  68
# Air traffic/operating proc  = Subsys No.  69
# Wing structure  = Subsys No.  70
# (general) Not attained/maintained  = Subsys No.  71
# (general) Pilot of other aircraft  = Subsys No.  72
# (general) Malfunction  = Subsys No.  73
# Vacuum system  = Subsys No.  74
# Knowledge  = Subsys No.  75
# Loading  = Subsys No.  76
# (general) Related records  = Subsys No.  77
# Pneumatic system  = Subsys No.  78
# (general) Damaged/degraded  = Subsys No.  79
# Radar services/coverage  = Subsys No.  80
# (general) Design  = Subsys No.  81
# (general) Incorrect service/maintenance  = Subsys No.  82
# Propeller system  = Subsys No.  83
# (general) Capability exceeded  = Subsys No.  84
# Cognitive limitation  = Subsys No.  85
# Doors  = Subsys No.  86
# Communications system  = Subsys No.  87
# Rotorcraft flight control  = Subsys No.  88
# (general) Availability of related info  = Subsys No.  89
# (general) Pilot  = Subsys No.  90
# (general) Copilot  = Subsys No.  91
# (general) Operator  = Subsys No.  92
# Engine bleed air system  = Subsys No.  93
# (general) Fluid level  = Subsys No.  94
# Misc hardware  = Subsys No.  95
# (general) Effect on equipment  = Subsys No.  96
# (general) Cabin crew  = Subsys No.  97
# (general) Other/unknown  = Subsys No.  98
# Action  = Subsys No.  99
# (general) Inadequate inspection  = Subsys No.  100
# (general) Instructor/check pilot  = Subsys No.  101
# (general) Related maintenance info  = Subsys No.  102
# Ignition system  = Subsys No.  103
# Meteorological services  = Subsys No.  104
# Runway/land/takeoff/taxi surface  = Subsys No.  105
# Info processing/decision  = Subsys No.  106
# Turbocharging (recip only)  = Subsys No.  107
# (general) Other government  = Subsys No.  108
# Physical characteristic  = Subsys No.  109
# Indicating/recording systems  = Subsys No.  110
# (general) Fluid management  = Subsys No.  111
# (general) Related operating info  = Subsys No.  112
# Maintenance  = Subsys No.  113
# (general) Contributed to outcome  = Subsys No.  114
# Fuel system  = Subsys No.  115
# Use of equip/info  = Subsys No.  116
# Temp/humidity/pressure  = Subsys No.  117
# (general) Owner/builder  = Subsys No.  118
# Equipment/furnishings  = Subsys No.  119
# Oxygen system  = Subsys No.  120
# Perception/orientation/illusion  = Subsys No.  121
# (general) Ability to respond/compensate  = Subsys No.  122
# (general) Other authority investigated  = Subsys No.  123
# (general) Meteorological service  = Subsys No.  124
# Terrain  = Subsys No.  125
# Empennage structure  = Subsys No.  126
# Training  = Subsys No.  127
# Runway/land/takeoff/taxi surfa  = Subsys No.  128
# Resources  = Subsys No.  129
# (general) ATC  = Subsys No.  130
# Engine controls  = Subsys No.  131
# Communication system  = Subsys No.  132
# Hydraulic power system  = Subsys No.  133
# Convective weather  = Subsys No.  134
# Power plant  = Subsys No.  135
# Approach aid coverage/avail  = Subsys No.  136
# (general) Failure  = Subsys No.  137
# Engine fuel and control  = Subsys No.  138
# Communication (organizational)  = Subsys No.  139
# Flight control system  = Subsys No.  140
# Physical workspace  = Subsys No.  141
# (general) Ground crew  = Subsys No.  142
# Engine (turbine/turboprop)  = Subsys No.  143
# Communication (personnel)  = Subsys No.  144
# Landing gear system  = Subsys No.  145
# Wind  = Subsys No.  146
# Engine indicating system  = Subsys No.  147
# Fuselage  = Subsys No.  148
# Maintenance/inspections  = Subsys No.  149
# Impairment/incapacitation  = Subsys No.  150
# Mental/emotional state  = Subsys No.  151
# Scheduling  = Subsys No.  152
# (general) Not installed/available  = Subsys No.  153
# Planning/preparation  = Subsys No.  154
# (general) Effect on operation  = Subsys No.  155
# (general) Effect on personnel  = Subsys No.  156
# Towing and taxiing  = Subsys No.  157
# Main rotor system  = Subsys No.  158
# Attention/monitoring  = Subsys No.  159
# Lighting system  = Subsys No.  160
# (general) Awareness of condition  = Subsys No.  161
# Air conditioning system  = Subsys No.  162
# Manufacture/production  = Subsys No.  163

# %%
subsys_no = 143
plt.figure(3,figsize=(20, 20)) 
S = nx.Graph()
for value in value_ls[subsys_no]:
    S.add_edge(key_ls[subsys_no], value)
nx.draw(S, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=12)
plt.show()

# %%
# repeat the process for the other details
sub_to_det_ls = list(sub_to_det.keys())
plt.figure(3,figsize=(25, 25)) 
# pos = nx.bfs_layout(G, key_ls[type_no]) #would this one work where each branch becomes its own layout
# Ideally limit the number of loops based on thevalues already in the chart
for value in value_test_ls:
    for subsystem in sub_to_det_ls:
        if value == subsystem:
            for subsys in sub_to_det[subsystem]:
                S.add_edge(system, subsys)
nx.draw(S, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=5)
plt.show()

# %%
# How to build on top of the graph already made?
sys_to_sub_ls = list(sys_to_sub.keys())
sub_ls = list(sys_to_sub.values())
fig = plt.figure()
for value in value_ls[type_no]:
    for system in sys_to_sub_ls:
        if value == system:
            for subsys in sys_to_sub[system]:
                G.add_edge(system, subsys)
nx.draw(G, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=5, ax=fig.add_subplot())
if True: 
    # Save plot to file
    # mat.use("Agg") 
    # fig.savefig("graph.png")

# %%
list(sys_to_sub.keys())

# %%
value_ls = list(type_to_sys.values())
value_ls[0]

# %% [markdown]
# ### Adding pyvis helper for clearer visualisation
