# %%
import pandas as pd
import networkx as nx
import regex as re
import matplotlib.pyplot as plt
import matplotlib as mat

# %%
df = pd.read_pickle("US_Accidents_Processed_df.pkl")

# %%
# All of the different findings to split into network diagrams
findings_ls = list(set(df['finding_description']))
findings_ls
# Out:
# ['Aircraft-Aircraft systems-Electrical power system-AC power distribution system-Failure - C',
#  'Aircraft-Aircraft structures-Wing structure-Spar (on wing)-Damaged/degraded - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller indicating system-Not serviced/maintained',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity indicator-Damaged/degraded',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Inadequate inspection',
#  'Personnel issues-Task performance-Maintenance-Scheduled/routine maintenance-Pilot - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Attain/maintain not possible - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-Main rotor blade system-Failure',
#  'Aircraft-Aircraft systems-(general)-(general)-Incorrect use/operation',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-ATC personnel - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Pilot - C',
#  'Personnel issues-Physical-Physical characteristic-Size-Pilot - F',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Contributed to outcome - F',
#  'Personnel issues-Task performance-(general)-(general)-Cabin crew',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Effect on personnel - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Effect on equipment - C',
#  'Aircraft-Aircraft systems-Electrical power system-(general)-Not specified',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Accuracy of related info - F',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other aircraft-Pilot - F',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven terrain-Contributed to outcome - C',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Capability exceeded - C',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent instrument experience-Pilot',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Maintenance personnel - F',
#  'Environmental issues-Operating environment-Airport facilities/design-Security-Effect on equipment - F',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Pilot',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general)-Decision related to condition',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Pilot',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Decision related to condition',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Design - C',
#  'Environmental issues-Physical environment-Object/animal/substance-(general)-Contributed to outcome',
#  'Personnel issues-Action/decision-(general)-(general)-Student pilot - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Downdraft-Not specified - F',
#  'Aircraft-Aircraft structures-Fuselage-Bulkheads (main fuselage)-Failure - C',
#  'Environmental issues-Physical environment-Terrain-High elevation-Contributed to outcome',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Fatigue/wear/corrosion - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Response/compensation',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-(general)-Malfunction - C',
#  'Aircraft-Aircraft handling/service-(general)-(general)-Not specified',
#  'Personnel issues-Experience/knowledge-Training-Recurrent instruct/training-Pilot - F',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Inadequate inspection - F',
#  'Environmental issues-Physical environment-Terrain-(general)-Awareness of condition',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Bright light-Contributed to outcome - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Incorrect use/operation',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Windshear-Effect on operation - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Pilot of other aircraft - F',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Flight control system-Rudder actuator-Failure',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Incorrect use/operation',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-(general)-Malfunction - C',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven terrain-Awareness of condition - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Equ/fur sys wiring-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Capability exceeded - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Soft-Not specified - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Student/instructed pilot - F',
#  'Environmental issues-Operating environment-Airport facilities/design-Security-Effect on operation - C',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Pilot - F',
#  'Personnel issues-Experience/knowledge-Training-(general)-Pilot of other aircraft - F',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-(general)-Ability to respond/compensate - C',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Windows/windshields & doors-Malfunction - C',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general)-Failure - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general)-Compliance w/ procedure - F',
#  'Environmental issues-Operating environment-Approach aid coverage/avail-Visual approach aid-Effect on operation - F',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Unintentional use/operation - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Attain/maintain not possible - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Soft-Decision related to condition - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Windshear-Effect on operation - C',
#  'Personnel issues-Task performance-Planning/preparation-Fuel planning-Student/instructed pilot - F',
#  'Personnel issues-Action/decision-Action-Lack of action-Other/unknown - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Related operating info - F',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Other/unknown - C',
#  'Personnel issues-Task performance-Workload management-Task overload-Pilot - F',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Qualification/certification-Student/instructed pilot',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Not attained/maintained - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Incorrect use/operation - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Sudden wind shift-Contributed to outcome - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general)-Ability to respond/compensate - F',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Pilot of other aircraft - C',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Incorrect service/maintenance - C',
#  'Personnel issues-Physical-Impairment/incapacitation-(general)-Not specified',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy terrain-Decision related to condition',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel controlling system-Inoperative',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Student pilot - F',
#  'Personnel issues-Psychological-Personality/attitude-Complacency-Pilot - F',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to structural icing-Awareness of condition - F',
#  'Aircraft-Aircraft structures-Empennage structure-Rudder misc structure-Design - C',
#  'Aircraft-Aircraft oper/perf/capability-(general)-(general)-Attain/maintain not possible - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Attain/maintain not possible - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Contributed to outcome - C',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Not specified - C',
#  'Personnel issues-Action/decision-Action-Lack of action-Pilot',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Sudden wind shift-Contributed to outcome - C',
#  'Aircraft-Aircraft structures-Windows-windshield system-Flight compartment windows-Not used/operated - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Effect on operation - F',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Passenger',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Contributed to outcome',
#  'Aircraft-Aircraft structures-(general)-(general)-Damaged/degraded',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, main system-Not specified - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Failure - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring equip/instruments-Flight crew - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Attain/maintain not possible',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Braking capability-Capability exceeded - C',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-(general)-Damaged/degraded - F',
#  'Aircraft-Aircraft handling/service-Parking/securing-Tie-down/mooring-Incorrect use/operation',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Owner/builder - C',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Incorrect use/operation - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-(general)-Not specified - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent rate-Incorrect use/operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Master cylinder/brake valve-Malfunction - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Downdraft-Effect on equipment - F',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Low light-Contributed to outcome - F',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Student pilot - C',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Failure - F',
#  'Aircraft-Aircraft systems-Electrical power system-(general)-Capability exceeded - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general)-Effect on equipment - C',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, indicating system-Malfunction - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Not specified - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Hydraulic fluid-Related operating info',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent experience-Student pilot',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel controlling system-Damaged/degraded',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Effect on operation - C',
#  'Aircraft-Aircraft power plant-(general)-(general)-Failure - C',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Copilot',
#  'Aircraft-Aircraft systems-Landing gear system-Aux gear (tail/rotorcrft skid)-Incorrect service/maintenance - C',
#  'Organizational issues-Support/oversight/monitoring-Training-Emergency proc training-Manufacturer - F',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy terrain-Contributed to outcome',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Hoses and tubes-Inadequate inspection',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Related maintenance info - C',
#  'Personnel issues-Task performance-Maintenance-Unauthorized maint/repair-Owner/builder - F',
#  'Personnel issues-Task performance-Maintenance-Scheduled/routine maintenance-Owner/builder - F',
#  'Aircraft-Aircraft systems-Electrical power system-Alternator-generator drive sys-Failure - C',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience w/ equipment-Maintenance personnel - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Failure - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Pilot - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Malfunction',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Timing of related info - F',
#  'Personnel issues-Psychological-Attention/monitoring-Attention-Instructor/check pilot - F',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Failure - C',
#  'Organizational issues-Development-Manufacture/production-Equipment manufacture-Manufacturer - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Not specified - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Effect on operation',
#  'Personnel issues-Psychological-Cognitive limitation-Cognitive overload-Pilot',
#  'Aircraft-Aircraft oper/perf/capability-(general)-(general)-Not specified - C',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Intake anti-ice, deice-Not specified - C',
#  'Organizational issues-Management-Policy/procedure-(general)-Operator - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered-Contributed to outcome - C',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Air inlet section (core eng)-Inadequate inspection - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Low ceiling-Decision related to condition - F',
#  'Environmental issues-Task environment-Pressures/demands-Financial pressure-Decision related to condition',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Incorrect use/operation - F',
#  'Aircraft-Aircraft systems-Landing gear system-Wheel/ski/float-Capability exceeded - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Fluid level - F',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Malfunction - F',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Failure - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Awareness of condition',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Fatigue/wear/corrosion',
#  'Personnel issues-Task performance-Maintenance-Installation-Other/unknown - F',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High density altitude-Not specified',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Pilot of other aircraft - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Not specified - F',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Clouds-Effect on personnel',
#  'Environmental issues-Physical environment-Terrain-(general)-Contributed to outcome - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Maximum weight-Capability exceeded - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Student/instructed pilot',
#  'Personnel issues-Task performance-Communication (personnel)-Accuracy of communication-Pilot of other aircraft - F',
#  'Personnel issues-Action/decision-Action-Incomplete action-Other/unknown - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Failure - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Designated examiner',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general)-Incorrect service/maintenance',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Effect on personnel',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Pilot',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Ice detection-Not used/operated',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Contributed to outcome',
#  'Organizational issues-Management-Policy/procedure-Availability of policy/proc-Operator - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Contributed to outcome - C',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Passenger',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Dust devil/whirlwind-Response/compensation - C',
#  'Aircraft-Aircraft systems-Fuel system-(general)-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Damaged/degraded - C',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general)-Incorrect service/maintenance - F',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Perception-Flight crew - C',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Unneccessary use/operation - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general)-Not attained/maintained - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel controlling system-Malfunction - C',
#  'Organizational issues-Development-Design-Equipment design-Not specified - F',
#  'Personnel issues-Task performance-Maintenance-Replacement-Owner/builder - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on equipment - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Related operating info - F',
#  'Environmental issues-Operating environment-Communication system-(general)-Not specified',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Pilot of other aircraft - C',
#  'Aircraft-Aircraft structures-Empennage structure-Elevators-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Communications system-VHF communication system-Inoperative - F',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear selector-Incorrect use/operation - C',
#  'Personnel issues-Psychological-Attention/monitoring-Attention-Student/instructed pilot',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Emergency services personnel - F',
#  'Environmental issues-Task environment-Pressures/demands-Time/schedule pressure-Decision related to condition - F',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Airport personnel - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Drizzle/mist-Effect on operation - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Failure - C',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Not specified',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Not attained/maintained',
#  'Personnel issues-Experience/knowledge-Knowledge-Aeronautical knowledge-Passenger',
#  'Aircraft-Aircraft power plant-Ignition system-(general)-Failure - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Parachute-Malfunction - F',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-(general)-Pilot - F',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear steering system-Malfunction',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Pilot of other aircraft - F',
#  'Aircraft-Aircraft systems-Electrical power system-DC generator-alternator-Failure',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Agricultural/external load sys-Unknown/Not determined',
#  'Personnel issues-Experience/knowledge-Training-Training with equipment-Pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Not serviced/maintained',
#  'Environmental issues-Task environment-Pressures/demands-Equipment/operational-Effect on personnel - C',
#  'Personnel issues-Task performance-(general)-(general)-Student pilot - F',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Accessory drives-Failure - C',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Other institution/organization',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Inadequate inspection - C',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Flt operations/dispatcher - F',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Response/compensation',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Not serviced/maintained - F',
#  'Environmental issues-Physical environment-Terrain-Wet/muddy terrain-Effect on operation',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Instructor/check pilot - F',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Manufacturer - C',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general)-Not specified',
#  'Personnel issues-Task performance-Use of equip/info-(general)-Pilot - C',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Not installed/available - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general)-Effect on operation',
#  'Personnel issues-Task performance-Communication (personnel)-(general)-ATC personnel',
#  'Personnel issues-Psychological-Mental/emotional state-Stress-Pilot',
#  'Aircraft-Aircraft systems-Flight control system-(general)-Design - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Effect on equipment - C',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Document revision tracking-Manufacturer',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Not attained/maintained - F',
#  'Environmental issues-Physical environment-Terrain-Water-Awareness of condition',
#  'Aircraft-Aircraft structures-Wing structure-Center wing box (on wing)-Capability exceeded',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Capability exceeded - F',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Maintenance personnel - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Incorrect service/maintenance - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Fog-Decision related to condition',
#  'Environmental issues-Physical environment-Terrain-Wet/muddy-Effect on equipment - C',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic pattern procedure-Effect on personnel',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Awareness of condition - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Awareness of condition',
#  'Organizational issues-Management-Resources-(general)-Emergency services',
#  'Aircraft-Aircraft handling/service-Placards and markings-(general)-Incorrect service/maintenance - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Wet-Decision related to condition - C',
#  'Aircraft-Aircraft power plant-Ignition system-Ignition power supply-Damaged/degraded - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Incorrect use/operation - C',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Flight crew - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Turbine governor-Failure - C',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Malfunction',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Incorrect service/maintenance',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Effect on equipment - F',
#  'Personnel issues-Action/decision-Action-Unnecessary action-Ground crew - C',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Capability exceeded',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-CG/weight distribution-Not attained/maintained',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Not specified - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Pilot of other aircraft - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Person-Effect on equipment - C',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, auxiliary system-Inadequate inspection',
#  'Personnel issues-Task performance-Use of equip/info-Aircraft control-Pilot - F',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Failure - C',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear strut/axle-Capability exceeded - C',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Oversight of personnel-ATC - C',
#  'Environmental issues-Physical environment-Terrain-Wet/muddy-Not specified',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Perception-Instructor/check pilot - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Thermal lifting-Effect on operation',
#  'Aircraft-Aircraft structures-Windows-windshield system-Flight compartment windows-Not specified - C',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Intake anti-ice, deice-Incorrect use/operation',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway markings/signage-Contributed to outcome',
#  'Aircraft-Aircraft systems-Hydraulic power system-(general)-Inoperative - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Unintentional use/operation - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Not attained/maintained - F',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Design',
#  'Organizational issues-Development-Design-Design of document/info-Operator - F',
#  'Environmental issues-Task environment-Physical workspace-Vibration-Awareness of condition',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Pilot - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Damaged/degraded - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Flight crew - F',
#  'Personnel issues-Psychological-Attention/monitoring-(general)-Pilot - F',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Fasteners-Not specified',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Unintentional use/operation',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Inadequate inspection - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller feather/reversing-Unintentional use/operation - C',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear selector-Unintentional use/operation',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring environment-Student pilot - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Decision related to condition',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Contributed to outcome - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel indicating system-Damaged/degraded',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Not serviced/maintained',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Copilot',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Design',
#  'Aircraft-Aircraft handling/service-Loading-(general)-Not specified',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Ground crew',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Unintentional use/operation - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Oil-Fluid level',
#  'Aircraft-Aircraft structures-Wing structure-Wing auxiliary structure-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Flight control system-Elevator tab control system-Inadequate inspection - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Contributed to outcome - C',
#  'Organizational issues-Management-Policy/procedure-Availability of policy/proc-Manufacturer',
#  'Personnel issues-Physical-Impairment/incapacitation-Illness/injury-Pilot - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Capability exceeded - C',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Fatigue/wear/corrosion',
#  'Personnel issues-Task performance-Inspection-(general)-Airport personnel - C',
#  'Personnel issues-Action/decision-Action-Lack of action-Instructor/check pilot',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Emergency equipment-Inadequate inspection',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Malfunction - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Not specified - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pressure-Not specified',
#  'Personnel issues-Physical-Health/Fitness-Predisposing condition-Not specified',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Capability exceeded - C',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor-(general)-Failure',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Not inspected - F',
#  'Aircraft-Aircraft systems-Electrical power system-DC power distribution system-Design',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Pilot - F',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Not serviced/maintained - F',
#  'Environmental issues-Physical environment-Terrain-(general)-Effect on personnel',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent/approach/glide path-Capability exceeded - C',
#  'Personnel issues-Task performance-Planning/preparation-Fuel planning-Student pilot - F',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear selector-Not used/operated - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring environment-Other/unknown - C',
#  'Aircraft-Aircraft power plant-Power plant-(general)-Not specified',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered-Awareness of condition',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Configuration-Not specified',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel indicating system-Related maintenance info - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Inadequate inspection',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Passenger - F',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Bright light-Not specified',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Incorrect use/operation - C',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Low light-Effect on personnel - F',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor-Tail rotor blade-Failure - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Effect on personnel - C',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Not used/operated - F',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear attach section-Fatigue/wear/corrosion',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Pilot - F',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Incorrect service/maintenance - F',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other aircraft-Student/instructed pilot',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Awareness of condition',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Pilot - C',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Unnecessary use/operation - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Flight compartment equipment-Failure - C',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Malfunction',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Malfunction - C',
#  'Environmental issues-Physical environment-Terrain-Mountainous/hilly terrain-Ability to respond/compensate - F',
#  'Aircraft-Aircraft systems-Flight control system-Stabilizer control system-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Related operating info',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Haze/smoke-Effect on personnel',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic congestion-Not specified',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Incorrect use/operation',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Compressor bleed control-Damaged/degraded - C',
#  'Aircraft-Aircraft power plant-Engine controls-(general)-Not used/operated - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Pilot',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Rotorcraft servo system-Incorrect service/maintenance',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent/approach/glide path-Attain/maintain not possible',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Decision related to condition - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Inoperative',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Malfunction - C',
#  'Environmental issues-Task environment-Physical workspace-Visibility-Effect on operation - C',
#  'Aircraft-Aircraft systems-Air conditioning system-Air distribution system-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft structures-Doors-(general)-Related operating info',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Perception-Pilot - C',
#  'Personnel issues-Action/decision-Action-Unneccessary action-Pilot - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Inadequate inspection - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Effect on equipment - F',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Terrain induced turbulence-Contributed to outcome - F',
#  'Aircraft-Aircraft systems-Vacuum system-(general)-Failure',
#  'Personnel issues-Physical-Impairment/incapacitation-Illness/injury-Cabin crew - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Effect on operation',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Not attained/maintained - C',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Damaged/degraded - F',
#  'Aircraft-Aircraft systems-Flight control system-(general)-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft structures-Wing structure-Wing auxiliary structure-Failure - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Fatigue/wear/corrosion',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Ability to respond/compensate - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Taxiway lighting-Contributed to outcome - C',
#  'Aircraft-Aircraft systems-Fuel system-(general)-Design',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Related maintenance info',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Copilot - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Engine out capability-Capability exceeded - F',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general)-Ability to respond/compensate - C',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Incorrect use/operation - F',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Capability exceeded',
#  'Personnel issues-Task performance-Inspection-(general)-Pilot',
#  'Environmental issues-Task environment-Pressures/demands-Other pressure/demand-Effect on personnel - F',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general)-Attain/maintain not possible',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Attain/maintain not possible - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to structural icing-Effect on equipment - C',
#  'Personnel issues-Physical-Health/Fitness-Physical fitness-Pilot',
#  'Personnel issues-Task performance-Maintenance-Replacement-Other/unknown - F',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general)-Failure',
#  'Personnel issues-Task performance-(general)-(general)-Unknown/Not determined',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Not serviced/maintained',
#  'Personnel issues-Task performance-Planning/preparation-Flight planning/navigation-Pilot',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-(general)-Not attained/maintained - C',
#  'Personnel issues-Task performance-Use of equip/info-Aircraft control-Flight crew',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Emergency locator beacon-Incorrect use/operation',
#  'Aircraft-Aircraft systems-Fuel system-Fuel temperature-Capability exceeded',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Flt operations/dispatcher',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Fog-Contributed to outcome',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Wet-Response/compensation - F',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Pilot of other aircraft - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Effect on operation - C',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Oversight of operation-Operator - C',
#  'Personnel issues-Task performance-Inspection-Scheduled/routine inspection-Maintenance personnel - F',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general)-Fatigue/wear/corrosion - C',
#  'Personnel issues-Task performance-Communication (personnel)-Issuing instructions-Instructor/check pilot - F',
#  'Aircraft-Aircraft oper/perf/capability-(general)-(general)-Related operating info - C',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Failure - C',
#  'Personnel issues-Task performance-Maintenance-Installation-Pilot - C',
#  'Personnel issues-Action/decision-Action-Lack of action-Pilot of other aircraft - C',
#  'Aircraft-Aircraft power plant-Ignition system-Spark plugs/igniters-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Flight control system-Rudder tab control system-Incorrect use/operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Inadequate inspection - C',
#  'Personnel issues-Task performance-(general)-(general)-Airport personnel - F',
#  'Personnel issues-Task performance-Maintenance-Repair-Pilot - C',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Capability exceeded',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Glide-Attain/maintain not possible - F',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Incorrect service/maintenance - C',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Student/instructed pilot - C',
#  'Aircraft-Aircraft structures-Wing structure-Flight surfaces (wing)-Design - C',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Instructor/check pilot',
#  'Aircraft-Aircraft systems-Electrical power system-Electrical pwr sys wiring-Design - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Contributed to outcome - F',
#  'Personnel issues-Task performance-Maintenance-Installation-Owner/builder',
#  'Aircraft-Aircraft systems-Lighting system-Exterior lighting-Design - F',
#  'Environmental issues-Physical environment-Object/animal/substance-(general)-Effect on operation - C',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Drizzle/mist-Effect on personnel',
#  'Environmental issues-Physical environment-Object/animal/substance-Debris/dirt/foreign object-Effect on equipment',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general)-Response/compensation',
#  'Aircraft-Aircraft systems-Landing gear system-(general)-Malfunction',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Other/unknown - F',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Fog-Decision related to condition - F',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Damaged/degraded',
#  'Personnel issues-Experience/knowledge-Knowledge-Aeronautical knowledge-Pilot',
#  'Aircraft-Aircraft power plant-Engine exhaust-(general)-Damaged/degraded',
#  'Environmental issues-Task environment-Pressures/demands-Other pressure/demand-Effect on personnel',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Capability exceeded - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general)-Effect on equipment - F',
#  'Environmental issues-Physical environment-Terrain-High elevation-Contributed to outcome - C',
#  'Aircraft-Aircraft structures-Wing structure-Flight surfaces (wing)-Failure - C',
#  'Aircraft-Aircraft power plant-Ignition system-Ignition power supply-Inoperative - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Effect on equipment',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Incorrect service/maintenance - C',
#  'Personnel issues-Action/decision-(general)-(general)-Pilot - F',
#  'Personnel issues-Physical-Impairment/incapacitation-OTC medication-Student/instructed pilot - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Effect on personnel',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-Instructor/check pilot - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Not specified - F',
#  'Aircraft-Aircraft power plant-Ignition system-(general)-Malfunction - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Prop/spinner section-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Fuel system-(general)-Damaged/degraded - C',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Dark-Ability to respond/compensate',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel flow sensor-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Emergency equipment-Design - F',
#  'Personnel issues-Task performance-Maintenance-Scheduled/routine maintenance-Not specified',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway/landing area condition-Effect on operation',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway/landing area length-Awareness of condition - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Effect on operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Incorrect service/maintenance',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Attain/maintain not possible',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft systems-Vacuum system-Vacuum distribution system-Incorrect service/maintenance - F',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Visual illusion/disorientation-Pilot - F',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Turbine section-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Engine out control-Incorrect use/operation - C',
#  'Environmental issues-Physical environment-Object/animal/substance-(general)-Effect on operation',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Response/compensation - C',
#  'Aircraft-Aircraft systems-Auto flight system-Autopilot system-Inoperative - F',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience-Copilot - F',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Power plant-Eng air baffle sec (recip.)-Damaged/degraded - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Not specified - F',
#  'Aircraft-Aircraft systems-Flight control system-(general)-Unintentional use/operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Data recorders (flight/maint)-Not installed/available',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Damaged/degraded - C',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Other institution/organization - F',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Escape slide-Unintentional use/operation - C',
#  'Organizational issues-Development-Design-Policy/procedure development-Not specified - F',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Effect on personnel - C',
#  'Aircraft-Aircraft systems-Landing gear system-Wheel/ski/float-Not used/operated - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-(general)-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft systems-Fuel system-(general)-Incorrect service/maintenance',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic pattern procedure-Compliance w/ procedure - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Not serviced/maintained - C',
#  'Personnel issues-Miscellaneous-(general)-(general)-Cabin crew - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Effect on equipment - F',
# ...
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Clouds-Ability to respond/compensate',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Downdraft-Contributed to outcome - F',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Thermal lifting-Contributed to outcome - F',
#  'Environmental issues-Operating environment-Air traffic/operating proc-(general)-Contributed to outcome - C',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Related operating info - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Not specified - F',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general)-Not specified - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway lighting-Awareness of condition',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Fog-Effect on personnel - C',
#  'Personnel issues-Action/decision-Action-Lack of action-Cabin crew',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-Eng oil dist (airframe furn)-Malfunction - C',
#  'Personnel issues-Task performance-Communication (personnel)-Interpretation/understanding-Pilot - F',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Engine anti-icing system-Not used/operated - C',
#  'Personnel issues-Psychological-Mental/emotional state-Anxiety/panic-Pilot',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Spatial disorientation-Flight crew',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Incorrect use/operation - F',
#  'Personnel issues-Task performance-Use of equip/info-Use of charts-Pilot - F',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Failure',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Qualification/certification-Student pilot - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Inadequate inspection - F',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High temperature-Effect on operation - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Instrument flight capability-Not attained/maintained - C',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Rotorcraft servo system-Malfunction - C',
#  'Aircraft-Aircraft systems-Navigation system-Ground proximity system-Not used/operated - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller feather/reversing-Not specified',
#  'Organizational issues-Management-Policy/procedure-Availability of policy/proc-Airport - F',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent experience-Pilot - C',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear attach section-Capability exceeded - C',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Maintenance personnel - C',
#  'Personnel issues-Action/decision-Action-Lack of action-Instructor/check pilot - C',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Owner/builder - C',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Reduction gear and shaft-Incorrect service/maintenance - F',
#  'Personnel issues-Task performance-Planning/preparation-Performance calculations-Pilot',
#  'Aircraft-Aircraft structures-Wing structure-Spoilers-Unintentional use/operation - C',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear strut/axle-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general)-Damaged/degraded',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Copilot - C',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Operator - F',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Failure - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Effect on equipment - C',
#  'Environmental issues-Physical environment-Object/animal/substance-(general)-Decision related to condition',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general)-Not serviced/maintained - C',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Instructor/check pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Inoperative',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Not specified - C',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Ground crew - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Effect on equipment',
#  'Personnel issues-Physical-Impairment/incapacitation-OTC medication-Pilot - F',
#  'Personnel issues-Physical-Impairment/incapacitation-Prescription medication-Instructor/check pilot - F',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-(general)-Contributed to outcome',
#  'Aircraft-Aircraft handling/service-Parking/securing-Tie-down/mooring-Inadequate inspection - C',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Instructor/check pilot',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience-Instructor/check pilot',
#  'Aircraft-Aircraft structures-Wing structure-Plates/skins (on wing)-Incorrect service/maintenance - C',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total instrument experience-Pilot',
#  'Personnel issues-Action/decision-Action-Lack of action-Owner/builder - C',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Pilot of other aircraft - F',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Failure',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Landing distance-Not attained/maintained',
#  'Aircraft-Aircraft power plant-Engine exhaust-Thrust reverser-Incorrect use/operation - F',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Student/instructed pilot - C',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Other',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Effect on equipment',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Malfunction - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel divider-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent rate-Attain/maintain not possible',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general)-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Related operating info - C',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven terrain-Response/compensation',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Student/instructed pilot',
#  'Environmental issues-Operating environment-Air traffic/operating proc-ATC clearance procedure-Effect on operation - F',
#  'Organizational issues-Management-Resources-Availability of equipment-Meteorological service - F',
#  'Personnel issues-Task performance-Communication (personnel)-(general)-Other/unknown - F',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Incorrect service/maintenance - C',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-(general)-Operator - F',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Inadequate inspection',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total instrument experience-Pilot - F',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Student/instructed pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Not specified - C',
#  'Aircraft-Aircraft power plant-Ignition system-Spark plugs/igniters-Not specified - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Dust devil/whirlwind-Not specified - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Sudden wind shift-Effect on equipment - F',
#  'Personnel issues-Action/decision-Action-Unnecessary action-Pilot of other aircraft - C',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller hub section-Incorrect service/maintenance - C',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Availability of safety program-Other government - F',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Response/compensation - F',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity sensor-Incorrect service/maintenance - F',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Unintentional use/operation - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway/landing area length-Accuracy of related info',
#  'Personnel issues-Action/decision-Action-Incomplete action-Maintenance personnel - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Effect on operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Sign/marker-Awareness of condition - F',
#  'Environmental issues-Operating environment-Approach aid coverage/avail-Glideslope-Compliance w/ procedure - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Malfunction',
#  'Environmental issues-Physical environment-Terrain-Water-Effect on operation - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Main rotor gearbox-Inadequate inspection - F',
#  'Personnel issues-Task performance-Maintenance-Unauthorized maint/repair-Not specified - C',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Damaged/degraded - C',
#  'Organizational issues-Support/oversight/monitoring-Training-(general)-Airport - F',
#  'Aircraft-Aircraft structures-Wing structure-Ailerons-Fatigue/wear/corrosion - C',
#  'Organizational issues-Support/oversight/monitoring-Enforcement-Operational procedures-FAA/Regulator',
#  'Personnel issues-Physical-Alertness/Fatigue-Lack of sleep-Flight crew - F',
#  'Personnel issues-Psychological-Personality/attitude-Personality-Pilot - C',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Fluid type - F',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Damaged/degraded - C',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Pilot',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Malfunction - F',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience in position-Pilot - F',
#  'Organizational issues-Support/oversight/monitoring-(general)-(general)-Operator - F',
#  'Aircraft-Aircraft structures-Fuselage-(general)-Damaged/degraded - C',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-(general)-Timing of related info',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Not inspected - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Airport lighting-Not specified',
#  'Personnel issues-Psychological-Mental/emotional state-Anxiety/panic-Passenger - F',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Incorrect service/maintenance',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Spatial disorientation-Copilot - C',
#  'Aircraft-Aircraft systems-Electrical power system-Electrical pwr sys wiring-Damaged/degraded - C',
#  'Aircraft-Aircraft systems-Vacuum system-(general)-Incorrect service/maintenance - C',
#  'Personnel issues-Action/decision-Action-Lack of action-Flight crew',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Failure - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Not attained/maintained - F',
#  'Aircraft-Aircraft structures-Empennage structure-Elevator misc structure-Failure - C',
#  'Aircraft-Aircraft systems-Lighting system-Exterior lighting-Incorrect service/maintenance - C',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general)-Ability to respond/compensate',
#  'Aircraft-Fluids/misc hardware-Fluids-Grease-Incorrect service/maintenance - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Related operating info - F',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Awareness of condition - F',
#  'Aircraft-Aircraft structures-(general)-(general)-Not serviced/maintained - F',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Response/compensation - C',
#  'Aircraft-Aircraft systems-Electrical power system-Alternator-generator drive sys-Inoperative - F',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Not specified',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on operation - F',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Unintentional use/operation - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway lighting-Not specified - F',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Oversight of maintenance-FAA/Regulator',
#  'Personnel issues-Action/decision-(general)-(general)-ATC personnel - C',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Design - F',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Passenger - F',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Not used/operated - C',
#  'Aircraft-Fluids/misc hardware-Fluids-(general)-Not serviced/maintained - F',
#  'Aircraft-Aircraft power plant-Engine controls-(general)-Failure - C',
#  'Organizational issues-Development-Selection/certification/testing-Document/info verification-FAA/Regulator - C',
#  'Environmental issues-Operating environment-Airport facilities/design-Taxiway markings/signage-Compliance w/ procedure - F',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Related operating info - C',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Contributed to outcome - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Attain/maintain not possible - F',
#  'Organizational issues-Management-Communication (organizational)-Between groups/organizations-Meteorological service - F',
#  'Aircraft-Aircraft structures-Wing structure-Plates/skins (on wing)-Fatigue/wear/corrosion - C',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation - F',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Contributed to outcome - C',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Other/unknown - C',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-CG/weight distribution-Not attained/maintained - C',
#  'Aircraft-Aircraft systems-Flight control system-Gust lock or damper-Incorrect use/operation',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Not attained/maintained - C',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft-Effect on equipment - C',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Not specified - C',
#  ...]

# %%
findings_ls[0].replace('- C', '')
# Out:
# 'Aircraft-Aircraft systems-Electrical power system-AC power distribution system-Failure '

# %%
len(findings_ls)
# Out:
# 6163

# %%
findings_ls_ver1 = []
for finding in findings_ls:
    if re.split('-', finding)[-1] == ' C':
        finding = finding.replace('- C', '')
    if re.split('-', finding)[-1] == ' F':
        finding = finding.replace('- F', '')
    findings_ls_ver1.append(finding)

# %%
len(findings_ls_ver1)
# Out:
# 6163

# %%
finding = findings_ls_ver1[9]
finding.find('(general)')
# Out:
# 26

# %%
finding = findings_ls_ver1[9]
finding = finding.replace('-(general)', '', 1)
ix = finding.find('(general)')
ls = re.split('-', finding[ix:])
finding[0:ix] + ls[0] + ' ' + ls[1]
# what if there's more than one word after the (general) word?
# Out:
# 'Aircraft-Aircraft systems-(general) Incorrect use/operation'

# %%
# Locate all of the (general) options and instead combine it with the next part
findings_ls_ver2 = []
for finding in findings_ls_ver1:
    if '(general)' in finding:
        if finding.count('(general)') == 1:
            # know which specific index the 'general' is in and recreate the previous format
            ix = finding.find('(general)')
            ls = re.split('-', finding[ix:])
            if len(ls) == 2:
                finding = finding[0:ix] + ls[0] + ' ' + ls[1] # finding = before (general) + (general) + rest of the finding
            else:
                print(finding, '- Recheck')
        else:
            # what if (general) occurs more than once? Remove one of the instances and repeat the same process as above
            finding = finding.replace('-(general)', '', 1)
            ix = finding.find('(general)')
            ls = re.split('-', finding[ix:])
            if len(ls) == 2:
                finding = finding[0:ix] + ls[0] + ' ' + ls[1] # finding = before (general) + (general) + rest of the finding
            else:
                print(finding, '- Recheck')
    findings_ls_ver2.append(finding)

# %%
findings_ls_ver2
# Out:
# ['Aircraft-Aircraft systems-Electrical power system-AC power distribution system-Failure ',
#  'Aircraft-Aircraft structures-Wing structure-Spar (on wing)-Damaged/degraded ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller indicating system-Not serviced/maintained',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity indicator-Damaged/degraded',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Inadequate inspection',
#  'Personnel issues-Task performance-Maintenance-Scheduled/routine maintenance-Pilot ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Incorrect service/maintenance ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Attain/maintain not possible ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-Main rotor blade system-Failure',
#  'Aircraft-Aircraft systems-(general) Incorrect use/operation',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-ATC personnel ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Pilot ',
#  'Personnel issues-Physical-Physical characteristic-Size-Pilot ',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Contributed to outcome ',
#  'Personnel issues-Task performance-(general) Cabin crew',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Effect on personnel ',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Effect on equipment ',
#  'Aircraft-Aircraft systems-Electrical power system-(general) Not specified',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground equipment-Accuracy of related info ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other aircraft-Pilot ',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven terrain-Contributed to outcome ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Capability exceeded ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent instrument experience-Pilot',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Maintenance personnel ',
#  'Environmental issues-Operating environment-Airport facilities/design-Security-Effect on equipment ',
#  'Personnel issues-Physical-Impairment/incapacitation-Illicit drug-Pilot',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-(general) Decision related to condition',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Pilot',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Decision related to condition',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller assembly-Design ',
#  'Environmental issues-Physical environment-Object/animal/substance-(general) Contributed to outcome',
#  'Personnel issues-Action/decision-(general) Student pilot ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Downdraft-Not specified ',
#  'Aircraft-Aircraft structures-Fuselage-Bulkheads (main fuselage)-Failure ',
#  'Environmental issues-Physical environment-Terrain-High elevation-Contributed to outcome',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Fatigue/wear/corrosion ',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Response/compensation',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-(general) Malfunction ',
#  'Aircraft-Aircraft handling/service-(general) Not specified',
#  'Personnel issues-Experience/knowledge-Training-Recurrent instruct/training-Pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Inadequate inspection ',
#  'Environmental issues-Physical environment-Terrain-(general) Awareness of condition',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Bright light-Contributed to outcome ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Incorrect use/operation',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Windshear-Effect on operation ',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Pilot of other aircraft ',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Flight control system-Rudder actuator-Failure',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Incorrect use/operation',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-(general) Malfunction ',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven terrain-Awareness of condition ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Equ/fur sys wiring-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel filter-strainer-Capability exceeded ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Soft-Not specified ',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Student/instructed pilot ',
#  'Environmental issues-Operating environment-Airport facilities/design-Security-Effect on operation ',
#  'Personnel issues-Task performance-Planning/preparation-Weather planning-Pilot ',
#  'Personnel issues-Experience/knowledge-Training-(general) Pilot of other aircraft ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-(general) Ability to respond/compensate ',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Windows/windshields & doors-Malfunction ',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general) Failure ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general) Compliance w/ procedure ',
#  'Environmental issues-Operating environment-Approach aid coverage/avail-Visual approach aid-Effect on operation ',
#  'Aircraft-Aircraft systems-Landing gear system-(general) Unintentional use/operation ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Attain/maintain not possible ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Soft-Decision related to condition ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Windshear-Effect on operation ',
#  'Personnel issues-Task performance-Planning/preparation-Fuel planning-Student/instructed pilot ',
#  'Personnel issues-Action/decision-Action-Lack of action-Other/unknown ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Related operating info ',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Other/unknown ',
#  'Personnel issues-Task performance-Workload management-Task overload-Pilot ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Qualification/certification-Student/instructed pilot',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Not attained/maintained ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Incorrect use/operation ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Sudden wind shift-Contributed to outcome ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general) Ability to respond/compensate ',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Pilot of other aircraft ',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Incorrect service/maintenance ',
#  'Personnel issues-Physical-Impairment/incapacitation-(general) Not specified',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy terrain-Decision related to condition',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel controlling system-Inoperative',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Student pilot ',
#  'Personnel issues-Psychological-Personality/attitude-Complacency-Pilot ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to structural icing-Awareness of condition ',
#  'Aircraft-Aircraft structures-Empennage structure-Rudder misc structure-Design ',
#  'Aircraft-Aircraft oper/perf/capability-(general) Attain/maintain not possible ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Attain/maintain not possible ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Contributed to outcome ',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Not specified ',
#  'Personnel issues-Action/decision-Action-Lack of action-Pilot',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Sudden wind shift-Contributed to outcome ',
#  'Aircraft-Aircraft structures-Windows-windshield system-Flight compartment windows-Not used/operated ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Effect on operation ',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Passenger',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Contributed to outcome',
#  'Aircraft-Aircraft structures-(general) Damaged/degraded',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, main system-Not specified ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Failure ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring equip/instruments-Flight crew ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Attain/maintain not possible',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Braking capability-Capability exceeded ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor drive system-(general) Damaged/degraded ',
#  'Aircraft-Aircraft handling/service-Parking/securing-Tie-down/mooring-Incorrect use/operation',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Owner/builder ',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Incorrect use/operation ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-(general) Not specified ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent rate-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Master cylinder/brake valve-Malfunction ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Downdraft-Effect on equipment ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Low light-Contributed to outcome ',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Student pilot ',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Failure ',
#  'Aircraft-Aircraft systems-Electrical power system-(general) Capability exceeded ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general) Effect on equipment ',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, indicating system-Malfunction ',
#  'Environmental issues-Physical environment-Object/animal/substance-Ground vehicle-Not specified ',
#  'Aircraft-Fluids/misc hardware-Fluids-Hydraulic fluid-Related operating info',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent experience-Student pilot',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel controlling system-Damaged/degraded',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Effect on operation ',
#  'Aircraft-Aircraft power plant-(general) Failure ',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Copilot',
#  'Aircraft-Aircraft systems-Landing gear system-Aux gear (tail/rotorcrft skid)-Incorrect service/maintenance ',
#  'Organizational issues-Support/oversight/monitoring-Training-Emergency proc training-Manufacturer ',
#  'Environmental issues-Physical environment-Terrain-Snowy/icy terrain-Contributed to outcome',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Hoses and tubes-Inadequate inspection',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Related maintenance info ',
#  'Personnel issues-Task performance-Maintenance-Unauthorized maint/repair-Owner/builder ',
#  'Personnel issues-Task performance-Maintenance-Scheduled/routine maintenance-Owner/builder ',
#  'Aircraft-Aircraft systems-Electrical power system-Alternator-generator drive sys-Failure ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience w/ equipment-Maintenance personnel ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Failure ',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Pilot ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Malfunction',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-Thunderstorm-Timing of related info ',
#  'Personnel issues-Psychological-Attention/monitoring-Attention-Instructor/check pilot ',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Failure ',
#  'Organizational issues-Development-Manufacture/production-Equipment manufacture-Manufacturer ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Not specified ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Effect on operation',
#  'Personnel issues-Psychological-Cognitive limitation-Cognitive overload-Pilot',
#  'Aircraft-Aircraft oper/perf/capability-(general) Not specified ',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Intake anti-ice, deice-Not specified ',
#  'Organizational issues-Management-Policy/procedure-(general) Operator ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered-Contributed to outcome ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Air inlet section (core eng)-Inadequate inspection ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Low ceiling-Decision related to condition ',
#  'Environmental issues-Task environment-Pressures/demands-Financial pressure-Decision related to condition',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Wheel/ski/float-Capability exceeded ',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Fluid level ',
#  'Aircraft-Aircraft systems-Landing gear system-(general) Malfunction ',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Failure ',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Awareness of condition',
#  'Aircraft-Aircraft systems-Flight control system-Aileron control system-Fatigue/wear/corrosion',
#  'Personnel issues-Task performance-Maintenance-Installation-Other/unknown ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High density altitude-Not specified',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Pilot of other aircraft ',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Not specified ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Clouds-Effect on personnel',
#  'Environmental issues-Physical environment-Terrain-(general) Contributed to outcome ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Maximum weight-Capability exceeded ',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Student/instructed pilot',
#  'Personnel issues-Task performance-Communication (personnel)-Accuracy of communication-Pilot of other aircraft ',
#  'Personnel issues-Action/decision-Action-Incomplete action-Other/unknown ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng wiring-Failure ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Designated examiner',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general) Incorrect service/maintenance',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Effect on personnel',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Pilot',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Ice detection-Not used/operated',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Contributed to outcome',
#  'Organizational issues-Management-Policy/procedure-Availability of policy/proc-Operator ',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Contributed to outcome ',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Passenger',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Not specified',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Dust devil/whirlwind-Response/compensation ',
#  'Aircraft-Aircraft systems-Fuel system-(general) Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Damaged/degraded ',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-(general) Incorrect service/maintenance ',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Perception-Flight crew ',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Unneccessary use/operation ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general) Not attained/maintained ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel controlling system-Malfunction ',
#  'Organizational issues-Development-Design-Equipment design-Not specified ',
#  'Personnel issues-Task performance-Maintenance-Replacement-Owner/builder ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on equipment ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Related operating info ',
#  'Environmental issues-Operating environment-Communication system-(general) Not specified',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Pilot of other aircraft ',
#  'Aircraft-Aircraft structures-Empennage structure-Elevators-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft systems-Communications system-VHF communication system-Inoperative ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear selector-Incorrect use/operation ',
#  'Personnel issues-Psychological-Attention/monitoring-Attention-Student/instructed pilot',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Emergency services personnel ',
#  'Environmental issues-Task environment-Pressures/demands-Time/schedule pressure-Decision related to condition ',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Airport personnel ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Drizzle/mist-Effect on operation ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Failure ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Not specified',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Not attained/maintained',
#  'Personnel issues-Experience/knowledge-Knowledge-Aeronautical knowledge-Passenger',
#  'Aircraft-Aircraft power plant-Ignition system-(general) Failure ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Parachute-Malfunction ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-(general) Pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear steering system-Malfunction',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Pilot of other aircraft ',
#  'Aircraft-Aircraft systems-Electrical power system-DC generator-alternator-Failure',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Agricultural/external load sys-Unknown/Not determined',
#  'Personnel issues-Experience/knowledge-Training-Training with equipment-Pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Not serviced/maintained',
#  'Environmental issues-Task environment-Pressures/demands-Equipment/operational-Effect on personnel ',
#  'Personnel issues-Task performance-(general) Student pilot ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Accessory drives-Failure ',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Other institution/organization',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Inadequate inspection ',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Flt operations/dispatcher ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Clear air turbulence-Response/compensation',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Not serviced/maintained ',
#  'Environmental issues-Physical environment-Terrain-Wet/muddy terrain-Effect on operation',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Instructor/check pilot ',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Manufacturer ',
#  'Aircraft-Aircraft systems-Indicating/recording systems-(general) Not specified',
#  'Personnel issues-Task performance-Use of equip/info-(general) Pilot ',
#  'Aircraft-Aircraft structures-Fuselage-Rotorcraft tail boom-Damaged/degraded ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Not installed/available ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general) Effect on operation',
#  'Personnel issues-Task performance-Communication (personnel)-(general) ATC personnel',
#  'Personnel issues-Psychological-Mental/emotional state-Stress-Pilot',
#  'Aircraft-Aircraft systems-Flight control system-(general) Design ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Effect on equipment ',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Document revision tracking-Manufacturer',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Landing flare-Not attained/maintained ',
#  'Environmental issues-Physical environment-Terrain-Water-Awareness of condition',
#  'Aircraft-Aircraft structures-Wing structure-Center wing box (on wing)-Capability exceeded',
#  'Aircraft-Aircraft structures-Fuselage-Seat/cargo attach fitting-Capability exceeded ',
#  'Personnel issues-Task performance-Communication (personnel)-Lack of communication-Maintenance personnel ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Incorrect service/maintenance ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Fog-Decision related to condition',
#  'Environmental issues-Physical environment-Terrain-Wet/muddy-Effect on equipment ',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic pattern procedure-Effect on personnel',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Awareness of condition ',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Awareness of condition',
#  'Organizational issues-Management-Resources-(general) Emergency services',
#  'Aircraft-Aircraft handling/service-Placards and markings-(general) Incorrect service/maintenance ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Wet-Decision related to condition ',
#  'Aircraft-Aircraft power plant-Ignition system-Ignition power supply-Damaged/degraded ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Incorrect use/operation ',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Flight crew ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Turbine governor-Failure ',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Malfunction',
#  'Aircraft-Aircraft systems-Electrical power system-Battery/charger-Incorrect service/maintenance',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Effect on equipment ',
#  'Personnel issues-Action/decision-Action-Unnecessary action-Ground crew ',
#  'Aircraft-Aircraft structures-Wing structure-Attach fittings (on wing)-Capability exceeded',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-CG/weight distribution-Not attained/maintained',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Not specified ',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Pilot of other aircraft ',
#  'Environmental issues-Physical environment-Object/animal/substance-Person-Effect on equipment ',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, auxiliary system-Inadequate inspection',
#  'Personnel issues-Task performance-Use of equip/info-Aircraft control-Pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Failure ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear strut/axle-Capability exceeded ',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Oversight of personnel-ATC ',
#  'Environmental issues-Physical environment-Terrain-Wet/muddy-Not specified',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Perception-Instructor/check pilot ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Thermal lifting-Effect on operation',
#  'Aircraft-Aircraft structures-Windows-windshield system-Flight compartment windows-Not specified ',
#  'Aircraft-Aircraft systems-Ice/rain protection system-Intake anti-ice, deice-Incorrect use/operation',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway markings/signage-Contributed to outcome',
#  'Aircraft-Aircraft systems-Hydraulic power system-(general) Inoperative ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Unintentional use/operation ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Surface speed/braking-Not attained/maintained ',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Design',
#  'Organizational issues-Development-Design-Design of document/info-Operator ',
#  'Environmental issues-Task environment-Physical workspace-Vibration-Awareness of condition',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Pilot ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Damaged/degraded ',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Flight crew ',
#  'Personnel issues-Psychological-Attention/monitoring-(general) Pilot ',
#  'Aircraft-Fluids/misc hardware-Misc hardware-Fasteners-Not specified',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Unintentional use/operation',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Inadequate inspection ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller feather/reversing-Unintentional use/operation ',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Damaged/degraded',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear selector-Unintentional use/operation',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring environment-Student pilot ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Tailwind-Decision related to condition',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Contributed to outcome ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel indicating system-Damaged/degraded',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Not serviced/maintained',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Copilot',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Incorrect service/maintenance ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Design',
#  'Aircraft-Aircraft handling/service-Loading-(general) Not specified',
#  'Personnel issues-Psychological-Attention/monitoring-Task monitoring/vigilance-Ground crew',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Unintentional use/operation ',
#  'Aircraft-Fluids/misc hardware-Fluids-Oil-Fluid level',
#  'Aircraft-Aircraft structures-Wing structure-Wing auxiliary structure-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Flight control system-Elevator tab control system-Inadequate inspection ',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Contributed to outcome ',
#  'Organizational issues-Management-Policy/procedure-Availability of policy/proc-Manufacturer',
#  'Personnel issues-Physical-Impairment/incapacitation-Illness/injury-Pilot ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Capability exceeded ',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Fatigue/wear/corrosion',
#  'Personnel issues-Task performance-Inspection-(general) Airport personnel ',
#  'Personnel issues-Action/decision-Action-Lack of action-Instructor/check pilot',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Emergency equipment-Inadequate inspection',
#  'Aircraft-Aircraft systems-Electrical power system-AC generator-alternator-Malfunction ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Not specified ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pressure-Not specified',
#  'Personnel issues-Physical-Health/Fitness-Predisposing condition-Not specified',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Capability exceeded ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor-(general) Failure',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Not inspected ',
#  'Aircraft-Aircraft systems-Electrical power system-DC power distribution system-Design',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Pilot ',
#  'Aircraft-Aircraft power plant-Ignition system-Magneto/distributor-Not serviced/maintained ',
#  'Environmental issues-Physical environment-Terrain-(general) Effect on personnel',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent/approach/glide path-Capability exceeded ',
#  'Personnel issues-Task performance-Planning/preparation-Fuel planning-Student pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear selector-Not used/operated ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring environment-Other/unknown ',
#  'Aircraft-Aircraft power plant-Power plant-(general) Not specified',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered-Awareness of condition',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Configuration-Not specified',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel indicating system-Related maintenance info ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel selector/shutoff valve-Inadequate inspection',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Passenger ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Bright light-Not specified',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Incorrect use/operation ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Low light-Effect on personnel ',
#  'Aircraft-Aircraft propeller/rotor-Tail rotor-Tail rotor blade-Failure ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Below VFR minima-Effect on personnel ',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Not used/operated ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear attach section-Fatigue/wear/corrosion',
#  'Personnel issues-Action/decision-Action-Incorrect action sequence-Pilot ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Incorrect service/maintenance ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other aircraft-Student/instructed pilot',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Awareness of condition',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Unnecessary use/operation ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Flight compartment equipment-Failure ',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Malfunction',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Malfunction ',
#  'Environmental issues-Physical environment-Terrain-Mountainous/hilly terrain-Ability to respond/compensate ',
#  'Aircraft-Aircraft systems-Flight control system-Stabilizer control system-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Related operating info',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Haze/smoke-Effect on personnel',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic congestion-Not specified',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Incorrect use/operation',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Compressor bleed control-Damaged/degraded ',
#  'Aircraft-Aircraft power plant-Engine controls-(general) Not used/operated ',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Pilot',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Rotorcraft servo system-Incorrect service/maintenance',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent/approach/glide path-Attain/maintain not possible',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Decision related to condition ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel pumps-Inoperative',
#  'Aircraft-Aircraft systems-Landing gear system-Gear position and warning-Malfunction ',
#  'Environmental issues-Task environment-Physical workspace-Visibility-Effect on operation ',
#  'Aircraft-Aircraft systems-Air conditioning system-Air distribution system-Incorrect service/maintenance ',
#  'Aircraft-Aircraft structures-Doors-(general) Related operating info',
#  'Personnel issues-Psychological-Perception/orientation/illusio-Perception-Pilot ',
#  'Personnel issues-Action/decision-Action-Unneccessary action-Pilot ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller blade section-Inadequate inspection ',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Effect on equipment ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-Terrain induced turbulence-Contributed to outcome ',
#  'Aircraft-Aircraft systems-Vacuum system-(general) Failure',
#  'Personnel issues-Physical-Impairment/incapacitation-Illness/injury-Cabin crew ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Effect on operation',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel injector nozzle-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Not attained/maintained ',
#  'Aircraft-Aircraft systems-Landing gear system-Tire casing-Damaged/degraded ',
#  'Aircraft-Aircraft systems-Flight control system-(general) Damaged/degraded',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Incorrect service/maintenance ',
#  'Aircraft-Aircraft structures-Wing structure-Wing auxiliary structure-Failure ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel storage-Fatigue/wear/corrosion',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Ability to respond/compensate ',
#  'Environmental issues-Operating environment-Airport facilities/design-Taxiway lighting-Contributed to outcome ',
#  'Aircraft-Aircraft systems-Fuel system-(general) Design',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Scheduled maint checks-Related maintenance info',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Copilot ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Engine out capability-Capability exceeded ',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general) Ability to respond/compensate ',
#  'Aircraft-Aircraft systems-Landing gear system-(general) Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Capability exceeded',
#  'Personnel issues-Task performance-Inspection-(general) Pilot',
#  'Environmental issues-Task environment-Pressures/demands-Other pressure/demand-Effect on personnel ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-(general) Attain/maintain not possible',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Pitch control-Attain/maintain not possible ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to structural icing-Effect on equipment ',
#  'Personnel issues-Physical-Health/Fitness-Physical fitness-Pilot',
#  'Personnel issues-Task performance-Maintenance-Replacement-Other/unknown ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general) Failure',
#  'Personnel issues-Task performance-(general) Unknown/Not determined',
#  'Aircraft-Aircraft handling/service-Maintenance/inspections-Return to service-Not serviced/maintained',
#  'Personnel issues-Task performance-Planning/preparation-Flight planning/navigation-Pilot',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-(general) Not attained/maintained ',
#  'Personnel issues-Task performance-Use of equip/info-Aircraft control-Flight crew',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Emergency locator beacon-Incorrect use/operation',
#  'Aircraft-Aircraft systems-Fuel system-Fuel temperature-Capability exceeded',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Flt operations/dispatcher',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Fog-Contributed to outcome',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Wet-Response/compensation ',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Pilot of other aircraft ',
#  'Environmental issues-Physical environment-Object/animal/substance-Wire-Effect on operation ',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Oversight of operation-Operator ',
#  'Personnel issues-Task performance-Inspection-Scheduled/routine inspection-Maintenance personnel ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor system-(general) Fatigue/wear/corrosion ',
#  'Personnel issues-Task performance-Communication (personnel)-Issuing instructions-Instructor/check pilot ',
#  'Aircraft-Aircraft oper/perf/capability-(general) Related operating info ',
#  'Aircraft-Aircraft systems-Flight control system-Control column section-Failure ',
#  'Personnel issues-Task performance-Maintenance-Installation-Pilot ',
#  'Personnel issues-Action/decision-Action-Lack of action-Pilot of other aircraft ',
#  'Aircraft-Aircraft power plant-Ignition system-Spark plugs/igniters-Damaged/degraded ',
#  'Aircraft-Aircraft systems-Flight control system-Rudder tab control system-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Inadequate inspection ',
#  'Personnel issues-Task performance-(general) Airport personnel ',
#  'Personnel issues-Task performance-Maintenance-Repair-Pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Capability exceeded',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Glide-Attain/maintain not possible ',
#  'Aircraft-Aircraft systems-Flight control system-Elevator control system-Incorrect service/maintenance ',
#  'Personnel issues-Task performance-Communication (personnel)-Following instructions-Student/instructed pilot ',
#  'Aircraft-Aircraft structures-Wing structure-Flight surfaces (wing)-Design ',
#  'Personnel issues-Task performance-Use of equip/info-Use of equip/system-Instructor/check pilot',
#  'Aircraft-Aircraft systems-Electrical power system-Electrical pwr sys wiring-Design ',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Contributed to outcome ',
#  'Personnel issues-Task performance-Maintenance-Installation-Owner/builder',
#  'Aircraft-Aircraft systems-Lighting system-Exterior lighting-Design ',
#  'Environmental issues-Physical environment-Object/animal/substance-(general) Effect on operation ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Drizzle/mist-Effect on personnel',
#  'Environmental issues-Physical environment-Object/animal/substance-Debris/dirt/foreign object-Effect on equipment',
#  'Environmental issues-Conditions/weather/phenomena-Turbulence-(general) Response/compensation',
#  'Aircraft-Aircraft systems-Landing gear system-(general) Malfunction',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Other/unknown ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Fog-Decision related to condition ',
#  'Aircraft-Aircraft systems-Landing gear system-Gear extension and retract sys-Damaged/degraded',
#  'Personnel issues-Experience/knowledge-Knowledge-Aeronautical knowledge-Pilot',
#  'Aircraft-Aircraft power plant-Engine exhaust-(general) Damaged/degraded',
#  'Environmental issues-Task environment-Pressures/demands-Other pressure/demand-Effect on personnel',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Capability exceeded ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-(general) Effect on equipment ',
#  'Environmental issues-Physical environment-Terrain-High elevation-Contributed to outcome ',
#  'Aircraft-Aircraft structures-Wing structure-Flight surfaces (wing)-Failure ',
#  'Aircraft-Aircraft power plant-Ignition system-Ignition power supply-Inoperative ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Effect on equipment',
#  'Aircraft-Aircraft structures-Fuselage-Fuselage main structure-Incorrect service/maintenance ',
#  'Personnel issues-Action/decision-(general) Pilot ',
#  'Personnel issues-Physical-Impairment/incapacitation-OTC medication-Student/instructed pilot ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Snow/slush/ice covered surface-Effect on personnel',
#  'Personnel issues-Action/decision-Info processing/decision-Expectation/assumption-Instructor/check pilot ',
#  'Environmental issues-Physical environment-Object/animal/substance-Fence/fence post-Not specified ',
#  'Aircraft-Aircraft power plant-Ignition system-(general) Malfunction ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Prop/spinner section-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft systems-Fuel system-(general) Damaged/degraded ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Dark-Ability to respond/compensate',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel flow sensor-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Emergency equipment-Design ',
#  'Personnel issues-Task performance-Maintenance-Scheduled/routine maintenance-Not specified',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway/landing area condition-Effect on operation',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway/landing area length-Awareness of condition ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Effect on operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Incorrect service/maintenance',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Attain/maintain not possible',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng oil sys-Incorrect service/maintenance ',
#  'Aircraft-Aircraft systems-Vacuum system-Vacuum distribution system-Incorrect service/maintenance ',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Visual illusion/disorientation-Pilot ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Turbine section-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Engine out control-Incorrect use/operation ',
#  'Environmental issues-Physical environment-Object/animal/substance-(general) Effect on operation',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Crosswind-Response/compensation ',
#  'Aircraft-Aircraft systems-Auto flight system-Autopilot system-Inoperative ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience-Copilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Damaged/degraded',
#  'Aircraft-Aircraft power plant-Power plant-Eng air baffle sec (recip.)-Damaged/degraded ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-High wind-Not specified ',
#  'Aircraft-Aircraft systems-Flight control system-(general) Unintentional use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft systems-Indicating/recording systems-Data recorders (flight/maint)-Not installed/available',
#  'Aircraft-Aircraft systems-Landing gear system-Brake-Damaged/degraded ',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Other institution/organization ',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Escape slide-Unintentional use/operation ',
#  'Organizational issues-Development-Design-Policy/procedure development-Not specified ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Effect on personnel ',
#  'Aircraft-Aircraft systems-Landing gear system-Wheel/ski/float-Not used/operated ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-(general) Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft systems-Fuel system-(general) Incorrect service/maintenance',
#  'Environmental issues-Operating environment-Air traffic/operating proc-Traffic pattern procedure-Compliance w/ procedure ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Not serviced/maintained ',
#  'Personnel issues-Miscellaneous-(general) Cabin crew ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft surface-Effect on equipment ',
#  'Aircraft-Aircraft systems-Hydraulic power system-Hydraulic, auxiliary system-Incorrect use/operation ',
#  'Aircraft-Aircraft systems-Pneumatic system-Pneumatic indicating system-Inadequate inspection ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring equip/instruments-Flight crew',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Wet-Contributed to outcome',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Damaged/degraded',
#  'Personnel issues-Task performance-Use of equip/info-Use of policy/procedure-Not specified ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-(general) Capability exceeded ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity indicator-Incorrect service/maintenance ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Angle of attack-Not attained/maintained ',
#  'Personnel issues-Task performance-Planning/preparation-Flight planning/navigation-Pilot of other aircraft ',
# ...
#  'Environmental issues-Conditions/weather/phenomena-Wind-Gusts-Contributed to outcome ',
#  'Aircraft-Aircraft structures-Doors-Service doors-Inadequate inspection ',
#  'Aircraft-Aircraft structures-Empennage structure-Elevator/tab attach fitting-Incorrect service/maintenance ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Capability exceeded ',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Clouds-Ability to respond/compensate',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Downdraft-Contributed to outcome ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Thermal lifting-Contributed to outcome ',
#  'Environmental issues-Operating environment-Air traffic/operating proc-(general) Contributed to outcome ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel distribution-Related operating info ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Not specified ',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-(general) Not specified ',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway lighting-Awareness of condition',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Fog-Effect on personnel ',
#  'Personnel issues-Action/decision-Action-Lack of action-Cabin crew',
#  'Aircraft-Aircraft power plant-Eng oil sys (airframe furnish)-Eng oil dist (airframe furn)-Malfunction ',
#  'Personnel issues-Task performance-Communication (personnel)-Interpretation/understanding-Pilot ',
#  'Aircraft-Aircraft power plant-Engine bleed air system-Engine anti-icing system-Not used/operated ',
#  'Personnel issues-Psychological-Mental/emotional state-Anxiety/panic-Pilot',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Spatial disorientation-Flight crew',
#  'Aircraft-Aircraft systems-Equipment/furnishings-Passenger compartment equip-Incorrect use/operation ',
#  'Personnel issues-Task performance-Use of equip/info-Use of charts-Pilot ',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Failure',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Qualification/certification-Student pilot ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip eng cyl section-Inadequate inspection ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-High temperature-Effect on operation ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Instrument flight capability-Not attained/maintained ',
#  'Aircraft-Aircraft propeller/rotor-Rotorcraft flight control-Rotorcraft servo system-Malfunction ',
#  'Aircraft-Aircraft systems-Navigation system-Ground proximity system-Not used/operated ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller feather/reversing-Not specified',
#  'Organizational issues-Management-Policy/procedure-Availability of policy/proc-Airport ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Recent experience-Pilot ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear attach section-Capability exceeded ',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Maintenance personnel ',
#  'Personnel issues-Action/decision-Action-Lack of action-Instructor/check pilot ',
#  'Personnel issues-Task performance-Inspection-Post maintenance inspection-Owner/builder ',
#  'Aircraft-Aircraft power plant-Engine (turbine/turboprop)-Reduction gear and shaft-Incorrect service/maintenance ',
#  'Personnel issues-Task performance-Planning/preparation-Performance calculations-Pilot',
#  'Aircraft-Aircraft structures-Wing structure-Spoilers-Unintentional use/operation ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail gear strut/axle-Capability exceeded',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-(general) Damaged/degraded',
#  'Personnel issues-Task performance-Use of equip/info-Use of checklist-Copilot ',
#  'Organizational issues-Management-Policy/procedure-Adequacy of policy/proc-Operator ',
#  'Aircraft-Aircraft power plant-Engine controls-Mixture control-Failure ',
#  'Environmental issues-Physical environment-Object/animal/substance-Tree(s)-Effect on equipment ',
#  'Environmental issues-Physical environment-Object/animal/substance-(general) Decision related to condition',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general) Not serviced/maintained ',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Instructor/check pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Main gear strut/axle/truck-Inoperative',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Not specified ',
#  'Personnel issues-Action/decision-Info processing/decision-Understanding/comprehension-Ground crew ',
#  'Environmental issues-Physical environment-Object/animal/substance-Pole-Effect on equipment',
#  'Personnel issues-Physical-Impairment/incapacitation-OTC medication-Pilot ',
#  'Personnel issues-Physical-Impairment/incapacitation-Prescription medication-Instructor/check pilot ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-(general) Contributed to outcome',
#  'Aircraft-Aircraft handling/service-Parking/securing-Tie-down/mooring-Inadequate inspection ',
#  'Personnel issues-Psychological-Attention/monitoring-Monitoring other person-Instructor/check pilot',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience-Instructor/check pilot',
#  'Aircraft-Aircraft structures-Wing structure-Plates/skins (on wing)-Incorrect service/maintenance ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total instrument experience-Pilot',
#  'Personnel issues-Action/decision-Action-Lack of action-Owner/builder ',
#  'Personnel issues-Action/decision-Action-Incorrect action selection-Pilot of other aircraft ',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Failure',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-Landing distance-Not attained/maintained',
#  'Aircraft-Aircraft power plant-Engine exhaust-Thrust reverser-Incorrect use/operation ',
#  'Personnel issues-Miscellaneous-Intentional act-Stolen/unauthorized-Student/instructed pilot ',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Other',
#  'Environmental issues-Conditions/weather/phenomena-Ceiling/visibility/precip-Freezing rain/sleet-Effect on equipment',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel pump-Malfunction ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Incorrect service/maintenance ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel divider-Fatigue/wear/corrosion',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Descent rate-Attain/maintain not possible',
#  'Aircraft-Fluids/misc hardware-Misc hardware-(general) Incorrect service/maintenance ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Lateral/bank control-Related operating info ',
#  'Environmental issues-Physical environment-Terrain-Sloped/uneven terrain-Response/compensation',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Student/instructed pilot',
#  'Environmental issues-Operating environment-Air traffic/operating proc-ATC clearance procedure-Effect on operation ',
#  'Organizational issues-Management-Resources-Availability of equipment-Meteorological service ',
#  'Personnel issues-Task performance-Communication (personnel)-(general) Other/unknown ',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear-Incorrect service/maintenance ',
#  'Aircraft-Aircraft power plant-Engine (reciprocating)-Recip engine power section-Incorrect service/maintenance ',
#  'Organizational issues-Support/oversight/monitoring-Documentation/record keeping-(general) Operator ',
#  'Aircraft-Aircraft power plant-Power plant-Air intake-Inadequate inspection',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total instrument experience-Pilot ',
#  'Personnel issues-Action/decision-Info processing/decision-Identification/recognition-Student/instructed pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Not specified ',
#  'Aircraft-Aircraft power plant-Ignition system-Spark plugs/igniters-Not specified ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Dust devil/whirlwind-Not specified ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Sudden wind shift-Effect on equipment ',
#  'Personnel issues-Action/decision-Action-Unnecessary action-Pilot of other aircraft ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller hub section-Incorrect service/maintenance ',
#  'Organizational issues-Support/oversight/monitoring-Safety programs-Availability of safety program-Other government ',
#  'Environmental issues-Physical environment-Object/animal/substance-Animal(s)/bird(s)-Response/compensation ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel quantity sensor-Incorrect service/maintenance ',
#  'Aircraft-Aircraft propeller/rotor-Propeller system-Propeller controlling system-Unintentional use/operation ',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway/landing area length-Accuracy of related info',
#  'Personnel issues-Action/decision-Action-Incomplete action-Maintenance personnel ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Effect on operation',
#  'Environmental issues-Physical environment-Object/animal/substance-Sign/marker-Awareness of condition ',
#  'Environmental issues-Operating environment-Approach aid coverage/avail-Glideslope-Compliance w/ procedure ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel indication system-Malfunction',
#  'Environmental issues-Physical environment-Terrain-Water-Effect on operation ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Main rotor gearbox-Inadequate inspection ',
#  'Personnel issues-Task performance-Maintenance-Unauthorized maint/repair-Not specified ',
#  'Aircraft-Aircraft propeller/rotor-Main rotor drive-Engine/transmission coupling-Damaged/degraded ',
#  'Organizational issues-Support/oversight/monitoring-Training-(general) Airport ',
#  'Aircraft-Aircraft structures-Wing structure-Ailerons-Fatigue/wear/corrosion ',
#  'Organizational issues-Support/oversight/monitoring-Enforcement-Operational procedures-FAA/Regulator',
#  'Personnel issues-Physical-Alertness/Fatigue-Lack of sleep-Flight crew ',
#  'Personnel issues-Psychological-Personality/attitude-Personality-Pilot ',
#  'Aircraft-Fluids/misc hardware-Fluids-Fuel-Fluid type ',
#  'Aircraft-Aircraft systems-Landing gear system-Nose/tail landing gear-Damaged/degraded ',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Pilot',
#  'Aircraft-Aircraft structures-Doors-Passenger/crew doors-Malfunction ',
#  'Personnel issues-Experience/knowledge-Experience/qualifications-Total experience in position-Pilot ',
#  'Organizational issues-Support/oversight/monitoring-(general) Operator ',
#  'Aircraft-Aircraft structures-Fuselage-(general) Damaged/degraded ',
#  'Environmental issues-Conditions/weather/phenomena-Convective weather-(general) Timing of related info',
#  'Aircraft-Aircraft power plant-Engine controls-Power lever-Not inspected ',
#  'Environmental issues-Operating environment-Airport facilities/design-Airport lighting-Not specified',
#  'Personnel issues-Psychological-Mental/emotional state-Anxiety/panic-Passenger ',
#  'Aircraft-Aircraft systems-Landing gear system-Main landing gear attach sec-Incorrect service/maintenance',
#  'Personnel issues-Psychological-Perception/orientation/illusion-Spatial disorientation-Copilot ',
#  'Aircraft-Aircraft systems-Electrical power system-Electrical pwr sys wiring-Damaged/degraded ',
#  'Aircraft-Aircraft systems-Vacuum system-(general) Incorrect service/maintenance ',
#  'Personnel issues-Action/decision-Action-Lack of action-Flight crew',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear brakes system-Failure ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Not attained/maintained ',
#  'Aircraft-Aircraft structures-Empennage structure-Elevator misc structure-Failure ',
#  'Aircraft-Aircraft systems-Lighting system-Exterior lighting-Incorrect service/maintenance ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-(general) Ability to respond/compensate',
#  'Aircraft-Fluids/misc hardware-Fluids-Grease-Incorrect service/maintenance ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Altitude-Related operating info ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Awareness of condition ',
#  'Aircraft-Aircraft structures-(general) Not serviced/maintained ',
#  'Environmental issues-Conditions/weather/phenomena-Wind-Variable wind-Response/compensation ',
#  'Aircraft-Aircraft systems-Electrical power system-Alternator-generator drive sys-Inoperative ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Airspeed-Not specified',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surfa-Snow/slush/ice covered-Effect on operation ',
#  'Aircraft-Aircraft systems-Flight control system-Rudder control system-Unintentional use/operation ',
#  'Environmental issues-Operating environment-Airport facilities/design-Runway lighting-Not specified ',
#  'Organizational issues-Support/oversight/monitoring-Oversight-Oversight of maintenance-FAA/Regulator',
#  'Personnel issues-Action/decision-(general) ATC personnel ',
#  'Aircraft-Aircraft systems-Fuel system-Fuel distribution-Design ',
#  'Personnel issues-Action/decision-Action-Incorrect action performance-Passenger ',
#  'Personnel issues-Task performance-Inspection-Preflight inspection-Pilot',
#  'Aircraft-Aircraft systems-Landing gear system-Landing gear actuator-Not used/operated ',
#  'Aircraft-Fluids/misc hardware-Fluids-(general) Not serviced/maintained ',
#  'Aircraft-Aircraft power plant-Engine controls-(general) Failure ',
#  'Organizational issues-Development-Selection/certification/testing-Document/info verification-FAA/Regulator ',
#  'Environmental issues-Operating environment-Airport facilities/design-Taxiway markings/signage-Compliance w/ procedure ',
#  'Aircraft-Aircraft power plant-Engine fuel and control-Fuel control/carburetor-Related operating info ',
#  'Environmental issues-Physical environment-Object/animal/substance-Aircraft-Contributed to outcome ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Directional control-Attain/maintain not possible ',
#  'Organizational issues-Management-Communication (organizational)-Between groups/organizations-Meteorological service ',
#  'Aircraft-Aircraft structures-Wing structure-Plates/skins (on wing)-Fatigue/wear/corrosion ',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Incorrect use/operation ',
#  'Environmental issues-Conditions/weather/phenomena-Light condition-Glare-Contributed to outcome ',
#  'Personnel issues-Action/decision-Info processing/decision-Decision making/judgment-Other/unknown ',
#  'Aircraft-Aircraft oper/perf/capability-Aircraft capability-CG/weight distribution-Not attained/maintained ',
#  'Aircraft-Aircraft systems-Flight control system-Gust lock or damper-Incorrect use/operation',
#  'Aircraft-Aircraft oper/perf/capability-Performance/control parameters-Crosswind correction-Not attained/maintained ',
#  'Environmental issues-Physical environment-Runway/land/takeoff/taxi surface-Soft-Effect on equipment ',
#  'Environmental issues-Conditions/weather/phenomena-Temp/humidity/pressure-Conducive to carburetor icing-Not specified ',
#  ...]

# %%
findings_ls = findings_ls_ver2

# %%
# Count the number of layers that will be needed in the network diagram - max and min
word_no_ls = []
for finding in findings_ls:
    word_no = len(re.split('-', finding))
    word_no_ls.append(word_no)
max_word_no = max(word_no_ls)
min_word_no = min(word_no_ls)
print('Min connections are: ', min_word_no)
print('Max connections are: ', max_word_no)
# Out:
# Min connections is:  2
# Max connections is:  6

# %%
# identify the unique words for each layer
type_ls = []
sys_ls = []
subsys_ls = []
details_ls = []
moredet_ls = []
evenmore_ls = []
ix = 0
for finding in findings_ls:
    # for each finding I want to append each word to a separate list
    # but I also want the connection
    # remove trailing characters to enable the only values to be found and shown using .rstrip()
    ix += 1
    word_ls = re.split('-', finding)
    if len(word_ls) == 2:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
    elif len(word_ls) == 3:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
        subsys_ls.append(word_ls[2].rstrip())
    elif len(word_ls) == 4:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
        subsys_ls.append(word_ls[2].rstrip())
        details_ls.append(word_ls[3].rstrip())
    elif len(word_ls) == 5:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
        subsys_ls.append(word_ls[2].rstrip())
        details_ls.append(word_ls[3].rstrip())
        moredet_ls.append(word_ls[4].rstrip())
    else:
        type_ls.append(word_ls[0].rstrip())
        sys_ls.append(word_ls[1].rstrip())
        subsys_ls.append(word_ls[2].rstrip())
        details_ls.append(word_ls[3].rstrip())
        moredet_ls.append(word_ls[4].rstrip())
        evenmore_ls.append(word_ls[5].rstrip())

# %%
type_ls = set(type_ls)
sys_ls = set(sys_ls)
subsys_ls = set(subsys_ls)
details_ls = set(details_ls)
moredet_ls = set(moredet_ls)
evenmore_ls = set(evenmore_ls)

# %%
# Does it make sense to rework the data as a dictionary of dictionaries for creating network diagrams?

# %% [markdown]
# ## Create the network diagram of the connections

# %%
def NetworkLinks(type_ls, findings_ls, ix1, ix2):
    LinkDict = {}
    for type_name in type_ls:
        ls = []
        for finding in findings_ls:
            type_names_found = re.split('-', finding)
            if len(type_names_found) < 2:
                continue
            else:
                type_name_found = type_names_found[ix1]
                system = re.split('-', finding)[ix2]
                if type_name == type_name_found:
                    ls.append(system)
                else:
                    continue
        ls = list(set(ls))
        LinkDict[type_name] = ls 
    return LinkDict

# %%
def NetworkLinks_ver2(subsys_ls, findings_ls, ix1, ix2): # only for subsystem to more details
    LinkDict = {}
    for type_name in subsys_ls:
        ls = []
        for finding in findings_ls:
            type_names_found = re.split('-', finding)
            if len(type_names_found) <= 3: # condition for the 
                continue
            else:
                type_name_found = type_names_found[ix1]
                system = type_names_found[ix2]
                if type_name == type_name_found:
                    ls.append(system)
                else:
                    continue
        ls = list(set(ls))
        LinkDict[type_name] = ls
    return LinkDict

# %%
type_to_sys = NetworkLinks(type_ls, findings_ls, 0, 1)
sys_to_sub = NetworkLinks_ver2(sys_ls, findings_ls, 1, 2)
sub_to_det = NetworkLinks_ver2(subsys_ls, findings_ls, 2, 3) # need to add an extra condition for sets of strings that don't have any more words
#det_to_more = NetworkLinks_ver2(details_ls, findings_ls, 3, 4)

# %%
list(sys_to_sub.values())[0]
# Out:
# ['Temp/humidity/pressure',
#  'Wind',
#  'Turbulence',
#  'Light condition',
#  'Ceiling/visibility/precip',
#  'Convective weather']

# %%
key_ls = list(type_to_sys.keys())
value_ls = list(type_to_sys.values())

# %% [markdown]
# ## Choose a specific type no. for visualisation

# %%
type_no = 0
for key in key_ls:
    print(key, ' correspond to Type No. ', type_no)
    type_no += 1
# Out:
# Aircraft  correspond to Type No.  0
# Environmental issues  correspond to Type No.  1
# main system  correspond to Type No.  2
# Not determined  correspond to Type No.  3
# Personnel issues  correspond to Type No.  4
# Organizational issues  correspond to Type No.  5

# %%
type_no = 0
plt.figure(3,figsize=(15, 15)) 
G = nx.Graph()
for value in value_ls[type_no]:
    G.add_edge(key_ls[type_no], value)
nx.draw(G, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=10)
plt.show()

# %%
# How to build on top of the graph already made?
sys_to_sub_ls = list(sys_to_sub.keys())
value_test_ls = []
plt.figure(3,figsize=(20, 20)) 
# pos = nx.bfs_layout(G, key_ls[type_no]) # recreation of the layout I've been using for my spider diagrams
pos = nx.kamada_kawai_layout(G, scale = 10) # recommended layout type for clearest visualisation BUT overlapping labels
for value in value_ls[type_no]:
    for system in sys_to_sub_ls:
        if value == system:
            for subsys in sys_to_sub[system]:
                value_test_ls.append(subsys)
                G.add_edge(system, subsys)
nx.draw(G, pos=pos, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=10)
plt.show()

# %%
# do it part by part
# only select 5 conditions to develop
#value_test_ls = value_test_ls[0:5]

# %% [markdown]
# ## Choose a specific system/subsystem to visualise

# %%
key_ls = list(sub_to_det.keys())
value_ls = list(sub_to_det.values())

# %%
subsys_no = 0
for key in key_ls:
    print(key, ' = Subsys No. ', type_no)
    type_no += 1
# Out:
# Selection/certification/testin  = Subsys No.  328
# Oversight  = Subsys No.  329
# Ignition system  = Subsys No.  330
# Experience/qualifications  = Subsys No.  331
# Policy/procedure  = Subsys No.  332
# Air conditioning system  = Subsys No.  333
# Object/animal/substance  = Subsys No.  334
# (general) Manufacturer  = Subsys No.  335
# Record  = Subsys No.  336
# Equipment/furnishings  = Subsys No.  337
# (general) Capability exceeded  = Subsys No.  338
# (general) Meteorological service  = Subsys No.  339
# Runway/land/takeoff/taxi surfa  = Subsys No.  340
# (general) Incorrect use/operation  = Subsys No.  341
# (general) Not used/operated  = Subsys No.  342
# (general) Awareness of condition  = Subsys No.  343
# Fluids  = Subsys No.  344
# Training  = Subsys No.  345
# Nacelles/pylons structure  = Subsys No.  346
# Airport facilities/design  = Subsys No.  347
# Balloon/dirigible structures  = Subsys No.  348
# Landing gear system  = Subsys No.  349
# Communication (personnel)  = Subsys No.  350
# Inspection  = Subsys No.  351
# Engine (turbine/turboprop)  = Subsys No.  352
# Main rotor drive  = Subsys No.  353
# (general) Decision related to condition  = Subsys No.  354
# (general) Damaged/degraded  = Subsys No.  355
# (general) Inoperative  = Subsys No.  356
# (general) Instructor/check pilot  = Subsys No.  357
# Wing structure  = Subsys No.  358
# (general) Owner/builder  = Subsys No.  359
# Parking/securing  = Subsys No.  360
# Air traffic/operating proc  = Subsys No.  361
# Aircraft capability  = Subsys No.  362
# (general) Student pilot  = Subsys No.  363
# (general) Related operating info  = Subsys No.  364
# Light condition  = Subsys No.  365
# Design  = Subsys No.  366
# Cognitive limitation  = Subsys No.  367
# Sensory ability/limitation  = Subsys No.  368
# Towing and taxiing  = Subsys No.  369
# Loading  = Subsys No.  370
# Water injection  = Subsys No.  371
# (general) Effect on equipment  = Subsys No.  372
# (general) ATC  = Subsys No.  373
# Manufacture/production  = Subsys No.  374
# Engine exhaust  = Subsys No.  375
# Planning/preparation  = Subsys No.  376
# Tail rotor drive system  = Subsys No.  377
# Alertness/Fatigue  = Subsys No.  378
# Indicating/recording systems  = Subsys No.  379
# Impairment/incapacitation  = Subsys No.  380
# (general) Malfunction  = Subsys No.  381
# Runway/land/takeoff/taxi surface  = Subsys No.  382
# (general) Not installed/available  = Subsys No.  383
# (general) Attain/maintain not possible  = Subsys No.  384
# (general) Other authority investigated  = Subsys No.  385
# Navigation system  = Subsys No.  386
# (general) Other/unknown  = Subsys No.  387
# Auto flight system  = Subsys No.  388
# (general) Availability of related info  = Subsys No.  389
# Communication system  = Subsys No.  390
# Ceiling/visibility/precip  = Subsys No.  391
# Turbocharging (recip only)  = Subsys No.  392
# (general) Not specified  = Subsys No.  393
# Pneumatic system  = Subsys No.  394
# Doors  = Subsys No.  395
# (general) Operator  = Subsys No.  396
# Enforcement  = Subsys No.  397
# (general) Passenger  = Subsys No.  398
# (general) Other government  = Subsys No.  399
# (general) Copilot  = Subsys No.  400
# Vacuum system  = Subsys No.  401
# Mental/emotional state  = Subsys No.  402
# Accessory gear  = Subsys No.  403
# Culture  = Subsys No.  404
# Eng oil sys (airframe furnish)  = Subsys No.  405
# Terrain  = Subsys No.  406
# Perception/orientation/illusion  = Subsys No.  407
# (general) Ability to respond/compensate  = Subsys No.  408
# (general) Incorrect service/maintenance  = Subsys No.  409
# Placards and markings  = Subsys No.  410
# Engine (reciprocating)  = Subsys No.  411
# Physical workspace  = Subsys No.  412
# Main rotor system  = Subsys No.  413
# Windows  = Subsys No.  414
# (general) Fluid level  = Subsys No.  415
# (general) Student/instructed pilot  = Subsys No.  416
# (general) Unintentional use/operation  = Subsys No.  417
# Resources  = Subsys No.  418
# (general) Design  = Subsys No.  419
# Action  = Subsys No.  420
# Engine indicating system  = Subsys No.  421
# Empennage structure  = Subsys No.  422
# (general) Airport  = Subsys No.  423
# (general) Not serviced/maintained  = Subsys No.  424
# Radar services/coverage  = Subsys No.  425
# Knowledge  = Subsys No.  426
# Engine bleed air system  = Subsys No.  427
# Engine controls  = Subsys No.  428
# Fuel system  = Subsys No.  429
# Engine fuel and control  = Subsys No.  430
# (general) Maintenance personnel  = Subsys No.  431
# Pressures/demands  = Subsys No.  432
# Workload management  = Subsys No.  433
# Attention/monitoring  = Subsys No.  434
# Maintenance  = Subsys No.  435
# (general) Related records  = Subsys No.  436
# Electrical power system  = Subsys No.  437
# (general) Pilot  = Subsys No.  438
# (general) Not attained/maintained  = Subsys No.  439
# Airborne APU system  = Subsys No.  440
# Tail rotor  = Subsys No.  441
# Hydraulic power system  = Subsys No.  442
# Perception/orientation/illusio  = Subsys No.  443
# Misc hardware  = Subsys No.  444
# (general) ATC personnel  = Subsys No.  445
# (general) Airport personnel  = Subsys No.  446
# (general) Flight crew  = Subsys No.  447
# Convective weather  = Subsys No.  448
# Health/Fitness  = Subsys No.  449
# Documentation/record keeping  = Subsys No.  450
# Scheduling  = Subsys No.  451
# (general) Fluid management  = Subsys No.  452
# Temp/humidity/pressure  = Subsys No.  453
# Maintenance/inspections  = Subsys No.  454
# (general) Unknown/Not determined  = Subsys No.  455
# Lighting system  = Subsys No.  456
# (general) Effect on operation  = Subsys No.  457
# Power plant  = Subsys No.  458
# Turbulence  = Subsys No.  459
# (general) Contributed to outcome  = Subsys No.  460
# Personality/attitude  = Subsys No.  461
# Physical characteristic  = Subsys No.  462
# Approach aid coverage/avail  = Subsys No.  463
# (general) Inadequate inspection  = Subsys No.  464
# Fire protection system  = Subsys No.  465
# Engine starting  = Subsys No.  466
# (general) Fatigue/wear/corrosion  = Subsys No.  467
# (general) Failure  = Subsys No.  468
# Meteorological services  = Subsys No.  469
# Use of equip/info  = Subsys No.  470
# Flight control system  = Subsys No.  471
# (general) Related maintenance info  = Subsys No.  472
# (general) Ground crew  = Subsys No.  473
# Rotorcraft flight control  = Subsys No.  474
# Safety programs  = Subsys No.  475
# Wind  = Subsys No.  476
# (general) Pilot of other aircraft  = Subsys No.  477
# Water and waste system  = Subsys No.  478
# (general) Cabin crew  = Subsys No.  479
# Oxygen system  = Subsys No.  480
# Performance/control parameters  = Subsys No.  481
# Intentional act  = Subsys No.  482
# Fuselage  = Subsys No.  483
# Communication (organizational)  = Subsys No.  484
# Propeller system  = Subsys No.  485
# (general) Simulated malf/failure  = Subsys No.  486
# Ice/rain protection system  = Subsys No.  487
# (general) Effect on personnel  = Subsys No.  488
# Selection/certification/testing  = Subsys No.  489
# Info processing/decision  = Subsys No.  490
# Communications system  = Subsys No.  491

# %%
subsys_no = 24
plt.figure(3,figsize=(15, 15)) 
S = nx.Graph()
for value in value_ls[subsys_no]:
    S.add_edge(key_ls[subsys_no], value)
nx.draw(S, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=10)
plt.show()

# %%
# repeat the process for the other details
sub_to_det_ls = list(sub_to_det.keys())
# pos = nx.bfs_layout(G, key_ls[type_no]) #would this one work where each branch becomes its own layout
# Ideally limit the number of loops based on thevalues already in the chart
for value in value_test_ls:
    for subsystem in sub_to_det_ls:
        if value == subsystem:
            for subsys in sub_to_det[subsystem]:
                G.add_edge(system, subsys)
nx.draw(G, pos=pos, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=5)
plt.show()

# %%
# How to build on top of the graph already made?
sys_to_sub_ls = list(sys_to_sub.keys())
sub_ls = list(sys_to_sub.values())
fig = plt.figure()
for value in value_ls[type_no]:
    for system in sys_to_sub_ls:
        if value == system:
            for subsys in sys_to_sub[system]:
                G.add_edge(system, subsys)
nx.draw(G, with_labels = True, node_shape="s", node_color="none", bbox=dict(facecolor="skyblue", edgecolor='black', boxstyle='round, pad=0.2'), font_size=5, ax=fig.add_subplot())
if True: 
    # Save plot to file
    # mat.use("Agg") 
    fig.savefig("graph.png")
# Out:
# C:\Users\yxb19198\AppData\Local\Temp\ipykernel_10756\889855193.py:13: MatplotlibDeprecationWarning: Auto-close()ing of figures upon backend switching is deprecated since 3.8 and will be removed in 3.10.  To suppress this warning, explicitly call plt.close('all') first.
#   mat.use("Agg")

# %%
list(sys_to_sub.keys())
# Out:
# ['Conditions/weather/phenomena',
#  'Aircraft systems',
#  'Aircraft handling/service',
#  'Experience/knowledge',
#  'Capability exceeded ',
#  'Task environment',
#  'Operating environment',
#  'Action/decision',
#  'Development',
#  'Simulated malf/failure ',
#  'Fluids/misc hardware',
#  'Task performance',
#  'Support/oversight/monitoring',
#  'Inoperative ',
#  'Aircraft power plant',
#  'Psychological',
#  'Physical',
#  'Not determined',
#  'Management',
#  'Aircraft structures',
#  'Physical environment',
#  'Aircraft oper/perf/capability',
#  'Miscellaneous',
#  'Damaged/degraded ',
#  'Aircraft propeller/rotor']

# %%
value_ls = list(type_to_sys.values())
value_ls[0]
# Out:
# ['Conditions/weather/phenomena',
#  'Task environment',
#  'Physical environment',
#  'Operating environment']
